# %% [markdown]
# <h1>Содержания<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта." data-toc-modified-id="Описание-проекта.-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта.</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Задачи" data-toc-modified-id="Задачи-1.0.1"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>Задачи</a></span></li><li><span><a href="#Вопросы" data-toc-modified-id="Вопросы-1.0.2"><span class="toc-item-num">1.0.2&nbsp;&nbsp;</span>Вопросы</a></span></li></ul></li></ul></li><li><span><a href="#Синопсис:" data-toc-modified-id="Синопсис:-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Синопсис:</a></span></li><li><span><a href="#Анализ-df_movie" data-toc-modified-id="Анализ-df_movie-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Анализ df_movie</a></span><ul class="toc-item"><li><span><a href="#Наблюдение:" data-toc-modified-id="Наблюдение:-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Наблюдение:</a></span></li><li><span><a href="#Общий-вывод-по-df_movie" data-toc-modified-id="Общий-вывод-по-df_movie-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Общий вывод по df_movie</a></span><ul class="toc-item"><li><span><a href="#Название-столбцов:" data-toc-modified-id="Название-столбцов:-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Название столбцов:</a></span></li><li><span><a href="#Типы-даных:" data-toc-modified-id="Типы-даных:-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Типы даных:</a></span></li><li><span><a href="#Пропущенные-значения:" data-toc-modified-id="Пропущенные-значения:-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Пропущенные значения:</a></span><ul class="toc-item"><li><span><a href="#Дополнительные-категорильные-столбцы:" data-toc-modified-id="Дополнительные-категорильные-столбцы:-3.2.3.1"><span class="toc-item-num">3.2.3.1&nbsp;&nbsp;</span>Дополнительные категорильные столбцы:</a></span></li></ul></li><li><span><a href="#Дубликаты:" data-toc-modified-id="Дубликаты:-3.2.4"><span class="toc-item-num">3.2.4&nbsp;&nbsp;</span>Дубликаты:</a></span></li><li><span><a href="#Артефакты,-аномалии-и-неявные-дубликаты:" data-toc-modified-id="Артефакты,-аномалии-и-неявные-дубликаты:-3.2.5"><span class="toc-item-num">3.2.5&nbsp;&nbsp;</span>Артефакты, аномалии и неявные дубликаты:</a></span></li></ul></li></ul></li><li><span><a href="#Анализ-df_shows" data-toc-modified-id="Анализ-df_shows-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Анализ df_shows</a></span><ul class="toc-item"><li><span><a href="#Общий-вывод-по-df_shows" data-toc-modified-id="Общий-вывод-по-df_shows-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Общий вывод по df_shows</a></span><ul class="toc-item"><li><span><a href="#Название-столбцов:" data-toc-modified-id="Название-столбцов:-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Название столбцов:</a></span></li><li><span><a href="#Типы-даных:" data-toc-modified-id="Типы-даных:-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Типы даных:</a></span></li><li><span><a href="#Пропущенные-значения:" data-toc-modified-id="Пропущенные-значения:-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Пропущенные значения:</a></span></li><li><span><a href="#Дубликаты:" data-toc-modified-id="Дубликаты:-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Дубликаты:</a></span></li><li><span><a href="#Артефакты,-аномалии-и-неявные-дубликаты:" data-toc-modified-id="Артефакты,-аномалии-и-неявные-дубликаты:-4.1.5"><span class="toc-item-num">4.1.5&nbsp;&nbsp;</span>Артефакты, аномалии и неявные дубликаты:</a></span></li></ul></li></ul></li><li><span><a href="#Очистка-данных-в-df_movies" data-toc-modified-id="Очистка-данных-в-df_movies-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Очистка данных в df_movies</a></span></li><li><span><a href="#Соединение-таблицы-и-переименование-столбца-puNumber" data-toc-modified-id="Соединение-таблицы-и-переименование-столбца-puNumber-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Соединение таблицы и переименование столбца puNumber</a></span></li><li><span><a href="#Создание-столбцов" data-toc-modified-id="Создание-столбцов-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Создание столбцов</a></span></li><li><span><a href="#ИАД-и-графики" data-toc-modified-id="ИАД-и-графики-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>ИАД и графики</a></span><ul class="toc-item"><li><span><a href="#Кол-во-фильмов-в-прокате-каждый-год" data-toc-modified-id="Кол-во-фильмов-в-прокате-каждый-год-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Кол-во фильмов в прокате каждый год</a></span></li><li><span><a href="#Доли-фильмов-по-годам" data-toc-modified-id="Доли-фильмов-по-годам-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Доли фильмов по годам</a></span><ul class="toc-item"><li><span><a href="#Доля-прокатных-фильмов----все-удостоврение-с-первым-числом-меньше-22" data-toc-modified-id="Доля-прокатных-фильмов----все-удостоврение-с-первым-числом-меньше-22-8.2.1"><span class="toc-item-num">8.2.1&nbsp;&nbsp;</span>Доля прокатных фильмов -  все удостоврение с первым числом меньше 22</a></span></li><li><span><a href="#Полнота-данных-проката-по-годам" data-toc-modified-id="Полнота-данных-проката-по-годам-8.2.2"><span class="toc-item-num">8.2.2&nbsp;&nbsp;</span>Полнота данных проката по годам</a></span></li></ul></li><li><span><a href="#Средняя-и-медианная-сумма-сбора-по-годам" data-toc-modified-id="Средняя-и-медианная-сумма-сбора-по-годам-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Средняя и медианная сумма сбора по годам</a></span></li><li><span><a href="#Сумма-сбора-~-возрастное-ограничение-+-год" data-toc-modified-id="Сумма-сбора-~-возрастное-ограничение-+-год-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>Сумма сбора ~ возрастное ограничение + год</a></span></li><li><span><a href="#Процент-государственной-поддержки-по-годам" data-toc-modified-id="Процент-государственной-поддержки-по-годам-8.5"><span class="toc-item-num">8.5&nbsp;&nbsp;</span>Процент государственной поддержки по годам</a></span></li><li><span><a href="#Процент-возвращаемой-и-невозвращаемой-государственной-поддержки-по-годам" data-toc-modified-id="Процент-возвращаемой-и-невозвращаемой-государственной-поддержки-по-годам-8.6"><span class="toc-item-num">8.6&nbsp;&nbsp;</span>Процент возвращаемой и невозвращаемой государственной поддержки по годам</a></span></li><li><span><a href="#Анализ-жанров-фильмов-с-гос.-поддержкой-с-гос.-поддержкой" data-toc-modified-id="Анализ-жанров-фильмов-с-гос.-поддержкой-с-гос.-поддержкой-8.7"><span class="toc-item-num">8.7&nbsp;&nbsp;</span>Анализ жанров фильмов с гос. поддержкой с гос. поддержкой</a></span></li><li><span><a href="#Анализ-типов-фильмов-с-гос.-поддержкой" data-toc-modified-id="Анализ-типов-фильмов-с-гос.-поддержкой-8.8"><span class="toc-item-num">8.8&nbsp;&nbsp;</span>Анализ типов фильмов с гос. поддержкой</a></span></li></ul></li><li><span><a href="#Выводы:" data-toc-modified-id="Выводы:-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Выводы:</a></span><ul class="toc-item"><li><span><a href="#Количество-фильмов-по-годам" data-toc-modified-id="Количество-фильмов-по-годам-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Количество фильмов по годам</a></span></li><li><span><a href="#Средняя-и-медианная-сумма-сбора-по-годам-(по-возрастанию)" data-toc-modified-id="Средняя-и-медианная-сумма-сбора-по-годам-(по-возрастанию)-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Средняя и медианная сумма сбора по годам (по возрастанию)</a></span></li><li><span><a href="#Доля-прокатных-фильмов---все-удостоврение-с-первым-числом-меньше-22" data-toc-modified-id="Доля-прокатных-фильмов---все-удостоврение-с-первым-числом-меньше-22-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Доля прокатных фильмов - все удостоврение с первым числом меньше 22</a></span></li><li><span><a href="#Полнота-данных-проката-по-годам:" data-toc-modified-id="Полнота-данных-проката-по-годам:-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>Полнота данных проката по годам:</a></span></li><li><span><a href="#Сумма-сбора-~-возрастное-ограничение-+-год" data-toc-modified-id="Сумма-сбора-~-возрастное-ограничение-+-год-9.5"><span class="toc-item-num">9.5&nbsp;&nbsp;</span>Сумма сбора ~ возрастное ограничение + год</a></span></li><li><span><a href="#Процент-государственной-поддержки-по-годам" data-toc-modified-id="Процент-государственной-поддержки-по-годам-9.6"><span class="toc-item-num">9.6&nbsp;&nbsp;</span>Процент государственной поддержки по годам</a></span></li><li><span><a href="#Процент-возвращаемой-и-невозвращаемой-государственной-поддержки-по-годам:" data-toc-modified-id="Процент-возвращаемой-и-невозвращаемой-государственной-поддержки-по-годам:-9.7"><span class="toc-item-num">9.7&nbsp;&nbsp;</span>Процент возвращаемой и невозвращаемой государственной поддержки по годам:</a></span></li><li><span><a href="#Анализ-жанров-фильмов-с-гос.-поддержкой-и-рейтинга" data-toc-modified-id="Анализ-жанров-фильмов-с-гос.-поддержкой-и-рейтинга-9.8"><span class="toc-item-num">9.8&nbsp;&nbsp;</span>Анализ жанров фильмов с гос. поддержкой и рейтинга</a></span></li><li><span><a href="#Анализ-типов-фильмов-с-гос.поддержкой-и-рейтинга" data-toc-modified-id="Анализ-типов-фильмов-с-гос.поддержкой-и-рейтинга-9.9"><span class="toc-item-num">9.9&nbsp;&nbsp;</span>Анализ типов фильмов с гос.поддержкой и рейтинга</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Описание проекта.
#
# Заказчик — Министерство культуры Российской Федерации.
#
# #### Задачи
# 1. Изучить рынок российского кинопроката и выявить текущие тренды.
# 2. Провести анализ фильмов с государственной поддержкой
#
# #### Вопросы
#
# 1. Насколько интересны и прибыльны фильмы с государственной поддержкой?
# 2. Какую долю от общего бюджета фильма составляет государственная поддержка?
# 3. Сколько фильмов выходило в прокат в каждом году?
# 4. Какова доля кинопроката в базе?
# 5. Как менялась динамика проката по годам. В каком году сумма сборов была минимальной и максимальной?
# 6. Каковы средние и медианные значения сборов по годам?
# 7. Влияет ли возрастное ограничение аудитории на сборы фильма в прокате в период с 2015 по 2019 год?
# 8. Фильмы с каким возрастным ограничением собрали больше всего денег в прокате? Есть ли изменения по годам?

# %% [markdown]
# ## Синопсис:
#
# 1. **Проанализируем каждую таблицу по отдельности.**
# 2. **Проведем очистку данных.**
# 3. **Объединим данные по прокатному удостоверению.**
# 4. **Проведем нужный ИАД, нарисуем графики и сделаем выводы.**
# 5. **Найдем интересные закономерности и тенденции.**

# %%
# !pip install re 
# !pip install squarify
# !pip install wordcloud 
# !pip install datetime
# !pip install matplotlib
# !pip install numpy
# !pip install seaborn
# !pip install pandas
# Out:
# ERROR: Could not find a version that satisfies the requirement re (from versions: none)
# ERROR: No matching distribution found for re
# Requirement already satisfied: squarify in c:\users\egor\anaconda3\lib\site-packages (0.4.3)
# Requirement already satisfied: wordcloud in c:\users\egor\anaconda3\lib\site-packages (1.8.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\egor\anaconda3\lib\site-packages (from wordcloud) (1.22.4)
# Requirement already satisfied: matplotlib in c:\users\egor\anaconda3\lib\site-packages (from wordcloud) (3.4.3)
# Requirement already satisfied: pillow in c:\users\egor\anaconda3\lib\site-packages (from wordcloud) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\egor\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\egor\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\egor\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\egor\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.10.0)
# Requirement already satisfied: six in c:\users\egor\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib->wordcloud) (1.16.0)
# Requirement already satisfied: datetime in c:\users\egor\anaconda3\lib\site-packages (5.1)
# Requirement already satisfied: zope.interface in c:\users\egor\anaconda3\lib\site-packages (from datetime) (5.4.0)
# Requirement already satisfied: pytz in c:\users\egor\anaconda3\lib\site-packages (from datetime) (2021.3)
# Requirement already satisfied: setuptools in c:\users\egor\anaconda3\lib\site-packages (from zope.interface->datetime) (58.0.4)
# Requirement already satisfied: matplotlib in c:\users\egor\anaconda3\lib\site-packages (3.4.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\egor\anaconda3\lib\site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\egor\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\egor\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\egor\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\egor\anaconda3\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: numpy>=1.16 in c:\users\egor\anaconda3\lib\site-packages (from matplotlib) (1.22.4)
# Requirement already satisfied: six in c:\users\egor\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Requirement already satisfied: numpy in c:\users\egor\anaconda3\lib\site-packages (1.22.4)
# Requirement already satisfied: seaborn in c:\users\egor\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: pandas>=0.23 in c:\users\egor\anaconda3\lib\site-packages (from seaborn) (1.3.4)
# Requirement already satisfied: numpy>=1.15 in c:\users\egor\anaconda3\lib\site-packages (from seaborn) (1.22.4)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\egor\anaconda3\lib\site-packages (from seaborn) (3.4.3)
# Requirement already satisfied: scipy>=1.0 in c:\users\egor\anaconda3\lib\site-packages (from seaborn) (1.7.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\egor\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\egor\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\egor\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\egor\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\egor\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Requirement already satisfied: six in c:\users\egor\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\egor\anaconda3\lib\site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: pandas in c:\users\egor\anaconda3\lib\site-packages (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\egor\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\egor\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\egor\anaconda3\lib\site-packages (from pandas) (1.22.4)
# Requirement already satisfied: six>=1.5 in c:\users\egor\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)

# %%
# импортируем нужные библиотеки
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import os
import datetime as dt
import re 
import squarify
from wordcloud import WordCloud

# %%
# Найдем абсолютный путь и откроем нужные файлы
path_movies = os.path.abspath('mkrf_movies.csv')
path_shows = os.path.abspath('mkrf_shows.csv')
try:
    df_movies = pd.read_csv(path_movies)
    df_shows = pd.read_csv(path_shows)
except Exception as ex:
    print(f'Что-то пошло не так: {ex}')

# %%
# Функция для ознакомления с данными
def pre_view(data,n_row=4,head=True, info=True,columns=True,shape=True,isna=True,duplicated=True):
    if head:
        print(f'First {n_row} row(s) in the head of data')
        display(data.head(n_row))
        print('-'*30)
    if info:
        print('Data Information:')
        display(data.info())
        print('-'*30)
    if columns:
        print('Data columns:')
        display(data.columns)
        print('-'*30)
    if shape:
        print('Data shape:')
        display(data.shape)
        print('-'*30)
    if isna:
        print('Data isna by row mean:')
        display(data.isna().mean())
        print('-'*30)
    if duplicated:
        print('Data clear duplicates sum:')
        display(data.isna().mean())
        print('-'*30)

# %% [markdown]
# ## Анализ df_movie

# %%
# ознакомимся с таблицей df_movies
pre_view(df_movies,4)
# Out:
# First 4 row(s) in the head of data
#                   title   puNumber           show_start_date            type  \
# 0      Открытый простор  221048915  2015-11-27T12:00:00.000Z  Художественный
# 1  Особо важное задание  111013716  2016-09-13T12:00:00.000Z  Художественный
# 2          Особо опасен  221038416  2016-10-10T12:00:00.000Z  Художественный
# 3          Особо опасен  221026916  2016-06-10T12:00:00.000Z  Художественный
#
#                                          film_studio production_country  \
# 0  Тачстоун Пикчерз, Кобальт Пикчерз, Бикон Пикче...                США
# 1                              Киностудия "Мосфильм"               СССР
# 2  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 3  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
#
#             director                                           producer  \
# 0      Кевин Костнер          Дэвид Валдес, Кевин Костнер, Джейк Эбертс
# 1          Е.Матвеев                                                NaN
# 2  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 3  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
#
#                  age_restriction  refundable_support  nonrefundable_support  \
# 0    «18+» - запрещено для детей                 NaN                    NaN
# 1  «6+» - для детей старше 6 лет                 NaN                    NaN
# 2    «18+» - запрещено для детей                 NaN                    NaN
# 3    «18+» - запрещено для детей                 NaN                    NaN
#
#    budget financing_source ratings                     genres
# 0     NaN              NaN     7.2     боевик,драма,мелодрама
# 1     NaN              NaN     6.6              драма,военный
# 2     NaN              NaN     6.8  фантастика,боевик,триллер
# 3     NaN              NaN     6.8  фантастика,боевик,триллер
# ------------------------------
# Data Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7486 entries, 0 to 7485
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7486 non-null   object
#  2   show_start_date        7486 non-null   object
#  3   type                   7486 non-null   object
#  4   film_studio            7468 non-null   object
#  5   production_country     7484 non-null   object
#  6   director               7477 non-null   object
#  7   producer               6918 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   object
#  14  genres                 6510 non-null   object
# dtypes: float64(3), object(12)
# memory usage: 877.4+ KB
# None
# ------------------------------
# Data columns:
# Index(['title', 'puNumber', 'show_start_date', 'type', 'film_studio',
#        'production_country', 'director', 'producer', 'age_restriction',
#        'refundable_support', 'nonrefundable_support', 'budget',
#        'financing_source', 'ratings', 'genres'],
#       dtype='object')
# ------------------------------
# Data shape:
# (7486, 15)
# ------------------------------
# Data isna by row mean:
# title                    0.000000
# puNumber                 0.000000
# show_start_date          0.000000
# type                     0.000000
# film_studio              0.002404
# production_country       0.000267
# director                 0.001202
# producer                 0.075875
# age_restriction          0.000000
# refundable_support       0.955651
# nonrefundable_support    0.955651
# budget                   0.955651
# financing_source         0.955651
# ratings                  0.129174
# genres                   0.130377
# dtype: float64
# ------------------------------
# Data clear duplicates sum:
# title                    0.000000
# puNumber                 0.000000
# show_start_date          0.000000
# type                     0.000000
# film_studio              0.002404
# production_country       0.000267
# director                 0.001202
# producer                 0.075875
# age_restriction          0.000000
# refundable_support       0.955651
# nonrefundable_support    0.955651
# budget                   0.955651
# financing_source         0.955651
# ratings                  0.129174
# genres                   0.130377
# dtype: float64
# ------------------------------

# %%
# функция для вывода уникальные значения для столбца
def unique_values(column):
    print(column.name)
    print(column.unique())
    print('-'*30)

# %%
# взглянем на уникальные значения по всех столбцах
for column in df_movies.columns:
    unique_values(df_movies[column])
# Out:
# title
# ['Открытый простор' 'Особо важное задание' 'Особо опасен' ...
#  'Щенячий патруль: Скорей спешим на помощь!'
#  'Машины песенки. Серия "Испанские мотивы"'
#  'Машины песенки. Серия "Когда цветут кактусы"']
# ------------------------------
# puNumber
# ['221048915' '111013716' '221038416' ... '124010819' '124010619'
#  '124010719']
# ------------------------------
# show_start_date
# ['2015-11-27T12:00:00.000Z' '2016-09-13T12:00:00.000Z'
#  '2016-10-10T12:00:00.000Z' ... '2019-12-24T12:00:00.000Z'
#  '2019-12-28T12:00:00.000Z' '2019-12-30T12:00:00.000Z']
# ------------------------------
# type
# ['Художественный' 'Анимационный' 'Прочие' 'Документальный'
#  'Научно-популярный' ' Художественный' ' Анимационный'
#  'Музыкально-развлекательный']
# ------------------------------
# film_studio
# ['Тачстоун Пикчерз, Кобальт Пикчерз, Бикон Пикчерз, Тиг Продакшнз'
#  'Киностудия "Мосфильм"'
#  'Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Платт Продакшнз, Рилейтивити Медиа, Спайгласс Интертейнмент, Стилкин Филмз, Топ Кау Продакшнз'
#  ...
#  'Дэниел Гродник Продакшнз, Вандерфилм Медиа Корпорэйшн, Импринт Интертейнмент, Вор Хорс Интертейнмент, Пимиента '
#  'Никелодеон Анимейшн Студиос, Спин Мастер'
#  'Анимаккорд Лтд., ООО Студия "АНИМАККОРД"']
# ------------------------------
# production_country
# ['США' 'СССР' 'Франция' 'СССР, Венгрия' 'Германия-Великобритания'
#  'Великобритания - Италия' 'Чехословакия' 'США - Франция - Турция'
#  'Новая Зеландия' 'Канада - Франция - Испания' 'США-Германия'
#  'США - Великобритания' 'Великобритания' 'США - Германия'
#  'Франция - Мексика - США' 'Россия, Казахстан, США' 'СССР, Швеция'
#  'СССР, Франция, Англия, Куба, ГДР' 'Германия'
#  'Великобритания-США-Германия-КНР' 'СССР, ЧССР, Западный Берлин, ПНР'
#  'СССР, Италия' 'Гонконг, КНР' 'США - Франция'
#  'США - Япония - Франция - Великобритания'
#  'Гонконг - Сингапур - Таиланд - Великобритания' 'США-Канада'
#  'Франция - Италия - Великобритания - США' 'Франция - США'
#  'Ирландия-Великобритания-Германия' 'Чехия' 'США-Австралия'
#  'СССР, Финляндия' 'США-Франция-Великобритания-Австрия' 'США - Бельгия'
#  'США - Ирландия - Великобритания' 'Великобритания - США'
#  'Люксембург - Нидерланды - Испания - Великобритания - США - Италия'
#  'Великобритания - Франция - США' 'Новая Зеландия - США'
#  'США - Великобритания - Чехия' 'Канада - Франция - Великобритания'
#  'Ирландия' 'Великобритания - Германия - США'
#  'США - Франция - Великобритания' 'Япония' 'СССР, Польша'
#  'Франция - Испания' 'Канада-Франция' 'Германия - Италия - США'
#  'Аргентина - Бразилия' 'Дания - Швейцария - Бельгия - Франция'
#  'США - Испания' 'Германия - США'
#  'Франция - Австрия - Германия - Италия - США' 'Австрия'
#  'США - Канада - Германия' 'США - Канада' 'СССР - Швейцария - Франция'
#  'Россия - Казахстан' 'Гонконг' 'Италия' 'США - ОАЭ' 'Россия'
#  'США - Франция - Испания - Великобритания' 'Великобритания - Франция'
#  'США-Италия-Испания-Аргентина' 'Франция-Великобритания' 'КНР - Гонконг'
#  'Франция - Италия - Швейцария' 'США - Новая Зеландия' 'Франция - Бельгия'
#  'КНР' 'Германия - Великобритания - Австрия'
#  'Великобритания - Израиль - Франция - Япония - США' 'Швеция' 'Испания'
#  'Дания' 'Франция - Бельгия - Люксембург' 'США - Индия - ОАЭ'
#  'Германия-Канада-Великобритания-Швейцария-Франция' 'Мексика - Чили'
#  'Аргентина' 'Бразилия' 'Чили' 'Австралия' 'Португалия - Франция'
#  'США - ЮАР' 'Исландия-Ирландия-Германия' 'США-Индонезия' 'Южная Корея'
#  'Мексика - Испания - Дания - США' 'Великобритания-США' 'Франция - Италия'
#  'США-Франция' 'США - Венгрия - Великобритания' 'Бельгия-Франция-Италия'
#  'Чехия - Германия' 'Германия - Франция' 'США-Нидерланды' 'Украина'
#  'Великобритания - Германия' 'Франция-Бельгия' 'США-Франция-Испания'
#  'Италия - Франция' 'Канада' 'Швеция-Франция-Дания'
#  'Германия-Франция-Польша' 'Франция-Великобритания - Германия'
#  'США - Бразилия - Франция - Австралия - Великобритания - Германия'
#  'Германия-Австрия' 'Германия-Италия- Шри-Ланка'
#  'Великобритания - Испания' 'США - Великобритания - Канада - Швеция'
#  'Босния и Герцеговина - Франция - Великобритания - Германия - Словения - Бельгия - Сербия'
#  'Великобритания - Франция - Италия - США' 'США-ОАЭ' 'Испания - Франция'
#  'США-Великобритания' 'США-ЮАР' 'Великобритания-Австралия - США'
#  'Норвегия - Швеция - Дания - Германия' 'Норвегия' 'Швейцария'
#  'Греция - Германия - Франция' 'Норвения' 'Южная Корея - США'
#  'Чили - Франция - США' 'Австрия - Германия - Франция' 'Швеция - Дания'
#  'Великобритания - Франция - Бельгия - Италия' 'Франция - Германия'
#  'Грузия - Франция - Люксембург'
#  'США - Франция - Великобритания - Бразилия ' 'США - КНР'
#  'Мексика - Франция' 'США - Германия - Гонконг - Сингапур'
#  'Финляндия - Австрия - Россия' 'Испания - Куба' 'Великобритания - ЮАР'
#  'Великобритания - Ирландия' 'Израиль'
#  'Бразилия - Германия - Порртугалия - Франция '
#  'Франция - Канада - Бельгия' 'Франция-Испания'
#  'Испания - Канада - Япония' 'Иран' 'Швеция-Куба'
#  'США-Великобритания-Ирландия' 'Гонконг - КНР' 'Нидерланды'
#  'Испания - Канада' 'Япония-Великобритания'
#  'Великобритания - Норвегия - Дания - Германия'
#  'Финляндия - Франция - Германия'
#  'Мексика - Франция - Нидерланды - Германия' 'США - Индия'
#  'США-Великобритания-Индия' 'США-Канада-Бельгия' 'Республика Узбекистан'
#  'Италия ' 'Турция'
#  'Сербия - Словения - Хорватия - Черногория - Македония' 'Киргизия'
#  'Германия - Нидерланды - Беларусь - Россия - Латвия' 'Индия'
#  'Нидерланды - Россия - Германия'
#  'Великобритания - Нидерланды - Франция - Хорватия' 'Канада - Южная Корея'
#  'Великобритания - Польша - КНР - Индия - Норвегия'
#  'Япония - Франция - США - Южная Корея - Турция'
#  'Мексика - Аргентина - Великобритания' 'Израиль - Франция'
#  'Польша - Португалия - Франция - Великобритания' 'Австралия - США'
#  'США - Великобритания ' 'Франция - Люксембург - Бельгия' 'Армения'
#  'Бельгия - Люксембург - Франция - Швейцария'
#  'США - Великобритания - Канада' 'Норвегия - Швеция' 'Канада - Франция'
#  'КНР - Гонконг - США' 'США - Сингапур - Малайзия - Индонезия'
#  'Германия - Россия' 'Япония - Канада'
#  'Финляндия - Дания - Германия - Ирландия'
#  'Франция - Люксембург - Германия - Бельгия - Швейцария - Великобритания '
#  'Канада - США' 'США-Италия-Испания' 'США-Испания'
#  'США - Швейцария - Франция' 'Испания - США - Колумбия' 'Канада-ЮАР'
#  'Франция - Россия' 'Германия - Финляндия - Австралия' 'Дания - Швеция'
#  'Бельгия' 'Германия - Франция - Австрия' 'Франция-Индия' 'ЮАР'
#  'Франция-Перу' 'Франция - Канада' 'Республика Беларусь'
#  'Великобритания - Австрия - Франция - США' 'Австрия-Германия-Франция'
#  'США-Россия' 'Германия-США' 'США - Южная Корея' 'Канада - КНР'
#  'Дания - Швеция - Италия - Франция - Германия'
#  'Франция-Италия-Испания-Венгрия' 'Франция - Германия - Бельгия'
#  'Франция-Великобритания-Чехия' 'Румыния - Франция - Бельгия'
#  'Болгария - Франция - Изриль'
#  'Израиль - Германия - Польша - Бельгия - Франция - Люксембург'
#  'Россия, Германия, Франция, Бельгия' 'Индонезия' 'Франция - Португалия'
#  'Великобритания - Пуэрто-Рико' 'СССР, ФРГ, Западный Берлин'
#  'Россия, Республика Беларусь' 'США, Великобритания' 'Франция - Австрия'
#  'Бельгия-Нидерланды' 'Великобритания - США - Индия'
#  'США - Великобритания - Австралия'
#  'Канада - Франция - США - ОАЭ - Великобритания'
#  'США - Австралия - Франция'
#  'Дания-Франция-Бельгия-Германия-Великобритания' 'Испания - Аргентина'
#  'Исландия - Финляндия' 'Россия-Польша-Голландия-Словакия'
#  'Дания - Германия - Швеция' 'Южная Корея - США - Канада' 'Таиланд'
#  'США-Мальта' 'США -Германия'
#  'Великобритания - Германия - Франция - Кипр - США' 'Мексика'
#  'США - Великобритания - Ирландия' 'США - Украина'
#  'США - Финляндия - Испания - Великобритания - Франция'
#  'Австралия-Великобритания'
#  'США - Канада - Афганистан - Бельгия - Франция'
#  'США - Великобритания - Германия - Новая Зеландия - Бельгия - Франция'
#  'Франция-Канада'
#  'Ирландия - Финляндия - Бельгия - Великобритания - США - Швейцария'
#  'Малайзия - США' 'Германия - Италия' 'США - Франция - Бельгия - Италия'
#  'Франция - Ирландия - Швеция' 'Азербайджан-Россия'
#  'Великобритания - Италия - Швейцария' 'США - Германия - Великобритания'
#  'Германия - Бельгия - США -Франция' 'США-Китай' 'Чили - Испания'
#  'Франция - Швейцария' 'Канада - Испания' 'США - Румыния - Великобритания'
#  'США - Япония' 'США - Россия - Франция' 'Франция-США' 'Парагвай'
#  'Германия - Канада' 'США - Канада - Великобритания' 'Финляндия - Канада'
#  'Уругвай-Мексика-Германия ' 'США - Чили'
#  'Германия - Аргентина - Нидерланды - Чили' 'США - Канада - Индонезия'
#  'Армения - Казахстан' 'Финляндия' 'Испания - Италия - Франция'
#  'Бельгия - Испания - Канада - Нидерланды'
#  'Великобритания - Франция - Швеция - Бельгия'
#  'Мексика - Эквадор - Канада - США - Франция - Малайзия - Италия - Аргентина - Германия - Индия  '
#  'Франция - Бенльгия' 'Индия - Великобритания'
#  'Япония - Великобритания - Франция' 'Испания - Уругвай - Аргентина'
#  'Франция - Италия - Бельгия - Люксембург'
#  'Франция - Украина - Грузия - Армения' 'Сербия - Германия - Венгрия'
#  'Франция-Польша' 'Франция ' 'Румыния-США' 'Россия-Азербайджан'
#  'США - Нидерланды - Бельгия - Венгрия - Греция - Канада'
#  'Германия - Франция - Люксембург' 'США - Россия'
#  'Великобритания - США - Франция' 'США - Австралия - Дания'
#  'Бельгия-Франция' 'США-Мексика'
#  'Норвегия - Азербайджан - Россия - Колумбия - Великобритания - Венгрия - Румыния - Франция - Грузия'
#  'СЩА' 'Бразилия - Испания' 'Россия, Франция, Латвия'
#  'Нидерланды - США - Германия - Канада - Франция - Ирландия - Великобритания'
#  'Уругвай - Колумбия' 'США - Испания - Болгария' 'Армения - Германия'
#  'США - Великобритания- Франция - Швеция' 'США - Мексика'
#  'Австралия-Турция-США' 'Швеция - Германия' 'Польша - Италия - Россия'
#  'Франция - Бразилия' 'США - Канада - КНР' 'СССР, Венгрия, ЧССР, ГДР'
#  'Бельгия - Германия - Люксембург' 'СССР  ' 'СССР ' ' СССР '
#  'США - Австралия' 'Бразилия - США' 'США - Великобритания - Канада - КНР'
#  'Франция - Чили'
#  'Франция - США - Великобритания - Колумбия - Бельгия - Россия'
#  'Дания - Великобритания - ЮАР' 'СССР   ' 'Россия-США-Канада-Люксембург'
#  'Россия - Республика Кипр' 'Германия - США - Швеция - Франция'
#  'Великобритания-Германия-Канада-ЮАР' ' СССР   ' 'СССР     '
#  'Ирландия, Канада'
#  'Япония - Великобритания - Швейцария - Ирландия - Дания - Франция - Польша - Австралия - Канада  '
#  'Великобритания, Канада' 'Бельгия - США' 'Великобритания - США - Россия'
#  'Россия-Украина' 'Германия - США - Великобритания - Израиль'
#  'Канада - Германия' 'США- Ю.Корея' 'Индия - Мексика'
#  'Великобритания - Франция - Республика Кипр - Швейцария - США - Сербия'
#  'Испания - Аргентина - Индия - США'
#  'Норвегия - Исландия - США - Великобритания '
#  'Турция - Германя - Франция' 'Германия - Великобритания'
#  'Австралия - Германия' 'Мексика - Испания'
#  'Великобритания - США - Германия - Бельгия' 'США - Чехия - Франция'
#  'Россия - Италия' 'Франция-Россия' 'Норвегия - Дания - Швеция'
#  'Франция - Швейцария - Германия' 'Грузия - Украина'
#  'Россия - Эстония - Финляндия - Беларусь' 'США - Франция - ЮАР'
#  'Великобритания - США - Швейцария' 'Канада-США'
#  'Мексика - Нидерланды - Германия - Франция' 'США - Испания - Франция'
#  'США - Великобритания - КНР' 'США-Франция-Канада'
#  'Япония, Великобритания, Австрия, Германия, Ю.Корея'
#  'Великобритания - Ирландия - США' 'Бельгия - Италия - Франция '
#  'Швейцария-Германия-ЮАР' 'Великобритания - США - Германия'
#  'Германия - Исландия' 'Испания - США' 'СССР    ' 'Хорватия'
#  'Финляндия - Исландия - Швеция' 'Канада - США - Германия - Франция'
#  'США - Великобритания - Испания' 'Ирландия-Великобритания'
#  'Аргентина - Испания' 'Австрия - Германия' ' СССР'
#  'Германия - Швейцария - Франция - Южная Корея - США'
#  'Украина - Нидерланды' 'Венгрия - Германия - Швеция'
#  'Германия - Франция -  Польша - Турция - Канада - Италия - Россия '
#  'СССР, Афганистан' 'СССР, Монголия' 'Россия-Кипр'
#  'Россия, Грузия, Испания'
#  'Великобритания - Нидерланды - Германия - Франция - Бельгия - Австрия '
#  'Испания - Великобритания - Франция' 'Дания - Норвегия - Великобритания'
#  'Бельгия - Франция - Люксембург'
#  'Италия - Франция - Швейцария - Великобритания'
#  'Франция - Бельгия - Великобритания - Испания - Германия - США'
#  'Швейцария - Израиль - Франция - Великобритания'
#  'Великобритания - США - Канада - Нидерланды - Франция' 'Россия, Италия'
#  'СССР, Албания' 'Россия, Украина, Республика Беларусь, Литва'
#  'Финляндия - Великобритания - Германия' 'Россия, Украина, Польша'
#  'Франция - Италия - Бельгия - КНР'
#  'Германия - Бельгия - Люксембург - Ирландия' 'КНР - Сингапур'
#  'Франция - Бельгия - Великобритания - США - Нидерланды - Канада'
#  'США - Россия - Польша - Германия - Пуэрто Рико'
#  'Франция - Бельгия - Канада' 'США ' 'Мексика - США'
#  'США - Гонконг - КНР ' 'Греция - Россия'
#  'Ирландия - Дания - Бельгия - Люксембург - Франция' 'Эстония - Россия'
#  'Великобритания - Исландия - Испания - Швейцария - США'
#  'Австралия - Великобритания - Бельгия - Индия'
#  'Швеция - Германия - Франция - Норвегия'
#  'Нидерланды - Бельгия - Германия - Ирландия'
#  'Нидерланды - Великобритания - Бельгия' 'США - Колумбия - Испания'
#  'Франция-Испания-Бельгия-Панама' 'США-Великобритания-Чехия-Румыния'
#  'Аргентина - Уругвай - Россия - Германия - Франция - Нидерланды'
#  'Швеция - Франция - Норвегия - Дания' 'Италия-Франция-Великобритания'
#  'Великобритания, Франция' 'Австралия, США' 'Венесуэла'
#  'Великобритания - США - Австралия - Ирландия - Германия - Куба - Канада'
#  'Южная Корея - КНР' 'Аргентина - Мексика - Бразилия - Франция - США'
#  'Швеция - США' 'Франция - Германия - Турция - Катар' 'Франция-Китай'
#  'Россия, Германия, Великобритания' 'Великобритания - Италия - Испания'
#  'Италия - Россия' 'Япония - КНР - Южная Корея' 'Россия, Германия'
#  'Россия-Ирландия' 'Македония - Франция - Великобритания'
#  'Франция - Бразилия - Италия' 'Россия-США' 'Армения-Россия'
#  'Россия, Румыния' 'Франция -  Бельгия' 'Грузия-Франция' 'ЮАР - США'
#  'Великобритания-США-Франция'
#  'Великобритания - США - Германия - Канада - Австралия' 'США-Ирландия'
#  'Россия, Республика Кипр' 'Германия - Люксембург - Франция'
#  'Россия-Франция' 'США - Нидерланды - Финляндия - Великобритания - Италия'
#  'Республика Кипр' 'Венгрия' 'Франция - США - Норвегия - Дания'
#  'Германия - Австрия - Ирландия' 'США - Финляндия' 'Италия-Великобритания'
#  'Россия, Испания' 'США - Великобритания - Болгария'
#  'Великобритания - Люксембург' 'Индия - США'
#  'США - Канада - Россия - Франция - Чили - Ирландия' 'Грузия-Россия'
#  'Дания - Австрия - Ирландия - Финляндия - Норвегия - Швеция - Нидерланды'
#  'США-КНР' 'Грузия' 'Австралия - Ирландия' 'Великобритания - Канада'
#  'Италия - Аргентина - Словения '
#  'Испания - Франция - Нидерланды - Германия - Бельгия - Великобритания - Канада'
#  'Франция - Чехия - Бельгия' 'Великобритания - Франция - Германия - США'
#  'Ирландия - Великобритания - Франция - США - Германия - Нидерланды'
#  'США - Канада - Япония - КНР' 'Италия-Франция'
#  'США - Великобритания - Исландия' 'Великобритания-Франция'
#  'Франция - Германия - Нидерланды' 'Иран '
#  'Франция - Германия - Швеция - США - Чехия - Словакия - Великобритания - Нидерланды'
#  'Франция - Канада - Н.Зеландия - США - Нидерланды - Германия - Швеция - Россия'
#  'Турция - США'
#  'Великобритания - США - Канада - Бельгия - Нидерланды - Австрия - Германия'
#  'Израиль - Франция - Германия - Палестина - США - Австрия - Великобритания'
#  'Аргентина - Франция - Испания' 'СССР, Россия'
#  'Великобритания - Франция - Италия - Индия - Дания - КНР - Бангладеш - Камбоджа - Гаити - Уганда'
#  'Италия - Франция - Швейцария' 'Ирландия - Великобритания - Канада'
#  'Перу' 'США - Норвегия' 'Испания-Канада' 'Китай-Гонконг'
#  'США - Германия - КНР' 'Великобритания - Новая Зеландия'
#  'Франция - Дания - Швеция - КНР'
#  'США - Великобритания - Германия - Бельгия - Дания'
#  'США - Франция - Канада - Германия - Австралия - Индия' nan
#  'СССР, Румыния, Франция' 'СССР, ГДР' 'Австралия-Ирландия' 'США - Китай'
#  'Великобритания - Франция - Австрия - Швеция' 'Россия, Таджикистан'
#  'Нидерланды - Бельгия - Болгария' 'Великобритания - Канада - США'
#  'Франция - Бельгия - Испания' 'Китай-Гонконг-США'
#  'Франция - Великобритания' 'США - Вьетнам' 'США - Германия - Франция'
#  'Германия - Франция - Бельгия' 'США - Италия'
#  'Германия - Дания - Испания - Швеция - Канада - Эстония - Франция'
#  'Княжество Андорра - Украина' 'Германия - Люксембург - Бельгия'
#  'Великобритания - Россия - Украина - США'
#  'Германия - Бельгия - Люксембург - Норвегия'
#  'США - Австралия - Новая Зеландия - Великобритания'
#  'США - Франция - Канада - Великобритания' 'Испания-Колумбия'
#  'Великобритания - Чехия - Франция' 'Россия, Украина' 'Исландия'
#  'Великобритания - Франция - Венгрия' 'Россия, Франция, Германия, Бельгия'
#  'Франция - Македония'
#  'Нидерланды - Франция - Германия - Бельгия - Швеция - Великобритания'
#  'Испания - США - Великобритания - Канада' 'Германия - Австрия'
#  'Республика Казахстан' 'Франция - Испания - Дания - Венгрия - Швейцария'
#  'Франция-КНР' 'США - Пуэрто-Рико - Франция ' 'Мексика - Тайвань - США'
#  'Великобритания - Испания - Непал - Индия - Венгрия - Гонконг - Германия - Дания - Бахрейн'
#  'Великобритания - Аргентина - США - Франция - Россия - Испания'
#  'КНР - США' 'Италия - США' 'Финляндия - Швеция - Германия'
#  'Канада- Испания' 'Франция - Бельгия - Чехия' 'Франция-Бельгия-Канада'
#  'Франция - Германия - США' 'США - Дания' 'Индия - КНР'
#  'Чехия-Великобритания-США' 'США-ФРГ-Россия'
#  'Ирландия-Нидерланды-Франция-США-Великобритания'
#  'Россия, Грузия, Хорватия, Испания' 'Финляндия - Швеция - Норвегия'
#  'Сербия - Великобритания - США'
#  'США - Великобритания - Франция - Гонконг' 'Швейцария - Франция'
#  'Швейцария - Великобритания' 'ОАЭ - США'
#  'США - Франция - Германия - Канада - Австралия ' 'Германия - Австралия'
#  'Иран, Франция' 'США - Великобритания - Новая Зеландия' 'США-Колумбия'
#  'США-Франция-Ирландия' 'Великобритания - Франция - Бельгия'
#  'США - Великобритания - Япония' 'США - Франция - Германия'
#  'Польша - Ирландия' 'Ирландия - Великобритания - Франция - США'
#  'США - Бельгия - Великобритания' 'СССР, ВНР'
#  'Испания - Франция - США - Великобритания - Бельгия'
#  'Франция - Дания - США' 'США - Гонконг' 'Бразилия - К;анада'
#  'Франция-Германия' 'США - Колумбия'
#  'США - Ирландия - Великобритания - Франция'
#  'Великобритания - США - Канада' 'Польша - Франция'
#  'Канада - США - Нидерланды - Великобритания - Аргентина'
#  'Великобритания - Дания' 'Франция - Бельгия - Япония' 'Россия,  Испания'
#  'Франция -Бельгия' 'США - Канада - Германия - Франция'
#  'США-Канада-Франция' 'Россия - Германия' 'Россия-Италия'
#  'Китай - Гонконг' 'Германия-Австрия-Франция-Италия' 'США-Япония'
#  'США - Германия - Канада' 'Испания-Мексика'
#  'США - Япония - Канада - Великобритания - Германия - Франция'
#  'США -Великобритания - Австралия' 'Россия-Украина-Германия'
#  'Израиль - Франция - Великобритания - Германия' 'Корея'
#  'Россия - Болгария' 'США-Индия' 'Германия-Канада-Франция-Бельгия'
#  'Германия-Кения' 'Франция - Монако' 'Франция-Испания-Швейцария'
#  'Австрия-Франция-Германия' 'Румыния' 'США-Великобритания-Франция'
#  'Канада-Великобритания' 'Канада-Бразилия-Япония'
#  'Германия - Дания - Норвегия' 'Дания - Германия' 'СССР - Италия'
#  'СССР - ГДР - Польша - Италия' 'США - Испания - Франция - Великобритания'
#  'Китай' 'Мексика-Аргентина'
#  'Германия - Великобритания - Италия - Испания'
#  'Франция-Германия-Великобритания' 'Россия - Германия - Швейцария'
#  'Франция-Австралия' 'Голландия' 'Швейцария-Франция' 'Россия-Белоруссия'
#  'Франция - Испания - Тайвань' 'США-Южная Корея-Новая Зеландия'
#  'Великобритания-Венгрия' 'Россия-Германия'
#  'Великобритания-Франция-Германия' 'Франция-Германия-Италия'
#  'Швеция-Финляндия-Франция-Норвегия' 'Франция-Италия' 'Германия-Израиль'
#  'Швеция - Германия - Дания - Норвегия' 'США-Бельгия'
#  'Франция-Гонконг-Ирландия' 'Эстония' 'Литва-Россия-Украина'
#  'Германия - Италия - Франция' 'Великобритания - Австрия - Германия'
#  'Бельгия - Франция' 'Россия-Казахстан' 'Испания - Мальта'
#  'Франция-Россия-Румыния-Италия-Бельгия' 'Россия - Польша'
#  'Испания - Мексика' 'США-Аргентина' 'Великобритания '
#  'Израиль-США-Франция' 'США - Новая Зеландия - Япония'
#  'Франция - Чехия - Великобритания' 'Россия-Польша'
#  'Германия-Франция-Великобритания' 'США-Германия-Канада'
#  'США-Гонконг-Китай' 'США - Великобритания - Германия'
#  'США-Канада-Австралия' 'Япония-США-Франция' 'Франция-Испания-Германия'
#  'США - Хорватия - Босния-Герцеговина'
#  'Великобритания - Чехия - Франция - Италия' 'США - Германия - Нидерланды'
#  'Германия - Франция - Канада'
#  'Франция-Грузия-Германия-Россия-Украина-Бельгия'
#  'Великобритания - Франция - Италия' 'Россия - США'
#  'Франция - Италия - Иран' 'Россия - Азербайджан' 'Греция' 'Дания - США'
#  'США-Великобритания-Новая Зеландия' 'США-Германия-Австралия'
#  'США-Канада-Италия' 'США - Япония - Германия' 'Австралия-США'
#  'Франция - Великобритания - Багамские острова - США'
#  'Швейцария - Люксембург' 'Швейцария - Австрия' 'Германия - Швейцария'
#  'Дания-Швеция-Франция-Германия' 'Польша' 'Швейцария-Австрия'
#  'Бразилия - Канада - США' 'Нидерланды - Россия' 'Португалия'
#  'Франция-Аргентина' 'Швеция-Франция' 'Франция-Украина'
#  'Германия-Украина-Нидерланды' 'Италия-Швейцария'
#  'США-Германия-Великобритания' 'Латвия - Россия'
#  'Германия-Франция-Великобритания-США' 'Канада - Италия'
#  'США - Объединенные Арабские Эмираты' 'США-Венгрия' 'Малайзия'
#  'Россия - Германия - Украина' 'США - Австралия - Мексика'
#  'Литва - Венгрия' 'Германия - Китай' 'Казахстан' 'Республика Корея'
#  'США - Германия - Франция - Великобритания - Канада '
#  'Бельгия - Германия - Люксембург - Франция' 'Франция - Греция'
#  'Италия - Канада' 'США - Великобритания - Франция' 'США-Италия-Греция'
#  'Германия - США - Великобритания - Ирландия'
#  'Великобритания - Франция - Германия' 'Германия - Нидерланды - ЮАР'
#  'США-Япония-Германия-Великобритания-Нидерланды'
#  'США-Япония-Германия-Великобритания' 'Германия - Франция - Польша'
#  'Таиланд-Великобритания-Франция-Германия-Испания-Нидерланды'
#  'Германия-Италия-Швейцария'
#  'Дания - Швеция - Великобритания - Франция - Германия - Нидерланды - Норвегия - Финляндия'
#  'Франция - Великобритания - Нидерланды - Люксембург'
#  'Нидерланды-Великобритания-Франция-Италия-Япония'
#  'Финляндия-Дания-Германия-Ирландия' 'Испания-Аргентина'
#  'Великобритания - Нидерланды - Франция - США' 'Канада - Мексика'
#  'США, Франция' 'Канада-Южная Корея-США'
#  'Великобритания - Франция - Бельгия - США' 'КНР - Канада - США'
#  'Италия - Франция - Германия' 'Швеция - Германия - Франция - Дания'
#  'Франция - США - Бельгия' 'Украина - Германия - Латвия - Эстония'
#  'Австрия - Люксембург' 'Великобритания - КНР' 'Монголия'
#  'Франция - Дания' 'Швеция - Дания - Финляндия'
#  'Сингапур - Великобритания - Индонезия - Канада - США'
#  'США - Германия - Япония' 'Таиланд - США' 'Франция - Нидерланды'
#  'Великобритания - Румыния' 'США - Мальта'
#  'Великобритания - Германия - Нидерланды - Дания'
#  'Франция - Германия - Литва - Нидерланды - Россия' 'США - ЮАР - Гонконг'
#  'Австралия - Колумбия' 'Великобритания - Польша'
#  'США - Великобритания - Швеция' 'Франция - Швеция - Дания - Норвегия'
#  'Болгария - США' 'СССР, ФРГ' 'Бельгия - Нидерланды - Франция'
#  'Финляндия - Германия' 'Болгария'
#  'Грузия - Россия - Украина - Хорватия - Германия' 'Франция - Люксембург'
#  'Франция - Германия - Австрия' 'Норвегия - США' 'Германия-Швеция'
#  'Франция - Германия - Италия' 'Франция-Германия-Австрия' 'КНР-США'
#  'Великобритания - Ирландия - США ' 'Дания - Латвия - Россия - США'
#  'Финляндия - Польша' 'Германия - Бельгия'
#  'Германия - США - Франция - Испания'
#  'Бельгия-Германия-Канада-Франция-США-Великобритания'
#  'Нидерланды - Бельгия - Люксембург' 'Канада-Германия'
#  'Люксембург - Бельгия - Франция' 'США-Великобритания-Австралия'
#  'Великобритания, Новая Зеландия' 'Бельгия, Великобритания, США'
#  'Великобритания, Австралия' 'Исландия, Бельгия'
#  'Испания - Швейцария - Великобритания - Германия - Новая Зеландия - Нидерланды - Канада'
#  'Франция, Бельгия' 'Великобритания, США' 'Киргизия-Россия'
#  'Германия, США' 'Великобритания, США, Испания'
#  'Италия - Швейцария - Германия' 'Россия, Армения' 'Франция, Германия'
#  'Китай, Канада, США' 'Германия, Австралия' 'КНР, США'
#  'США, Великобритания, Люксембург' 'Испания, Ирландия, Бельгия, Франция'
#  'Великобритания - Гонконг - Венгрия - США - Ирландия' 'США - Пуэрто Рико'
#  'Аргентина - Испания - Уругвай'
#  'Израиль - Германия - Франция - Швейцария'
#  'Великобритания - Мексика - США' 'Испания - Болгария - США'
#  'Россия-Словакия-Чехия'
#  'Швейцария - КНР - США - Россия - Республика Корея - Великобритания'
#  'Россия, Нидерланды, Финляндия'
#  'Испания - Бельгия - Франция - Португалия - Великобритания'
#  'Бразилия - Португалия - Франция' 'Швеция - Норвегия'
#  'Франция - Польша - Бельгия' 'CША' 'Китай, США'
#  'Италия, Франция, Германия' 'Германия - Австрия - Франция'
#  'Чехия - Словакия - Хорватия' 'Россия, Польша, Финляндия'
#  'Россия, Латвия, Чешская Республика'
#  'Франция - Великобритания - Камбоджа - США - КНР' 'Чехия - Испания - США'
#  'Германия - Люксембург - Дания' 'Великобритания - Испания - Германия'
#  'Дания - Исландия' 'Германия, Франция, Великобритания'
#  'Великобритания - Испания - Италия - Латвия - Франция - Эстония'
#  'Дания, Швеция, Великобритания, Франция, Германия, Норвегия, Финляндия, Нидерланды, Италия'
#  'Польша - Франция - Великобритания' 'Дания, Норвегия, Венгрия, Чехия'
#  'Дания - Франция - Германия - Швеция' 'Великобритания, Швеция, США'
#  'Канада, Франция, Италия, Швейцария, США' 'США, Индия'
#  'США - Великобритания - Германия - - Швеция - Канада' 'Италия, Франция'
#  'Республика Беларусь, Германия, США, Россия'
#  'Италия-Швейцария-Франция-Германия '
#  'Россия - Франция - Великобритания - Латвия' 'Россия-Беларусь'
#  'Франция - Испания - Румыния - США - Бельгия' 'Италия-США'
#  'Россия, Австрия' 'Ирландия - Великобритания - США'
#  'Швейцария, Великобритания, Франция, США, Ирландия'
#  'Мексика, Франция, Германия, Дания, Швеция' 'Нидерланды, Бельгия'
#  'Швеция, Норвегия, Финляндия, Франция' 'Испания, Франция, Италия'
#  'Испания-Франция-Греция-Индия-США-Россия-Великобритания'
#  'Великобритания - Япония - США' 'Дания, Канада, Норвегия, Австралия, США'
#  'Аргентина, Испания' 'Россия, Германия, Казахстан, Польша, Китай'
#  'Португалия, Франция, Польша, США' 'США - Канада - Аргентина' 'Ливан-США'
#  'Япония - США' 'США, Гонконг '
#  'Франция - Россия - Швейцария - Румыния - Венгрия' 'Аргентина-Испания'
#  'Россия, Сербия' 'США - Болгария - Мексика'
#  'США - Великобритания - Швейцария - Франция' 'Таиланд - КНР - США'
#  'Великобритания, Нидерланды, Польша, Швейцария, Франция' 'Ирландия - США'
#  'Германия - Франция - Великобритания - Польша - США'
#  'Великобритания-Франция-Италия' 'США - Австралия - Индия' 'Франция - КНР'
#  'Великобритания - Израиль' 'Великобритания - Норвегия - Кения - Хорватия'
#  'США - Бразилия - Великобритания - Канада' 'Германия, Бельгия'
#  'Австралия, Канада' 'США, Великобритания, Франция' 'Кения, Германия'
#  'Нидерланды, Бельгия, Люксембург' 'Колумбия' 'Латвия - Франция'
#  'Ирландия, Великобритания' 'Франция - Израиль - Германия'
#  'Швеция, Франция, Великобритания' 'Бельгия - Люксембург'
#  'Германия - Бельгия - Великобритания'
#  'Испания, Франция, Великобритания, Дания, Бельгия, Германия'
#  'Румыния, ЮАР, Иран, Франция, Канада, Великобритания' 'Германия, Франция'
#  'США, Япония' 'США, Великобритания, Ирландия, Люксембург'
#  'Республика Армения' 'США, Франция, Япония' 'Япония, США' 'Канада, США'
#  'Республика Кипр - Россия'
#  'Дания - Франция - Италия - Бельгия - Нидерланды' 'Россия - Грузия'
#  'Италия, Германия' 'Норвегия, Швеция, Дания' 'Республика Кипр, Россия'
#  'КНР, Индия, Гонконг, США' 'Израиль, Украина' 'США, Россия'
#  'США - КНР - Индия - Ю.Корея' 'США - Швеция' 'Франция, Канада'
#  'Россия-Китай' 'Канада, Великобритания' 'США, Германия'
#  'Канада, США, Каймановы острова'
#  'Бразилия, Уругвай, Дания, Норвегия, Чили, Швеция'
#  'Пуэрто-Рико, Великобритания, США' 'Уругвай - Аргентина - Испания'
#  'США - Великобритания - Италия - Израиль - Сербия - Индия'
#  'США - Канада - Франция - Индия' 'Великобритания - Россия - КНР'
#  'Франция, Новая Зеландия' 'Франция, Люксембург, Бельгия'
#  'Канада, США, Норвегия' 'Италия, Испания'
#  'Испания - Германия - Нидерланды' 'Бразилия - США - КНР '
#  'Великобритания, Германия, Дания, США' '2019'
#  'Италия - Фрация - Бразилия - Германия' 'Норвегия - Швеция - Россия'
#  'Великобритания, Япония, США' 'Сша, Канада' 'Бельгия, Канада'
#  'Великобритания - Австралия - США' 'США, Канада' 'КНР - США '
#  'Франция - Финляндия' 'Колумбия - США' 'Великобритания, Франция, Бельгия'
#  'Норвегия - Нидерланды' 'Великобритания, Канада, США'
#  'Япония, Великобритания' 'Италия - Бельгия - Франция'
#  'Россия, Бельгия, Финляндия' 'США, Украина' 'Франция, Норвегия'
#  'Великобритания, Южная Корея, Канада, США, Индия, Китай, Япония'
#  'Канада - Норвегия' 'Республика Кипр-Россия' 'Германия, Россия'
#  'Польша - Франция - Испания - Бразилия - Швеция'
#  'Австрия, Великобритания, Германия' 'Франция - Сенегал - Бельгия'
#  'Франция, Бельгия, Люксембург' 'Финляндия, Латвия' 'Пакистан'
#  'Германия, Франция, США' 'Германия - Великобритания - США'
#  'КНР - Франция' 'Дания, Норвегия, Швеция, Исландия'
#  'Республика Кипр, США, Россия' 'Новая Зеландия - КНР'
#  'Дания - Канада - Швеция - Франция - Германия - Великобритания - США']
# ------------------------------
# director
# ['Кевин Костнер' 'Е.Матвеев' 'Тимур Бекмамбетов' ... 'Ник Пауэлл'
#  'А.Беляев' 'И.Трусов']
# ------------------------------
# producer
# ['Дэвид Валдес, Кевин Костнер, Джейк Эбертс' nan
#  'Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит' ...
#  'Поппи Бегум, Ник Пойнц'
#  'Джефф Боулер, Дэниэл Гродник, Луильо Руис, Брэт Саксон, Кирк Шоу'
#  'Дженнифер Додж']
# ------------------------------
# age_restriction
# ['«18+» - запрещено для детей' '«6+» - для детей старше 6 лет'
#  '«12+» - для детей старше 12 лет' '«16+» - для детей старше 16 лет'
#  '«0+» - для любой зрительской аудитории']
# ------------------------------
# refundable_support
# [         nan 0.000000e+00 5.000000e+07 2.600000e+07 3.000000e+07
#  1.500000e+07 1.000000e+07 2.000000e+07 7.153119e+06 2.500000e+07
#  4.000000e+07 6.000000e+07 4.400000e+07 2.900000e+07 4.100000e+07
#  3.600000e+07 3.500000e+06 5.000000e+06 1.900000e+07 9.000000e+06
#  1.100000e+08 1.700000e+07 7.500000e+07 1.500000e+08 3.800000e+07
#  1.000000e+08 5.500000e+07 7.000000e+06 7.346881e+06 8.000000e+06
#  1.150000e+08 3.500000e+07 1.800000e+08 2.800000e+07 8.000000e+07]
# ------------------------------
# nonrefundable_support
# [           nan 2.65000000e+07 2.60000000e+07 1.07847945e+08
#  2.80000000e+07 2.50000000e+07 1.00000000e+08 4.65022990e+07
#  7.50000000e+07 3.40000000e+07 3.00000000e+07 4.00000000e+07
#  2.30000000e+07 4.50000000e+07 5.65790550e+07 2.55000000e+07
#  2.75100000e+07 1.00000000e+07 2.40000000e+07 2.45000000e+07
#  2.70000000e+07 5.00000000e+06 9.00000000e+07 2.00000000e+07
#  7.00000000e+07 9.70000000e+07 2.44500000e+07 5.00000000e+07
#  0.00000000e+00 6.00000000e+07 2.75000000e+07 2.69500000e+07
#  1.10000000e+08 1.50000000e+07 5.90000000e+07 2.50000000e+08
#  3.70000000e+07 3.50000000e+07 2.01452850e+07 2.59000000e+07
#  6.00000000e+06 3.92104482e+08 2.52000000e+07 2.29040000e+07
#  2.90000000e+07 5.10000000e+07 4.70000000e+06 5.30000000e+06
#  2.17000000e+07 2.49860000e+07 2.53450000e+07 1.33000000e+08
#  1.75000000e+08 3.01239150e+07 2.85000000e+07 3.00000000e+08
#  4.15000000e+07 2.00000000e+08 1.50000000e+08 5.50000000e+07
#  6.40000000e+07 5.00008660e+07 1.15200000e+07 1.90000000e+08
#  2.25000000e+08 8.00000000e+06 4.00000000e+08 2.60000000e+08
#  3.10000000e+07 8.50000000e+07 8.00000000e+07 1.38969465e+08
#  1.20000000e+08 1.30000000e+08 1.40000000e+08 3.00000000e+06]
# ------------------------------
# budget
# [           nan 7.94119000e+07 3.71428570e+07 1.76023490e+08
#  4.05741400e+07 4.00151220e+07 5.18500000e+07 2.20588394e+08
#  8.62100670e+07 1.39551503e+08 4.85714300e+07 8.00000000e+07
#  3.62595000e+07 7.08761720e+07 2.52489571e+08 7.49100000e+07
#  0.00000000e+00 8.97823120e+07 4.36437176e+08 4.05000000e+07
#  6.84906060e+07 4.50066090e+07 1.31000000e+08 5.00000000e+08
#  6.10114070e+07 4.00000000e+07 3.73712620e+07 3.52969500e+07
#  4.30000000e+07 7.74017510e+07 3.50000000e+07 5.11967110e+07
#  9.01200000e+07 2.67288892e+08 4.92804960e+07 4.90714280e+07
#  4.69688830e+07 5.51950000e+07 1.56360666e+08 3.74247960e+07
#  3.57600600e+07 2.81155800e+07 3.79436520e+07 1.38325738e+08
#  4.22525090e+07 3.99900000e+07 1.12000000e+08 5.57294240e+07
#  3.57142860e+07 1.39357211e+08 5.02187410e+07 4.02650000e+07
#  3.90579710e+07 9.25000000e+07 4.14978600e+07 8.62363940e+07
#  8.03241370e+07 2.40153900e+08 1.00274436e+08 4.02877700e+07
#  2.85714290e+07 3.84768690e+07 2.70000000e+07 8.16124110e+07
#  6.40300800e+07 8.02732770e+07 3.60000000e+08 1.30619336e+08
#  5.28600000e+07 1.11736163e+08 5.54049630e+07 7.33795540e+07
#  4.20000000e+07 1.05445546e+08 5.80784510e+07 1.34000000e+08
#  8.46670380e+07 1.64780000e+08 4.19989840e+07 5.95607460e+07
#  7.40719180e+07 3.90000000e+07 8.53840000e+07 1.50008573e+08
#  5.21246380e+07 2.11810247e+08 6.35283867e+08 3.78891650e+07
#  4.62000000e+07 7.59409410e+07 5.42096570e+07 9.00000000e+07
#  6.94287280e+07 6.98830490e+07 4.28600000e+07 4.61600000e+07
#  6.20446460e+07 4.86611500e+07 3.99075326e+08 6.10700000e+07
#  3.84615380e+07 4.55386550e+07 3.80000000e+07 5.69095200e+07
#  5.38462000e+07 1.79257987e+08 1.09020947e+08 9.02767740e+07
#  7.86865000e+07 1.44624640e+07 2.15860000e+08 5.00000000e+07
#  7.00000000e+07 9.10000000e+07 3.70009900e+07 2.22177790e+08
#  3.84400000e+07 6.82942000e+07 1.62630398e+08 2.26271533e+08
#  5.28441977e+08 5.99374700e+07 7.50001350e+07 2.22513841e+08
#  4.61954270e+07 6.88092260e+07 6.10000000e+07 6.84200536e+08
#  2.87802711e+08 7.00864390e+07 6.30000000e+07 3.85000000e+07
#  1.10464061e+08 9.50000000e+07 1.13837339e+08 5.43032220e+07
#  4.30000000e+08 1.82659393e+08 3.23232109e+08 5.78743750e+07
#  2.06982031e+08 1.20000000e+08 2.02484224e+08 9.08227660e+07
#  3.60162690e+07 1.26932894e+08 5.46875000e+07 2.43122945e+08
#  3.13053130e+07 2.15162287e+08 3.78787870e+07 2.10405981e+08
#  3.20000000e+08 4.61538870e+07 1.80000000e+08 4.54832330e+07
#  4.06008000e+07 2.04674000e+08 3.44905389e+08 1.28570000e+08
#  6.50000000e+07 4.73280000e+07 1.87060800e+07 5.77670810e+07
#  9.02780630e+07 5.40000000e+07 6.31700000e+07 4.66573110e+07
#  3.00000000e+07 1.03290596e+09 7.70000000e+07 8.35534120e+07
#  1.57236080e+08 5.71667970e+07 4.93733957e+08 3.52477575e+08
#  7.80963150e+07 2.19398491e+08 7.42751000e+07 5.00012729e+08
#  3.84667000e+07 1.81664180e+07 4.86808580e+07 1.36230333e+08
#  5.84473010e+07 1.50000000e+08 1.74381922e+08 1.30000000e+08
#  5.90192191e+08 1.74464395e+08 4.46000000e+07 2.92412422e+08
#  1.70122675e+08 1.48585222e+08 6.00000000e+07 1.09609029e+08
#  8.28004880e+07 8.76491270e+07 2.04400968e+08 1.40005238e+08
#  1.10000000e+08 3.90191139e+08 1.09814241e+08 3.78491030e+07
#  1.18000000e+08 2.98500000e+08 2.00067392e+08 3.76000000e+07
#  1.14510306e+08 3.91292890e+07 9.50655460e+07 3.85000000e+08
#  3.08000000e+07 3.77656540e+07 6.20000000e+07 1.68271268e+08
#  1.11812387e+08 4.50450500e+07 1.81302726e+08 7.03050000e+07
#  8.24968890e+07 6.03735760e+07 7.69130580e+07 4.69237760e+07
#  4.82380750e+07 9.30000000e+07 4.50745470e+07 1.54245687e+08
#  1.72763618e+08 1.85500705e+08 3.97000000e+07 1.79708770e+08
#  5.63784717e+08 3.56550000e+08 3.35567667e+08 1.23714264e+08
#  1.15000000e+08 4.42865840e+07 5.66935590e+07 1.01463696e+08
#  1.08518988e+08 4.99826569e+08 4.69411400e+07 7.83551540e+07
#  1.02760000e+08 2.64578774e+08 1.69000000e+08 2.40041307e+08
#  1.65222908e+08 4.53704666e+08 3.77442800e+07 3.88582600e+07
#  3.75000000e+07 4.80000000e+07 4.61538460e+07 1.05721524e+08
#  4.10000000e+07 6.15714490e+07 4.63000000e+07 4.72000000e+07
#  3.00000000e+08 5.50000000e+07 6.06685760e+07 4.50500000e+07
#  7.15176310e+07 1.50100000e+07 6.01503760e+07 6.47929130e+07
#  6.79427180e+07 2.30507430e+09 1.01659240e+08 6.24157490e+07
#  1.54989700e+08 7.79941965e+08 3.30000000e+07 1.47866278e+08
#  5.78760000e+07 2.50000000e+08 1.40025000e+08 3.04489110e+07
#  7.50000000e+07 3.60054850e+08 4.77340500e+07 7.84222120e+07
#  2.70000000e+08 1.60000000e+08 9.80000000e+08 1.90000000e+08
#  9.44000000e+08 4.61540000e+07 1.50147502e+08]
# ------------------------------
# financing_source
# [nan 'Министерство культуры' 'Фонд кино'
#  'Министерство культуры, Фонд кино']
# ------------------------------
# ratings
# ['7.2' '6.6' '6.8' '7.7' '8.3' '8.0' '7.8' '8.1' '7.1' '6.0' '7.4' '5.8'
#  '8.7' '6.3' '6.9' '5.0' '4.3' '7.3' '7.0' '6.4' nan '8.2' '7.5' '6.7'
#  '7.9' '5.9' '6.2' '5.6' '6.5' '2.4' '7.6' '6.1' '8.6' '8.5' '8.8' '5.5'
#  '5.1' '5.7' '5.4' '99%' '4.4' '4.5' '5.3' '4.1' '8.4' '2.6' '3.8' '4.6'
#  '4.8' '4.0' '3.0' '1.6' '4.2' '5.2' '4.7' '4.9' '3.9' '2.7' '3.3' '2.9'
#  '28%' '3.7' '1.4' '3.1' '97%' '3.5' '3.2' '2.8' '1.5' '2.1' '2.5' '9.2'
#  '3.4' '1.1' '3.6' '83%' '64%' '91%' '94%' '62%' '79%' '90%' '19%' '88%'
#  '1.0' '89%' '1.3' '1.9' '1.8' '1.2' '1.7' '9.0' '98%' '8.9' '9.1']
# ------------------------------
# genres
# ['боевик,драма,мелодрама' 'драма,военный' 'фантастика,боевик,триллер'
#  'драма' 'мелодрама,комедия' 'мюзикл,мелодрама,комедия' 'комедия,криминал'
#  'боевик,триллер,детектив' 'боевик,драма,приключения' 'драма,спорт'
#  'триллер,драма,мелодрама' 'комедия,мелодрама' 'драма,мелодрама,комедия'
#  'драма,мелодрама' 'драма,история' 'драма,мелодрама,семейный'
#  'комедия,мелодрама,криминал' 'комедия' 'боевик,драма,криминал'
#  'драма,комедия' 'ужасы,фантастика,комедия'
#  'мультфильм,короткометражка,мелодрама' 'драма,криминал'
#  'мультфильм,фантастика,фэнтези' 'триллер,драма,криминал'
#  'драма,мелодрама,биография' 'драма,комедия,военный'
#  'фантастика,драма,детектив' 'мюзикл,семейный' nan
#  'военный,приключения,драма' 'документальный,драма'
#  'драма,биография,история' 'боевик,триллер,драма' 'фэнтези,боевик'
#  'боевик,комедия,криминал' 'мюзикл,комедия,детский'
#  'комедия,мелодрама,драма' 'мультфильм,фэнтези,комедия' 'комедия,история'
#  'мелодрама' 'драма,биография,музыка' 'фэнтези,драма,мелодрама'
#  'триллер,военный' 'драма,мелодрама,военный' 'мюзикл,драма,мелодрама'
#  'мюзикл,комедия' 'мультфильм,приключения,семейный' 'ужасы,триллер'
#  'боевик,драма,военный' 'драма,боевик' 'мультфильм,драма,комедия'
#  'триллер,криминал' 'военный,биография,драма' 'комедия,семейный' 'военный'
#  'драма,семейный,биография' 'фэнтези,приключения,семейный'
#  'драма,криминал,биография' 'ужасы,триллер,детектив'
#  'боевик,история,драма' 'ужасы,триллер,драма' 'драма,криминал,спорт'
#  'документальный,короткометражка' 'триллер,драма'
#  'криминал,детектив,приключения' 'драма,комедия,криминал'
#  'драма,комедия,вестерн' 'драма,мелодрама,детектив' 'мелодрама,биография'
#  'фэнтези,мелодрама,драма' 'драма,мелодрама,история'
#  'комедия,приключения,история' 'приключения' 'драма,семейный'
#  'криминал,детектив' 'мультфильм,короткометражка,ужасы'
#  'фантастика,триллер,драма' 'фэнтези,мелодрама,комедия' 'драма,биография'
#  'комедия,криминал,история' 'триллер,драма,детектив'
#  'фантастика,комедия,приключения' 'фэнтези,семейный'
#  'ужасы,фантастика,боевик' 'мелодрама,криминал'
#  'комедия,приключения,мелодрама' 'боевик,триллер,приключения'
#  'боевик,приключения' 'боевик,триллер,криминал'
#  'документальный,военный,история' 'драма,музыка' 'боевик,драма'
#  'приключения,боевик' 'драма,военный,биография'
#  'триллер,драма,приключения' 'аниме,мультфильм,фэнтези'
#  'триллер,детектив,драма' 'боевик,триллер,мелодрама' 'боевик,история'
#  'приключения,история' 'драма,комедия,приключения'
#  'фэнтези,комедия,приключения' 'драма,вестерн' 'документальный,музыка'
#  'мелодрама,драма' 'триллер,криминал,детектив' 'ужасы'
#  'боевик,комедия,приключения' 'мультфильм,фэнтези,боевик'
#  'боевик,фэнтези,драма' 'фэнтези,драма' 'фэнтези,боевик,комедия'
#  'приключения,детский,комедия' 'документальный' 'боевик,триллер,комедия'
#  'мелодрама,комедия,криминал' 'драма,детектив' 'мюзикл,ужасы,триллер'
#  'детектив,триллер,ужасы' 'ужасы,фэнтези' 'ужасы,фэнтези,триллер'
#  'мультфильм,драма' 'ужасы,боевик,фантастика' 'боевик' 'фантастика,боевик'
#  'мелодрама,комедия,приключения' 'триллер,детектив'
#  'мюзикл,мелодрама,фэнтези' 'криминал' 'триллер,комедия,криминал'
#  'боевик,приключения,триллер' 'триллер,драма,военный'
#  'комедия,семейный,музыка' 'комедия,фантастика,мелодрама'
#  'фантастика,триллер,криминал' 'комедия,драма' 'боевик,военный'
#  'ужасы,фантастика,триллер' 'фантастика,драма,мелодрама'
#  'фэнтези,драма,детектив' 'боевик,триллер' 'боевик,драма,история'
#  'мультфильм,мюзикл,фэнтези' 'для взрослых,драма,мелодрама'
#  'мультфильм,боевик,детектив' 'фантастика,мелодрама,боевик'
#  'ужасы,фантастика,детектив' 'фантастика,боевик,приключения'
#  'мелодрама,комедия,спорт' 'комедия,боевик,приключения'
#  'документальный,приключения' 'мультфильм,короткометражка,детский'
#  'комедия,приключения' 'ужасы,драма' 'ужасы,фэнтези,боевик'
#  'мультфильм,фэнтези,детский' 'мюзикл,боевик,драма'
#  'семейный,комедия,драма' 'концерт,музыка' 'фэнтези,боевик,драма'
#  'драма,комедия,музыка' 'фантастика,фэнтези,боевик'
#  'фэнтези,комедия,семейный' 'фэнтези,драма,комедия'
#  'мультфильм,мюзикл,драма' 'триллер' 'боевик,криминал,триллер'
#  'мультфильм,приключения,драма' 'мелодрама,музыка'
#  'документальный,музыка,концерт' 'мультфильм,семейный'
#  'мультфильм,комедия,приключения' 'мультфильм,комедия,семейный'
#  'фантастика,драма' 'фэнтези,боевик,приключения' 'мультфильм,приключения'
#  'драма,военный,история' 'история' 'драма,приключения,военный'
#  'документальный,короткометражка,семейный' 'мелодрама,история,триллер'
#  'ужасы,детектив' 'мюзикл,комедия,приключения' 'драма,спорт,биография'
#  'фантастика,боевик,комедия' 'фантастика,приключения,детектив'
#  'короткометражка,драма,военный' 'драма,мультфильм' 'приключения,семейный'
#  'детектив' 'триллер,приключения' 'аниме,мультфильм,боевик'
#  'драма,комедия,биография' 'драма,комедия,спорт'
#  'боевик,мелодрама,комедия' 'семейный,комедия' 'фэнтези,боевик,триллер'
#  'документальный,фэнтези,семейный' 'фантастика,фэнтези,драма'
#  'ужасы,комедия,фэнтези' 'документальный,биография,музыка'
#  'фантастика,боевик,фэнтези' 'ужасы,боевик,триллер'
#  'комедия,криминал,семейный' 'приключения,драма' 'криминал,драма,триллер'
#  'драма,детектив,криминал' 'фэнтези,приключения,комедия' 'комедия,спорт'
#  'мюзикл,фэнтези,мелодрама' 'мультфильм,фэнтези,приключения'
#  'фантастика,фэнтези,приключения' 'фэнтези' 'фэнтези,приключения,боевик'
#  'фантастика,боевик,драма' 'криминал,драма' 'криминал,триллер,драма'
#  'драма,мелодрама,приключения' 'детский,комедия' 'фантастика,драма,боевик'
#  'мультфильм,семейный,фэнтези' 'концерт,музыка,документальный'
#  'ужасы,комедия,приключения' 'драма,мелодрама,криминал'
#  'ужасы,фантастика,фэнтези' 'боевик,комедия'
#  'мультфильм,фантастика,комедия' 'триллер,ужасы'
#  'мультфильм,мюзикл,комедия' 'мелодрама,фэнтези,триллер'
#  'детский,приключения,комедия' 'комедия,детектив'
#  'аниме,мультфильм,мелодрама' 'документальный,драма,семейный'
#  'документальный,биография,история' 'военный,боевик,драма' 'ужасы,комедия'
#  'комедия,приключения,семейный' 'приключения,биография,история'
#  'детский,приключения,семейный' 'спорт,драма,биография'
#  'аниме,мультфильм,ужасы' 'фантастика,боевик,криминал' 'мюзикл,драма'
#  'драма,криминал,детектив' 'аниме,мультфильм,драма'
#  'драма,триллер,приключения' 'триллер,криминал,драма'
#  'фэнтези,комедия,драма' 'мультфильм,комедия' 'драма,комедия,история'
#  'комедия,биография,история' 'мультфильм,фантастика,приключения'
#  'аниме,мультфильм,фантастика' 'мультфильм,фэнтези,семейный'
#  'мультфильм,боевик,комедия' 'комедия,криминал,спорт'
#  'документальный,мюзикл' 'мелодрама,комедия,музыка' 'биография'
#  'триллер,криминал,комедия' 'фантастика,драма,комедия'
#  'комедия,драма,мелодрама' 'фантастика,приключения,боевик'
#  'мультфильм,фэнтези,драма' 'триллер,комедия'
#  'драма,приключения,биография' 'фантастика,комедия'
#  'мелодрама,драма,комедия' 'боевик,криминал' 'драма,криминал,боевик'
#  'мультфильм,мюзикл,детский' 'драма,фэнтези' 'документальный,семейный'
#  'фэнтези,драма,приключения' 'ужасы,комедия,фантастика'
#  'драма,мелодрама,музыка' 'фэнтези,драма,семейный'
#  'триллер,мелодрама,драма' 'вестерн,боевик,драма'
#  'мультфильм,короткометражка,комедия' 'триллер,драма,история'
#  'ужасы,фантастика' 'ужасы,мелодрама,комедия' 'фэнтези,приключения'
#  'фантастика,триллер' 'ужасы,боевик,фэнтези' 'мультфильм,комедия,детский'
#  'триллер,драма,биография' 'мультфильм,ужасы,фэнтези'
#  'мультфильм,ужасы,фантастика' 'ужасы,боевик,комедия'
#  'драма,биография,спорт' 'мультфильм' 'мелодрама,комедия,драма'
#  'приключения,фантастика,семейный' 'комедия,криминал,детектив'
#  'ужасы,триллер,комедия' 'криминал,комедия,триллер'
#  'семейный,приключения,комедия' 'мультфильм,драма,приключения'
#  'ужасы,драма,детектив' 'драма,приключения,фэнтези'
#  'фантастика,мультфильм,драма' 'драма,триллер,детектив'
#  'драма,история,музыка' 'детский' 'триллер,боевик,криминал'
#  'драма,фантастика' 'комедия,драма,семейный' 'боевик,драма,комедия'
#  'комедия,ужасы' 'драма,фантастика,триллер' 'фантастика,драма,триллер'
#  'история,спорт,драма' 'документальный,биография' 'биография,история'
#  'спорт,драма' 'боевик,фэнтези' 'мультфильм,фэнтези'
#  'документальный,комедия,история' 'криминал,комедия,боевик'
#  'фэнтези,приключения,драма' 'музыка,концерт' 'триллер,драма,боевик'
#  'комедия,криминал,боевик' 'комедия,фантастика,боевик'
#  'вестерн,приключения,боевик' 'аниме,мультфильм,комедия'
#  'детектив,криминал,триллер' 'мультфильм,комедия,криминал'
#  'комедия,приключения,детектив' 'мелодрама,фантастика,драма'
#  'драма,комедия,семейный' 'приключения,фантастика'
#  'триллер,детектив,ужасы' 'комедия,приключения,фэнтези'
#  'фэнтези,триллер,драма' 'мелодрама,приключения,боевик'
#  'детектив,триллер,криминал' 'фэнтези,семейный,мелодрама' 'военный,драма'
#  'документальный,приключения,семейный' 'криминал,комедия,драма'
#  'комедия,фантастика' 'история,биография,драма' 'мелодрама,драма,музыка'
#  'боевик,мелодрама' 'комедия,криминал,триллер' 'детектив,триллер,боевик'
#  'комедия,боевик,криминал' 'комедия,вестерн' 'детский,мелодрама,семейный'
#  'короткометражка,мультфильм' 'комедия,фэнтези' 'фантастика,драма,ужасы'
#  'триллер,драма,ужасы' 'драма,фэнтези,история'
#  'комедия,драма,короткометражка' 'фэнтези,триллер,приключения' 'семейный'
#  'комедия,криминал,драма' 'комедия,фэнтези,ужасы'
#  'короткометражка,комедия,криминал' 'фантастика' 'триллер,ужасы,драма'
#  'мелодрама,драма,фэнтези' 'фантастика,приключения,драма'
#  'боевик,детектив' 'военный,драма,боевик' 'комедия,мелодрама,фэнтези'
#  'вестерн,криминал,триллер' 'драма,история,триллер'
#  'мультфильм,фантастика,боевик' 'детектив,драма,криминал'
#  'приключения,история,драма' 'мультфильм,семейный,детский'
#  'биография,драма,история' 'триллер,криминал,боевик' 'история,мелодрама'
#  'приключения,детский' 'музыка,приключения,концерт'
#  'военный,драма,комедия' 'фэнтези,боевик,военный'
#  'фантастика,детектив,боевик' 'мультфильм,фэнтези,история'
#  'биография,мелодрама,драма' 'документальный,биография,спорт'
#  'фантастика,комедия,детектив' 'музыка,концерт,документальный'
#  'триллер,боевик,приключения' 'триллер,драма,комедия' 'детектив,криминал'
#  'мультфильм,приключения,фэнтези' 'мелодрама,приключения' 'комедия,музыка'
#  'мелодрама,комедия,ужасы' 'драма,криминал,приключения'
#  'приключения,детектив,мелодрама' 'драма,криминал,фантастика'
#  'фэнтези,драма,биография' 'детектив,фантастика,криминал'
#  'триллер,драма,фантастика' 'ужасы,комедия,боевик' 'мелодрама,история'
#  'триллер,боевик' 'фильм-нуар,триллер,детектив'
#  'комедия,криминал,приключения' 'ужасы,триллер,мелодрама'
#  'военный,драма,история' 'драма,спорт,история'
#  'документальный,драма,история' 'триллер,мелодрама,детектив'
#  'детский,семейный' 'мюзикл,семейный,драма' 'биография,военный,драма'
#  'мультфильм,детский' 'боевик,криминал,драма' 'детектив,фэнтези,триллер'
#  'драма,боевик,приключения' 'драма,мелодрама,фэнтези'
#  'детектив,история,драма' 'фэнтези,боевик,ужасы' 'ужасы,фэнтези,мелодрама'
#  'ужасы,приключения' 'боевик,фантастика' 'ужасы,мелодрама,детектив'
#  'фантастика,триллер,приключения' 'боевик,приключения,история'
#  'приключения,боевик,триллер' 'детектив,ужасы,криминал' 'семейный,фэнтези'
#  'мюзикл,мелодрама' 'драма,военный,приключения'
#  'фантастика,драма,приключения' 'приключения,семейный,драма'
#  'история,драма,боевик' 'мультфильм,приключения,комедия'
#  'криминал,драма,комедия' 'ужасы,комедия,драма'
#  'комедия,семейный,приключения' 'мюзикл,фэнтези,драма'
#  'драма,вестерн,боевик' 'фантастика,триллер,детектив'
#  'драма,история,детектив' 'короткометражка,биография'
#  'мультфильм,приключения,фантастика' 'комедия,триллер'
#  'мультфильм,приключения,детектив' 'драма,триллер'
#  'ужасы,триллер,криминал' 'документальный,криминал,военный'
#  'ужасы,фэнтези,драма' 'фэнтези,комедия' 'ужасы,фэнтези,комедия'
#  'комедия,музыка,драма' 'мультфильм,приключения,военный'
#  'мюзикл,фэнтези,комедия' 'боевик,фантастика,приключения'
#  'триллер,ужасы,криминал' 'ужасы,фантастика,драма'
#  'фантастика,приключения,семейный' 'короткометражка,музыка'
#  'мелодрама,детектив,комедия' 'документальный,триллер,биография'
#  'боевик,фантастика,триллер' 'спорт,драма,комедия'
#  'фэнтези,мелодрама,приключения' 'триллер,детектив,криминал'
#  'короткометражка,мелодрама' 'мультфильм,семейный,спорт'
#  'комедия,фэнтези,мелодрама' 'драма,спорт,комедия'
#  'история,драма,мелодрама' 'драма,боевик,криминал' 'драма,комедия,триллер'
#  'аниме,мультфильм' 'документальный,ужасы' 'мультфильм,короткометражка'
#  'драма,история,военный' 'мультфильм,короткометражка,фэнтези'
#  'комедия,военный,музыка' 'биография,история,драма'
#  'ужасы,драма,мелодрама' 'драма,комедия,детектив'
#  'комедия,семейный,фантастика' 'мультфильм,семейный,комедия'
#  'история,детектив' 'приключения,мелодрама,детектив'
#  'мюзикл,комедия,мелодрама' 'драма,фантастика,ужасы'
#  'мультфильм,ужасы,комедия' 'для взрослых,драма,комедия'
#  'ужасы,комедия,музыка' 'комедия,история,драма'
#  'семейный,детектив,детский' 'короткометражка,драма'
#  'документальный,новости,драма' 'триллер,мелодрама' 'ужасы,драма,вестерн'
#  'мюзикл,фэнтези,семейный' 'вестерн,драма,триллер'
#  'приключения,вестерн,боевик' 'семейный,комедия,музыка'
#  'боевик,драма,вестерн' 'ужасы,драма,триллер' 'фантастика,мелодрама'
#  'комедия,криминал,биография' 'семейный,мультфильм,комедия'
#  'комедия,драма,криминал' 'фантастика,боевик,военный'
#  'приключения,биография,драма' 'приключения,триллер,биография'
#  'криминал,боевик,триллер' 'боевик,вестерн,приключения' 'история,драма'
#  'фантастика,фэнтези,комедия' 'мультфильм,детский,комедия'
#  'мелодрама,комедия,триллер' 'документальный,боевик,приключения'
#  'драма,приключения' 'мелодрама,военный,драма' 'триллер,фэнтези'
#  'драма,триллер,биография' 'фэнтези,боевик,семейный'
#  'фантастика,триллер,комедия' 'документальный,фэнтези'
#  'комедия,мультфильм,фантастика' 'криминал,биография,комедия'
#  'биография,спорт,драма' 'приключения,военный' 'мультфильм,семейный,драма'
#  'документальный,фэнтези,драма' 'комедия,боевик,фантастика'
#  'семейный,приключения,военный' 'триллер,ужасы,детектив' 'короткометражка'
#  'мелодрама,триллер,история' 'документальный,история'
#  'мультфильм,приключения,детский' 'драма,комедия,мультфильм'
#  'военный,детектив' 'семейный,приключения,документальный'
#  'детский,фэнтези' 'документальный,комедия' 'комедия,биография'
#  'криминал,комедия' 'спорт,мелодрама,криминал' 'фантастика,комедия,боевик'
#  'боевик,приключения,детектив' 'детектив,триллер,драма'
#  'документальный,фантастика' 'мелодрама,комедия,семейный'
#  'мультфильм,мелодрама,комедия' 'драма,спорт,семейный'
#  'фантастика,мелодрама,фэнтези' 'мюзикл,комедия,музыка'
#  'фантастика,триллер,мелодрама' 'приключения,комедия,фэнтези'
#  'фэнтези,боевик,детектив' 'фэнтези,боевик,мелодрама' 'комедия,военный'
#  'драма,спорт,боевик' 'мультфильм,боевик,триллер' 'мелодрама,семейный'
#  'фантастика,боевик,детектив' 'драма,приключения,история'
#  'документальный,драма,музыка' 'фантастика,триллер,боевик'
#  'фэнтези,боевик,вестерн' 'драма,комедия,мелодрама'
#  'ужасы,фэнтези,приключения' 'триллер,фэнтези,драма'
#  'мультфильм,мюзикл,мелодрама' 'ужасы,триллер,фантастика'
#  'триллер,мелодрама,комедия' 'ужасы,комедия,семейный'
#  'комедия,приключения,музыка' 'документальный,комедия,криминал'
#  'мелодрама,детектив' 'детский,приключения,фантастика'
#  'короткометражка,боевик,драма' 'боевик,комедия,семейный'
#  'фантастика,боевик,мелодрама' 'фэнтези,триллер,мелодрама'
#  'драма,детектив,история' 'боевик,криминал,детектив'
#  'мультфильм,фэнтези,мелодрама' 'мелодрама,драма,боевик'
#  'драма,вестерн,приключения' 'драма,приключения,мелодрама'
#  'фэнтези,боевик,криминал' 'фантастика,комедия,семейный'
#  'детский,фэнтези,приключения' 'ужасы,боевик'
#  'фантастика,мелодрама,комедия' 'семейный,спорт,боевик'
#  'триллер,биография,драма' 'ужасы,драма,комедия'
#  'мультфильм,фэнтези,триллер' 'мюзикл' 'боевик,спорт,драма'
#  'комедия,приключения,вестерн' 'документальный,ужасы,боевик'
#  'фантастика,боевик,семейный' 'военный,история' 'ужасы,боевик,криминал'
#  'детектив,триллер' 'драма,семейный,комедия' 'драма,детектив,приключения'
#  'драма,криминал,история' 'приключения,триллер' 'боевик,драма,биография'
#  'драма,приключения,триллер' 'комедия,фэнтези,приключения'
#  'фантастика,боевик,ужасы' 'драма,комедия,фантастика'
#  'детектив,криминал,драма' 'боевик,триллер,фэнтези'
#  'приключения,детектив,семейный' 'ужасы,комедия,криминал'
#  'мультфильм,биография,драма' 'история,боевик,фэнтези'
#  'детектив,криминал,боевик' 'приключения,фэнтези'
#  'комедия,приключения,спорт' 'драма,биография,мюзикл'
#  'комедия,семейный,фэнтези' 'детектив,драма,триллер'
#  'боевик,приключения,семейный' 'биография,спорт,комедия'
#  'фантастика,приключения,военный' 'документальный,драма,биография'
#  'детектив,приключения,драма' 'аниме,мультфильм,приключения'
#  'семейный,приключения' 'ужасы,фэнтези,детектив' 'семейный,документальный'
#  'драма,приключения,семейный' 'приключения,история,военный'
#  'фэнтези,мелодрама' 'фэнтези,триллер,детектив'
#  'документальный,спорт,биография' 'комедия,триллер,драма' 'драма,ужасы'
#  'биография,музыка,драма' 'фэнтези,ужасы' 'детектив,мелодрама,фэнтези'
#  'боевик,военный,история' 'биография,драма,криминал'
#  'триллер,мелодрама,криминал' 'семейный,мелодрама' 'биография,драма'
#  'военный,история,драма' 'фантастика,детектив,фэнтези'
#  'детектив,приключения,триллер' 'фантастика,приключения'
#  'мультфильм,короткометражка,мюзикл' 'мультфильм,детский,семейный'
#  'документальный,драма,комедия' 'комедия,приключения,криминал'
#  'документальный,семейный,музыка' 'мелодрама,музыка,драма'
#  'детектив,фантастика,триллер' 'драма,мелодрама,триллер'
#  'биография,драма,военный' 'приключения,фантастика,драма'
#  'детектив,фильм-нуар,комедия' 'документальный,спорт'
#  'триллер,фантастика,драма' 'биография,документальный'
#  'ужасы,фантастика,мелодрама' 'детектив,комедия'
#  'история,биография,военный' 'криминал,мелодрама' 'драма,криминал,вестерн'
#  'мелодрама,семейный,приключения' 'триллер,ужасы,мелодрама'
#  'фэнтези,драма,фильм-нуар' 'детектив,мелодрама' 'комедия,драма,биография'
#  'драма,военный,боевик' 'драма,комедия,ужасы' 'фантастика,драма,криминал'
#  'документальный,музыка,биография' 'мультфильм,боевик,приключения'
#  'короткометражка,фантастика' 'мультфильм,мелодрама,драма'
#  'боевик,военный,драма' 'фэнтези,семейный,приключения'
#  'детский,мультфильм,приключения' 'семейный,фэнтези,комедия'
#  'фэнтези,ужасы,триллер' 'ужасы,триллер,приключения'
#  'драма,боевик,история' 'фэнтези,комедия,детектив' 'история,приключения'
#  'аниме,мультфильм,короткометражка' 'драма,военный,триллер'
#  'биография,криминал,триллер' 'фантастика,фэнтези,детектив'
#  'вестерн,биография,драма' 'биография,музыка,мюзикл'
#  'драма,история,биография' 'приключения,драма,фантастика'
#  'комедия,фэнтези,криминал' 'биография,спорт,история'
#  'драма,криминал,семейный' 'детектив,боевик,история'
#  'ужасы,комедия,детектив' 'триллер,приключения,драма'
#  'фэнтези,комедия,криминал' 'триллер,криминал,приключения'
#  'комедия,детектив,приключения' 'фэнтези,драма,ужасы'
#  'ужасы,драма,военный' 'реальное ТВ' 'аниме,мультфильм,детектив'
#  'приключения,фэнтези,семейный' 'драма,биография,комедия'
#  'триллер,комедия,ужасы' 'музыка,мелодрама,фэнтези' 'мультфильм,история'
#  'мультфильм,комедия,фантастика' 'биография,криминал,драма'
#  'комедия,мелодрама,фантастика' 'криминал,боевик,комедия'
#  'история,криминал' 'детектив,комедия,драма' 'триллер,фантастика,боевик'
#  'криминал,боевик' 'комедия,драма,военный' 'драма,триллер,криминал'
#  'мультфильм,мелодрама,приключения' 'фантастика,фэнтези,триллер'
#  'короткометражка,драма,триллер' 'военный,боевик,история'
#  'боевик,драма,триллер' 'документальный,военный,драма'
#  'драма,криминал,фильм-нуар' 'мультфильм,детский,приключения'
#  'мелодрама,история,драма']
# ------------------------------

# %%
# функция для подсчета количества уникальных значений
def value_counts(column):
    print(column.name)
    print(column.value_counts())
    print('-'*30)

# %%
# взглянем на количества уникальных значения по всех столбцах
for column in df_movies.columns:
    value_counts(df_movies[column])
# Out:
# title
# День святого Валентина_                               5
# Кошки против собак: Месть Китти Галор                 4
# Знакомство с Факерами 2.                              4
# Рапунцель: Запутанная история                         4
# Секс в большом городе 2                               4
#                                                      ..
# МУЛЬТ в кино. Выпуск № 14                             1
# Стажёр                                                1
# Мэхэббэт - ул йорэк эше (Любовь - это дело сердца)    1
# Иван Грозный - 2 серия (восстановленная версия)       1
# Машины песенки. Серия "Когда цветут кактусы"          1
# Name: title, Length: 6772, dtype: int64
# ------------------------------
# puNumber
# 221054410    2
# 221154310    2
# 221048915    1
# 121004611    1
# 121014411    1
#             ..
# 121009015    1
# 111004115    1
# 211047015    1
# 121011015    1
# 124010719    1
# Name: puNumber, Length: 7484, dtype: int64
# ------------------------------
# show_start_date
# 2010-12-17T12:00:00.000Z    96
# 2014-12-01T12:00:00.000Z    71
# 2014-12-24T12:00:00.000Z    61
# 2016-06-07T12:00:00.000Z    41
# 2013-12-19T12:00:00.000Z    39
#                             ..
# 2017-05-25T12:00:00.000Z     1
# 2018-03-05T12:00:00.000Z     1
# 2015-03-13T12:00:00.000Z     1
# 2018-03-17T12:00:00.000Z     1
# 2010-05-24T12:00:00.000Z     1
# Name: show_start_date, Length: 1965, dtype: int64
# ------------------------------
# type
# Художественный                4520
#  Художественный               1389
# Анимационный                   828
# Прочие                         406
# Документальный                 288
# Научно-популярный               53
#  Анимационный                    1
# Музыкально-развлекательный       1
# Name: type, dtype: int64
# ------------------------------
# film_studio
# Киностудия "Мосфильм"                                                                                                      341
# ООО "Мульт в кино"                                                                                                          57
# Анимаккорд Лтд                                                                                                              23
# ООО "Мульт в кино"                                                                                                          18
# ФГУП "ТПО "Киностудия "Союзмультфильм"                                                                                      16
#                                                                                                                           ...
# МортуСкрин, Игл Рок Интертейнмент                                                                                            1
# Эден Рок Медиа, Филм Нэйшн Интертейнмент, Флинн Пикчерз Компани, Нью Лайн Синема, Силвер Рил, Суперсенсори, Вентюр Ворт      1
# Мажестик Филмпродуцион, Айрис Продакшнз, Рат Пак Филмпродуцион, Фред Фильм                                                   1
# Арт Франс, Артлайн Филмз, Коэн Медиа Групп                                                                                   1
# Эмблин Интертейнмент, ДримУоркс, Марк Платт Продакшнз, Релианс Интертейнмент, Юниверсал Пикчерз                              1
# Name: film_studio, Length: 5490, dtype: int64
# ------------------------------
# production_country
# США                                                                    2172
# Россия                                                                 1821
# СССР                                                                    347
# Франция                                                                 301
# Великобритания                                                          257
#                                                                        ...
# Франция-Китай                                                             1
# Россия, Германия, Великобритания                                          1
# Великобритания - Италия - Испания                                         1
# Россия-Ирландия                                                           1
# Дания - Канада - Швеция - Франция - Германия - Великобритания - США       1
# Name: production_country, Length: 950, dtype: int64
# ------------------------------
# director
# О.Семёнова                  47
# Д.Червяцов                  17
# Стивен Содерберг            17
# Ридли Скотт                 16
# Тиль Швайгер                14
#                             ..
# Том Коркоран                 1
# Е.Сергеев                    1
# Фернандо Гонзалез Молина     1
# Е.Перволовичи                1
# И.Трусов                     1
# Name: director, Length: 4811, dtype: int64
# ------------------------------
# producer
# П.Смирнов                                                                     67
# Олег Кузовков, Дмитрий Ловейко, Марина Ратина                                 28
# С.Сельянов                                                                    18
# Д.Ловейко, О.Кузовков                                                         17
# Тони Майерс                                                                   11
#                                                                               ..
# Б.Гуц, А.Гусенцова                                                             1
# Лоран Петен, Мишель Петен                                                      1
#  ООО "КиноФирма"                                                               1
# Э.Илоян, В.Шляппо, А.Троцюк, Д.Жалинский, Д.Дьяченко, М.Ткаченко, А.Рубцов     1
# Дженнифер Додж                                                                 1
# Name: producer, Length: 5349, dtype: int64
# ------------------------------
# age_restriction
# «16+» - для детей старше 16 лет           2851
# «18+» - запрещено для детей               1605
# «12+» - для детей старше 12 лет           1593
# «0+» - для любой зрительской аудитории     811
# «6+» - для детей старше 6 лет              626
# Name: age_restriction, dtype: int64
# ------------------------------
# refundable_support
# 0.0            221
# 20000000.0      12
# 10000000.0      10
# 25000000.0      10
# 5000000.0        9
# 15000000.0       9
# 40000000.0       8
# 50000000.0       8
# 30000000.0       7
# 60000000.0       6
# 100000000.0      5
# 55000000.0       2
# 75000000.0       2
# 110000000.0      2
# 19000000.0       2
# 3500000.0        1
# 26000000.0       1
# 28000000.0       1
# 180000000.0      1
# 35000000.0       1
# 115000000.0      1
# 8000000.0        1
# 7346881.0        1
# 7000000.0        1
# 7153119.0        1
# 36000000.0       1
# 38000000.0       1
# 150000000.0      1
# 44000000.0       1
# 17000000.0       1
# 29000000.0       1
# 9000000.0        1
# 41000000.0       1
# 80000000.0       1
# Name: refundable_support, dtype: int64
# ------------------------------
# nonrefundable_support
# 25000000.0    53
# 30000000.0    48
# 35000000.0    29
# 40000000.0    26
# 20000000.0    19
#               ..
# 51000000.0     1
# 4700000.0      1
# 5300000.0      1
# 21700000.0     1
# 3000000.0      1
# Name: nonrefundable_support, Length: 75, dtype: int64
# ------------------------------
# budget
# 0.0            17
# 38000000.0      6
# 50000000.0      4
# 80000000.0      4
# 37142857.0      3
#                ..
# 109020947.0     1
# 90276774.0      1
# 78686500.0      1
# 14462464.0      1
# 150147502.0     1
# Name: budget, Length: 290, dtype: int64
# ------------------------------
# financing_source
# Министерство культуры               164
# Фонд кино                           146
# Министерство культуры, Фонд кино     22
# Name: financing_source, dtype: int64
# ------------------------------
# ratings
# 6.6    312
# 6.7    308
# 6.8    261
# 7.2    252
# 6.2    243
#       ...
# 19%      1
# 90%      1
# 62%      1
# 64%      1
# 9.1      1
# Name: ratings, Length: 94, dtype: int64
# ------------------------------
# genres
# драма                           476
# комедия                         352
# мелодрама,комедия               222
# драма,мелодрама,комедия         189
# драма,мелодрама                 183
#                                ...
# мюзикл,фэнтези,семейный           1
# мюзикл,мелодрама,фэнтези          1
# документальный,новости,драма      1
# семейный,детектив,детский         1
# мелодрама,история,драма           1
# Name: genres, Length: 742, dtype: int64
# ------------------------------

# %%
# для создания таблицы с пропущенными значениями в процентах
# создадим функции для таблицы и перевода в процент
def nan_table(data):
    return data.isna().mean().reset_index().rename(columns={'index': 'Столбец', 0: 'Процент'})
def percent(data):
    return data['Процент']*100

# %%
# Создаем таблицы с процентными значениями пропусков 
# в каждом столбце
mean_nan = nan_table(df_movies)
mean_nan['Процент'] = percent(mean_nan)

# %%
mean_nan
# Out:
#                   Столбец    Процент
# 0                   title   0.000000
# 1                puNumber   0.000000
# 2         show_start_date   0.000000
# 3                    type   0.000000
# 4             film_studio   0.240449
# 5      production_country   0.026717
# 6                director   0.120224
# 7                producer   7.587497
# 8         age_restriction   0.000000
# 9      refundable_support  95.565055
# 10  nonrefundable_support  95.565055
# 11                 budget  95.565055
# 12       financing_source  95.565055
# 13                ratings  12.917446
# 14                 genres  13.037670

# %%
# Функция для более наглядного представления количества
# уникальных значений
# с целью выявления аномалий и неявных дубликатов
def check_anomal(column):
    print(column)
    display(df_movies[column].value_counts().reset_index().sort_values(by='index'))
    print('-'*30)

# %%
# применяем функцию
list(map(check_anomal,df_movies.columns))
# Out:
# title
#                                                   index  title
# 2885                                           Я ПРЕПОД      1
# 4159                                   "SOS" над тайгой      1
# 1872                                "V" значит вендетта      1
# 2317  "АРТиШОК" анимационный альманах авторских фильмов      1
# 6660                     "Бежин луг" Сергея Эйзенштейна      1
# ...                                                 ...    ...
# 2496                                       Японский Бог      1
# 1215                                            Ярослав      1
# 6065                                      Ярость / Fury      1
# 3265  альманах документальных фильмов "Вокзалы Росси...      1
# 3849                                        сНежное шоу      1
#
# [6772 rows x 2 columns]
# ------------------------------
# puNumber
#            index  puNumber
# 5190   111004112         1
# 1331   111000110         1
# 266    111000111         1
# 5207   111000112         1
# 4105   111000113         1
# ...          ...       ...
# 1815   226017410         1
# 1008   226019110         1
# 3988   231001012         1
# 748    231001111         1
# 4430         нет         1
#
# [7484 rows x 2 columns]
# ------------------------------
# show_start_date
#                          index  show_start_date
# 1376  2010-01-11T12:00:00.000Z                1
# 957   2010-01-13T12:00:00.000Z                2
# 595   2010-01-14T12:00:00.000Z                4
# 188   2010-01-15T12:00:00.000Z                9
# 1189  2010-01-18T12:00:00.000Z                2
# ...                        ...              ...
# 900   2019-12-24T12:00:00.000Z                3
# 573   2019-12-26T12:00:00.000Z                4
# 1448  2019-12-27T12:00:00.000Z                1
# 1380  2019-12-28T12:00:00.000Z                1
# 1257  2019-12-30T12:00:00.000Z                2
#
# [1965 rows x 2 columns]
# ------------------------------
# type
#                         index  type
# 6                Анимационный     1
# 1              Художественный  1389
# 2                Анимационный   828
# 4              Документальный   288
# 7  Музыкально-развлекательный     1
# 5           Научно-популярный    53
# 3                      Прочие   406
# 0              Художественный  4520
# ------------------------------
# film_studio
#                                                   index  film_studio
# 1117                                    АНО "Кинофорум"            1
# 5349    Ауматик Интертейнмент, Блюмхаус Продакшнз и др.            1
# 2627   ЗАО "Кинокомпания ФаворитФильм" по заказу ООО...            1
# 257    Константин Фильм, А Эр Ди Дегето Фильм, Дюне ...            3
# 2142                                      ООО "АВАТАРА"            1
# ...                                                 ...          ...
# 2628  иУан, Джи-Эс Медиа, Скрин Йоркшир, Классифайд ...            1
# 1399                                колорФИЛД Филм ГмбХ            1
# 4124  ристалл Сити Интертейнмент, Эксклюзив Медиа Гр...            1
# 3902  совместное производство Киностудия "Мосфильм",...            1
# 856                                     юФилм, Твинпикс            2
#
# [5490 rows x 2 columns]
# ------------------------------
# production_country
#                                                  index  production_country
# 183                                               СССР                   2
# 648                                              СССР                    1
# 637                                            СССР                      1
# 468                                               2019                   1
# 563                                                CША                   1
# ..                                                 ...                 ...
# 432                             Япония, Великобритания                   1
# 896  Япония, Великобритания, Австрия, Германия, Ю.К...                   1
# 391                                        Япония, США                   1
# 223                              Япония-Великобритания                   2
# 341                                 Япония-США-Франция                   1
#
# [950 rows x 2 columns]
# ------------------------------
# director
#                                                   index  director
# 3050                                    Йохан Нийенхейс         1
# 3617                                   Н.Орлов, Р.Быков         1
# 4403                                           Р.Асхаев         1
# 2775                                           Т.Саакян         1
# 2266                                        Ф.Бондарчук         1
# ...                                                 ...       ...
# 3819  хореография Питера Райта, Льва Иванова по разр...         1
# 3085  хореография Питера Райта, Льва Иванова по разр...         1
# 2961       хореография Пьера Лакотта по Филиппу Тальони         1
# 4742                       хореография Фредерика Аштона         1
# 3803                       хореография Фредерика Эштона         1
#
# [4811 rows x 2 columns]
# ------------------------------
# producer
#                                                   index  producer
# 5318                                          А.Шальопа         1
# 3567                                          Г.Шпригов         1
# 3767   Дитмар Ганше, Филипп Фогес,  Бенджамин Херрма...         1
# 1361                                        И.Гелашвили         1
# 4374                      К.Шахназаров, А.Златопольский         1
# ...                                                 ...       ...
# 1118                                        Ярив Лернер         1
# 2664     Яцек Дросио, Михал Энглерт, Малгожата Шумовска         1
# 4827  Яэль Абекассис, Мат Кирби, Мишель Киркман, Паб...         1
# 1523         Яэль Бергман, Лаура Уотерс, Питер Хеллайар         1
# 2320                      Яэль Фогель, Летиция Гонзалез         1
#
# [5349 rows x 2 columns]
# ------------------------------
# age_restriction
#                                     index  age_restriction
# 3  «0+» - для любой зрительской аудитории              811
# 2         «12+» - для детей старше 12 лет             1593
# 0         «16+» - для детей старше 16 лет             2851
# 1             «18+» - запрещено для детей             1605
# 4           «6+» - для детей старше 6 лет              626
# ------------------------------
# refundable_support
#           index  refundable_support
# 0           0.0                 221
# 15    3500000.0                   1
# 4     5000000.0                   9
# 23    7000000.0                   1
# 24    7153119.0                   1
# 22    7346881.0                   1
# 21    8000000.0                   1
# 31    9000000.0                   1
# 2    10000000.0                  10
# 5    15000000.0                   9
# 29   17000000.0                   1
# 14   19000000.0                   2
# 1    20000000.0                  12
# 3    25000000.0                  10
# 16   26000000.0                   1
# 17   28000000.0                   1
# 30   29000000.0                   1
# 8    30000000.0                   7
# 19   35000000.0                   1
# 25   36000000.0                   1
# 26   38000000.0                   1
# 6    40000000.0                   8
# 32   41000000.0                   1
# 28   44000000.0                   1
# 7    50000000.0                   8
# 11   55000000.0                   2
# 9    60000000.0                   6
# 12   75000000.0                   2
# 33   80000000.0                   1
# 10  100000000.0                   5
# 13  110000000.0                   2
# 20  115000000.0                   1
# 27  150000000.0                   1
# 18  180000000.0                   1
# ------------------------------
# nonrefundable_support
#           index  nonrefundable_support
# 8           0.0                      9
# 74    3000000.0                      1
# 71    4700000.0                      1
# 16    5000000.0                      3
# 72    5300000.0                      1
# ..          ...                    ...
# 19  250000000.0                      3
# 41  260000000.0                      1
# 23  300000000.0                      2
# 66  392104482.0                      1
# 15  400000000.0                      3
#
# [75 rows x 2 columns]
# ------------------------------
# budget
#             index  budget
# 0    0.000000e+00      17
# 288  1.446246e+07       1
# 104  1.501000e+07       1
# 49   1.816642e+07       1
# 63   1.870608e+07       1
# ..            ...     ...
# 113  7.799420e+08       1
# 60   9.440000e+08       1
# 70   9.800000e+08       1
# 71   1.032906e+09       1
# 108  2.305074e+09       1
#
# [290 rows x 2 columns]
# ------------------------------
# financing_source
#                               index  financing_source
# 0             Министерство культуры               164
# 2  Министерство культуры, Фонд кино                22
# 1                         Фонд кино               146
# ------------------------------
# ratings
#    index  ratings
# 88   1.0        1
# 79   1.1        2
# 83   1.2        1
# 86   1.3        1
# 74   1.4        2
# ..   ...      ...
# 67   91%        3
# 66   94%        3
# 70   97%        3
# 75   98%        2
# 64   99%        4
#
# [94 rows x 2 columns]
# ------------------------------
# genres
#                            index  genres
# 374             аниме,мультфильм       2
# 118      аниме,мультфильм,боевик      11
# 409    аниме,мультфильм,детектив       2
# 176       аниме,мультфильм,драма       7
# 429     аниме,мультфильм,комедия       2
# ..                           ...     ...
# 109        фэнтези,триллер,драма      12
# 258    фэнтези,триллер,мелодрама       4
# 232  фэнтези,триллер,приключения       4
# 560                фэнтези,ужасы       1
# 568        фэнтези,ужасы,триллер       1
#
# [742 rows x 2 columns]
# ------------------------------
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
# смотрим на аномалию в столбце puNumber
df_movies[df_movies['puNumber'] == 'нет']
# Out:
#                                   title puNumber           show_start_date  \
# 1797  Курбан-роман. (История с жертвой)      нет  2014-05-15T12:00:00.000Z
#
#                 type       film_studio production_country director  \
# 1797  Художественный  ФОНД "ИННОВАЦИЯ"             Россия  С.Юзеев
#
#         producer                  age_restriction  refundable_support  \
# 1797  М.Галицкая  «12+» - для детей старше 12 лет                 NaN
#
#       nonrefundable_support  budget financing_source ratings genres
# 1797                    NaN     NaN              NaN     NaN    NaN

# %%
# ищем прокатные удостоверения у режиссера С.Юзеев
df_movies[df_movies['director'] == 'С.Юзеев']
# Out:
#                                    title   puNumber           show_start_date  \
# 1797   Курбан-роман. (История с жертвой)        нет  2014-05-15T12:00:00.000Z
# 2078  Курбан-роман. (История с жертвой).  111009614  2014-09-02T12:00:00.000Z
#
#                 type       film_studio production_country director  \
# 1797  Художественный  ФОНД "ИННОВАЦИЯ"             Россия  С.Юзеев
# 2078  Художественный  ФОНД "ИННОВАЦИЯ"             Россия  С.Юзеев
#
#         producer                  age_restriction  refundable_support  \
# 1797  М.Галицкая  «12+» - для детей старше 12 лет                 NaN
# 2078  М.Галицкая  «12+» - для детей старше 12 лет                 NaN
#
#       nonrefundable_support  budget financing_source ratings genres
# 1797                    NaN     NaN              NaN     NaN    NaN
# 2078                    NaN     NaN              NaN     NaN    NaN

# %%
# Сортируем по столбцу title, анализируем таблицу на факт дубликатов в столбцах
# 'show_start_date','type','film_studio','director','producer','age_restriction'
df_movies.loc[df_movies.duplicated(subset=('show_start_date',
                                           'type',
                                           'film_studio',
                                           'director',
                                           'producer',
                                           'age_restriction'), 
                                   keep=False)].sort_values(by='title').T
# Out:
#                                                   57    \
# title                               А если это любовь?
# puNumber                                     111010213
# show_start_date               2013-12-19T12:00:00.000Z
# type                                    Художественный
# film_studio                      Киностудия "Мосфильм"
# production_country                                СССР
# director                                     Ю.Райзман
# producer                                           NaN
# age_restriction        «12+» - для детей старше 12 лет
# refundable_support                                 NaN
# nonrefundable_support                              NaN
# budget                                             NaN
# financing_source                                   NaN
# ratings                                            7.7
# genres                                           драма
#
#                                                   44    \
# title                  Адъютант его превосходительства
# puNumber                                     211044013
# show_start_date               2013-12-19T12:00:00.000Z
# type                                    Художественный
# film_studio                      Киностудия "Мосфильм"
# production_country                                СССР
# director                                      Е.Ташков
# producer                                           NaN
# age_restriction          «6+» - для детей старше 6 лет
# refundable_support                                 NaN
# nonrefundable_support                              NaN
# budget                                             NaN
# financing_source                                   NaN
# ratings                                            8.2
# genres                       военный,приключения,драма
#
#                                                    1474  \
# title                  Адъютант его превосходительства.
# puNumber                                      111010713
# show_start_date                2013-12-19T12:00:00.000Z
# type                                     Художественный
# film_studio                       Киностудия "Мосфильм"
# production_country                                 СССР
# director                                       Е.Ташков
# producer                                            NaN
# age_restriction           «6+» - для детей старше 6 лет
# refundable_support                                  NaN
# nonrefundable_support                               NaN
# budget                                              NaN
# financing_source                                    NaN
# ratings                                             8.2
# genres                        военный,приключения,драма
#
#                                                   361   \
# title                                            Акция
# puNumber                                     111023914
# show_start_date               2014-12-24T12:00:00.000Z
# type                                    Художественный
# film_studio                      Киностудия "Мосфильм"
# production_country                                СССР
# director                                    В.Шамшурин
# producer                                           NaN
# age_restriction        «12+» - для детей старше 12 лет
# refundable_support                                 NaN
# nonrefundable_support                              NaN
# budget                                             NaN
# financing_source                                   NaN
# ratings                                            6.6
# genres                                  боевик,военный
#
#                                                     3086  \
# title                                          Анархисты
# puNumber                                       221003916
# show_start_date                 2016-02-03T12:00:00.000Z
# type                                      Художественный
# film_studio            24 Май Продюксьон, Франс 2 Синема
# production_country                               Франция
# director                                     Эли Важеман
# producer                                       Лола Гэнс
# age_restriction          «16+» - для детей старше 16 лет
# refundable_support                                   NaN
# nonrefundable_support                                NaN
# budget                                               NaN
# financing_source                                     NaN
# ratings                                              5.7
# genres                                             драма
#
#                                                     3087  \
# title                                          Анархисты
# puNumber                                       121002316
# show_start_date                 2016-02-03T12:00:00.000Z
# type                                      Художественный
# film_studio            24 Май Продюксьон, Франс 2 Синема
# production_country                               Франция
# director                                     Эли Важеман
# producer                                       Лола Гэнс
# age_restriction          «16+» - для детей старше 16 лет
# refundable_support                                   NaN
# nonrefundable_support                                NaN
# budget                                               NaN
# financing_source                                     NaN
# ratings                                              5.7
# genres                                             драма
#
#                                                                     6455  \
# title                  Анимационный фильм "Динозавр Рики", серия "Пыл...
# puNumber                                                       114008218
# show_start_date                                 2018-11-30T12:00:00.000Z
# type                                                        Анимационный
# film_studio                                   ООО "ДинозавРики продакшн"
# production_country                                                Россия
# director                                                       Е.Чернова
# producer                                             А.Колесник, И.Попов
# age_restriction                   «0+» - для любой зрительской аудитории
# refundable_support                                                   NaN
# nonrefundable_support                                                NaN
# budget                                                               NaN
# financing_source                                                     NaN
# ratings                                                              NaN
# genres                                                               NaN
#
#                                                                     6456  \
# title                  Анимационный фильм "Динозавр Рики", серия "Рем...
# puNumber                                                       114008318
# show_start_date                                 2018-11-30T12:00:00.000Z
# type                                                        Анимационный
# film_studio                                   ООО "ДинозавРики продакшн"
# production_country                                                Россия
# director                                                       Е.Чернова
# producer                                             А.Колесник, И.Попов
# age_restriction                   «0+» - для любой зрительской аудитории
# refundable_support                                                   NaN
# nonrefundable_support                                                NaN
# budget                                                               NaN
# financing_source                                                     NaN
# ratings                                                              NaN
# genres                                                               NaN
#
#                                                                     6452  \
# title                  Анимационный фильм "Динозавр Рики", серия "Спорт"
# puNumber                                                       114008418
# show_start_date                                 2018-11-30T12:00:00.000Z
# type                                                        Анимационный
# film_studio                                   ООО "ДинозавРики продакшн"
# production_country                                                Россия
# director                                                       Е.Чернова
# producer                                             А.Колесник, И.Попов
# age_restriction                   «0+» - для любой зрительской аудитории
# refundable_support                                                   NaN
# nonrefundable_support                                                NaN
# budget                                                               NaN
# financing_source                                                     NaN
# ratings                                                              NaN
# genres                                                               NaN
#
#                                                                     6454  ...  \
# title                  Анимационный фильм "Динозавр Рики", серия "Тем...  ...
# puNumber                                                       114008118  ...
# show_start_date                                 2018-11-30T12:00:00.000Z  ...
# type                                                        Анимационный  ...
# film_studio                                   ООО "ДинозавРики продакшн"  ...
# production_country                                                Россия  ...
# director                                                       Е.Чернова  ...
# producer                                             А.Колесник, И.Попов  ...
# age_restriction                   «0+» - для любой зрительской аудитории  ...
# refundable_support                                                   NaN  ...
# nonrefundable_support                                                NaN  ...
# budget                                                               NaN  ...
# financing_source                                                     NaN  ...
# ratings                                                              NaN  ...
# genres                                                               NaN  ...
#
#                                                          6371  \
# title                         Фиксики (серия "Драгоценность")
# puNumber                                            114007218
# show_start_date                      2018-11-08T12:00:00.000Z
# type                                             Анимационный
# film_studio                                    ЗАО "Аэроплан"
# production_country                                     Россия
# director                                 О.Лопато-Джагацпанян
# producer                        Г.Васильев, М.Мэннис, И.Попов
# age_restriction        «0+» - для любой зрительской аудитории
# refundable_support                                        NaN
# nonrefundable_support                                     NaN
# budget                                                    NaN
# financing_source                                          NaN
# ratings                                                   8.0
# genres                                        драма,мелодрама
#
#                                                          6167  \
# title                              Фиксики (серия "Телескоп")
# puNumber                                            114004918
# show_start_date                      2018-08-27T12:00:00.000Z
# type                                             Анимационный
# film_studio                                    ЗАО "Аэроплан"
# production_country                                     Россия
# director                                          А.Хачатурян
# producer                        Г.Васильев, М.Мэннис, И.Попов
# age_restriction        «0+» - для любой зрительской аудитории
# refundable_support                                        NaN
# nonrefundable_support                                     NaN
# budget                                                    NaN
# financing_source                                          NaN
# ratings                                                   NaN
# genres                                                    NaN
#
#                                                   326   \
# title                                   Частная жизнь_
# puNumber                                     111021914
# show_start_date               2014-12-01T12:00:00.000Z
# type                                    Художественный
# film_studio                      Киностудия "Мосфильм"
# production_country                                СССР
# director                                     Ю.Райзман
# producer                                           NaN
# age_restriction        «12+» - для детей старше 12 лет
# refundable_support                                 NaN
# nonrefundable_support                              NaN
# budget                                             NaN
# financing_source                                   NaN
# ratings                                            6.7
# genres                                   драма,комедия
#
#                                                                     581   \
# title                                         Че: Часть вторая. Партизан
# puNumber                                                       121013512
# show_start_date                                 2012-05-28T12:00:00.000Z
# type                                                      Художественный
# film_studio            Уайлд Банч, Телесинко, Лаура Бикфорд Продакшнз...
# production_country                                   США-Франция-Испания
# director                                                Стивен Содерберг
# producer                                Лаура Бикфорд, Бенисио Дель Торо
# age_restriction                          «16+» - для детей старше 16 лет
# refundable_support                                                   NaN
# nonrefundable_support                                                NaN
# budget                                                               NaN
# financing_source                                                     NaN
# ratings                                                              6.7
# genres                                           драма,военный,биография
#
#                                                                     580   \
# title                                       Че: Часть первая. Аргентинец
# puNumber                                                       121013412
# show_start_date                                 2012-05-28T12:00:00.000Z
# type                                                      Художественный
# film_studio            Уайлд Банч, Телесинко, Лаура Бикфорд Продакшнз...
# production_country                                   США-Франция-Испания
# director                                                Стивен Содерберг
# producer                                Лаура Бикфорд, Бенисио Дель Торо
# age_restriction                          «16+» - для детей старше 16 лет
# refundable_support                                                   NaN
# nonrefundable_support                                                NaN
# budget                                                               NaN
# financing_source                                                     NaN
# ratings                                                              6.8
# genres                                           драма,военный,биография
#
#                                                   319   \
# title                                  Человек родился
# puNumber                                     111022314
# show_start_date               2014-12-01T12:00:00.000Z
# type                                    Художественный
# film_studio                      Киностудия "Мосфильм"
# production_country                                СССР
# director                                   В.Ордынский
# producer                                           NaN
# age_restriction        «12+» - для детей старше 12 лет
# refundable_support                                 NaN
# nonrefundable_support                              NaN
# budget                                             NaN
# financing_source                                   NaN
# ratings                                            7.8
# genres                                 драма,мелодрама
#
#                                                                     1300  \
# title                                                          Эпидемия_
# puNumber                                                       121025713
# show_start_date                                 2013-10-07T12:00:00.000Z
# type                                                      Художественный
# film_studio            Морена Фильм, Ребелион Террестр, А 3 Медиа Гру...
# production_country                                     Испания - Франция
# director                                      Алекс Пастор, Давид Пастор
# producer                  Мерседес Гамеро, Альберто Марини, Педро Уриоль
# age_restriction                          «16+» - для детей старше 16 лет
# refundable_support                                                   NaN
# nonrefundable_support                                                NaN
# budget                                                               NaN
# financing_source                                                     NaN
# ratings                                                              7.2
# genres                                          драма,фантастика,триллер
#
#                                                                     1301  \
# title                                                          Эпидемия_
# puNumber                                                       221035513
# show_start_date                                 2013-10-07T12:00:00.000Z
# type                                                      Художественный
# film_studio            Морена Фильм, Ребелион Террестр, А 3 Медиа Гру...
# production_country                                     Испания - Франция
# director                                      Алекс Пастор, Давид Пастор
# producer                  Мерседес Гамеро, Альберто Марини, Педро Уриоль
# age_restriction                          «16+» - для детей старше 16 лет
# refundable_support                                                   NaN
# nonrefundable_support                                                NaN
# budget                                                               NaN
# financing_source                                                     NaN
# ratings                                                              7.2
# genres                                          драма,фантастика,триллер
#
#                                                   6379  \
# title                                     Ян Антонышев
# puNumber                                     112011818
# show_start_date               2018-11-15T12:00:00.000Z
# type                                    Документальный
# film_studio                                        NaN
# production_country                              Россия
# director                                     Е.Окопная
# producer                                   Е.Герасимов
# age_restriction        «12+» - для детей старше 12 лет
# refundable_support                                 NaN
# nonrefundable_support                              NaN
# budget                                             NaN
# financing_source                                   NaN
# ratings                                            NaN
# genres                                             NaN
#
#                                                   6380
# title                                     Ян Антонышев
# puNumber                                     112011918
# show_start_date               2018-11-15T12:00:00.000Z
# type                                    Документальный
# film_studio                                        NaN
# production_country                              Россия
# director                                     Е.Окопная
# producer                                   Е.Герасимов
# age_restriction        «12+» - для детей старше 12 лет
# refundable_support                                 NaN
# nonrefundable_support                              NaN
# budget                                             NaN
# financing_source                                   NaN
# ratings                                            NaN
# genres                                             NaN
#
# [15 rows x 128 columns]

# %% [markdown]
# **Выводы:**
#
# Есть явные дубликаты. Программа их не видит по причине наличия разных регистров, пункутации, пробелов и т.д.
#
# После чистки через функцию обрезания+удаление пункуации, почисти от явных дубликатов.

# %% [markdown]
# ### Наблюдение:
#
# На сайте можно заметить категориальность первых цифр в прокатных удостоврениях:
# * Первые две цифры 1_ или 12 говорят нам о том, что фильм будут показывать только в кионотеатрах и смешанный тип трансляции (кинотеатр, кафе, ТВ, в интернете и т.д.) соответсвенно
# * Первая пара цифр 22 - показ фильмов не в кинотеартрах
#
# В дальнейшем анализе `box_office` данных важно отбросить удостоврения больше или равные 22______, если мы будем рассматривать только **_прокат_**

# %%
# найдем количество непрокатных данных
df_movies[df_movies['puNumber'] >= '220_000_000'].shape[0]
# Out:
# 1132

# %%
# найдем процент непрокатных данных 
# от общего количества данных
print(f"{round(len(df_movies[df_movies['puNumber'] >= '200000000'])/len(df_movies['puNumber'])*100,1)}%")
# Out:
# 16.6%

# %%
# создаем список для дальнейших манипуляции с элементами
list_to_change = []

# %%
# Создаем функцию для обработки строк, чтобы исправить
# нераспознаваемые прогораммой дубликаты
# и подсчитать успех -
# - количество выявленных неявных дубликатов
def check_func_dup(row,column):
    print(column)
    len_without_func= len(row[column].value_counts())
    len_with_func = len(row[column]
                     .str.lower()
                     .str.strip('#$%&\*+,-./:;<=>@[\]^_`{|}~ ')
                     .value_counts()
                    )
    difference = len_without_func-len_with_func
    print(f'Без применения функции: {len_without_func}')
    print(f'С функцией: {len_with_func}')
    print(f'Разница между без функции и с функцией: {difference}')
    if difference != 0:
        print(f'''В столбце {column} присутствует прогресс в поиске дубликатов и аномалий в количестве: {difference} шт.''')
        list_to_change.append(column)
    print('-'*50)

# %%
# список столбцов со строчными значениями 
# для применения функции
str_list = (['title',
             'type',
             'film_studio',
             'production_country',
             'director',
             'producer',
             'financing_source',
             'age_restriction',
             'genres'])

# %%
# функция, которая применяет функцию check_func_dup
def check_all(column):
    check_func_dup(df_movies,column)

# %%
list(map(check_all,str_list))
# Out:
# title
# Без применения функции: 6772
# С функцией: 6655
# Разница между без функции и с функцией: 117
# В столбце title присутствует прогресс в поиске дубликатов и аномалий в количестве: 117 шт.
# --------------------------------------------------
# type
# Без применения функции: 8
# С функцией: 6
# Разница между без функции и с функцией: 2
# В столбце type присутствует прогресс в поиске дубликатов и аномалий в количестве: 2 шт.
# --------------------------------------------------
# film_studio
# Без применения функции: 5490
# С функцией: 5420
# Разница между без функции и с функцией: 70
# В столбце film_studio присутствует прогресс в поиске дубликатов и аномалий в количестве: 70 шт.
# --------------------------------------------------
# production_country
# Без применения функции: 950
# С функцией: 933
# Разница между без функции и с функцией: 17
# В столбце production_country присутствует прогресс в поиске дубликатов и аномалий в количестве: 17 шт.
# --------------------------------------------------
# director
# Без применения функции: 4811
# С функцией: 4795
# Разница между без функции и с функцией: 16
# В столбце director присутствует прогресс в поиске дубликатов и аномалий в количестве: 16 шт.
# --------------------------------------------------
# producer
# Без применения функции: 5349
# С функцией: 5326
# Разница между без функции и с функцией: 23
# В столбце producer присутствует прогресс в поиске дубликатов и аномалий в количестве: 23 шт.
# --------------------------------------------------
# financing_source
# Без применения функции: 3
# С функцией: 3
# Разница между без функции и с функцией: 0
# --------------------------------------------------
# age_restriction
# Без применения функции: 5
# С функцией: 5
# Разница между без функции и с функцией: 0
# --------------------------------------------------
# genres
# Без применения функции: 742
# С функцией: 742
# Разница между без функции и с функцией: 0
# --------------------------------------------------
# [None, None, None, None, None, None, None, None, None]

# %%
list_to_change
# Out:
# ['title', 'type', 'film_studio', 'production_country', 'director', 'producer']

# %%
# функция для описательной статистики 
def describe(row,column):
    return print(row[column].describe())

# %%
# функция для value_counts
def value_counts(row,column):
    return row[column].value_counts()

# %%
df_movies.columns
# Out:
# Index(['title', 'puNumber', 'show_start_date', 'type', 'film_studio',
#        'production_country', 'director', 'producer', 'age_restriction',
#        'refundable_support', 'nonrefundable_support', 'budget',
#        'financing_source', 'ratings', 'genres'],
#       dtype='object')

# %%
# выявляем значения максимальное и делим на 1_000_000
def maximus(row):
    maxim = max(map(int,row.dropna()))
    return maxim//1_000_000

# %%
# смотрим сколько значнеий больше 1 млрд. и что это за значения
c = 0
for i in [int(i) for i in list(map(int,df_movies[df_movies['budget'].isna() == False]['budget']))]:
    if (i//1_000_000) > 1_000:
        print(i//1000)
        c += 1
print(f'Количество фильмов, у которых бюджет больше 1 млрд. рублей: {c}')
billion_budget_percent = c/df_movies['budget'].shape[0]* 100
print(f"Процент фильмов миллиардников от общего количества строк {billion_budget_percent:.3f}%")
# Out:
# 1032905
# 2305074
# Количество фильмов, у которых бюджет больше 1 млрд. рублей: 2
# Процент фильмов миллиардников от общего количества строк 0.027%

# %%
# смотрим сколько значнеий больше 500 млн. и что это за значения
k = 0
for i in [int(i) for i in list(map(int,df_movies[df_movies['budget'].isna() == False]['budget']))]:
    if (i//1_000_000) > 500 and (i//1_000_000) < 1_000:
        print(i//1_000_000)
        k += 1
print(f'Количество фильмов, у которых бюджет больше 500 млн. рублей: {k}')
half_billion_budget_percent = k/df_movies['budget'].shape[0]* 100
more_than_half_billion = billion_budget_percent +  half_billion_budget_percent
print(f"Процент фильмов полумиллиардников и миллиардников от общего количества строк: {more_than_half_billion:.3f}%")
# Out:
# 635
# 528
# 684
# 590
# 563
# 779
# 980
# 944
# Количество фильмов, у которых бюджет больше 500 млн. рублей: 8
# Процент фильмов полумиллиардников и миллиардников от общего количества строк: 0.134%

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7486 entries, 0 to 7485
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7486 non-null   object
#  2   show_start_date        7486 non-null   object
#  3   type                   7486 non-null   object
#  4   film_studio            7468 non-null   object
#  5   production_country     7484 non-null   object
#  6   director               7477 non-null   object
#  7   producer               6918 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   object
#  14  genres                 6510 non-null   object
# dtypes: float64(3), object(12)
# memory usage: 877.4+ KB

# %% [markdown]
# ### Общий вывод по df_movie
#
# #### Название столбцов:
# В общем и целом, названия столбцов можно оставить и такими. Однако для удобства, читаемости и соблюдения аккуратности кода поменяем `puNumber` на `c_number`, где `c` ≡  `certificate`
#
# ***
#
# #### Типы даных:
# Из таблицы видно, что нужно заменить тип у столбцов:
# 1. `puNumber` - заменим на тип `int64`.
# 2. `show_start_date` - привести к типу `datetime`.
# 3. `age_restriction` - провести категориальную замену для удобства, но в числах.
#     - 18+ => 18
#     - 16+ => 16
#     - 6+ => 6
#     - 0+ => 0
# 4. `refundable_support` - приведем к типу `int64`.
# 5. `nonrefundable_support` - приведем к типу `int64`.
# 6. `budget` - заменим на тип `int64`.
# 7. `ratings` - заменим на тип `float64`. Посмотрим, нужно ли округлять значения до десятых.
#
# ***
#
# #### Пропущенные значения:
# * `film_studio` - Процент пропусков:0.2%.
# * `production_country` - Процент пропусков:0.03%.
# * `director` - Процент пропусков:0.1%.
# * `producer` - Процент пропусков:7.6%.
# * `refundable_support` - Процент пропусков:95.6%.
# * `nonrefundable_support` - Процент пропусков:95.6%. `refundable_support`
# * `budget` - Процент пропусков:95.6%.
# * `financing_source` - Процент пропусков:95.6%.
# * `ratings` - Процент пропусков:12.9%.
# * `genres` - Процент пропусков:13%.
#
# ###### Единственный вариант заполнения пропусков в этом случае - это значение заглушка. Можно было бы через парсинг достать остальные данные. Но поскольку мы не используем это в предсказании, а хотим сделать точный анализ данных, то нужно оставить данные пропуски, чтобы данные были первозданными.
#
# ***
#
# ###### Поскольку в столбце `budget` хранятся данные только о фильмах, которые получили государственную поддержку, то в столбце `financing_source` нужно будет поставить категориальное значение-заглушку - `none`, а в столбцах `refundable_support`, `nonrefundable_support`, `budget` значение заглушка будет иметь вид `0`
#
# ***
#
# ###### Вероятнее всего категориальная замена развяжет нам руки и поможет проанализировать данные намного эффективнее..
#
# ***
#
# ##### Дополнительные категорильные столбцы:
# Возможно, для лучшего анализа нам нужно будет создать категориальные столбца относительно:
# * `refundable_gov_sup_ratio` и `nonrefundable_gov_sup_ratio` - главная идея в этих столбцах обстоит в том, чтобы отобразить в них процент возврата и невозврата бюджетны средств.
#
#
# ***
#
# #### Дубликаты:
#
# Явных дубликатов не выявлено.
#
# ***
#
# #### Артефакты, аномалии и неявные дубликаты:
#
# * В столбце `title` присутствуют артефакты - различные пункутационные знаки - в количестве - 117 шт. Очистим их при помощи функции - приведем все к нижнему регистру, очистим при помощи `strip()` конец и начало строк и проверим.
# * В столбце `puNumber` есть одна аномалия ввиде строки 'нет'. По режиссеру и фильму совпадают строки 1797 и 2078 - стоит отбросить строку, в которой нет прокатного удостоверения. Других артефактов не выявлено.
# * В столбце `type` замечены несерьезные артефакты в количестве - 2 шт.(Избавимся от них при помощи привода к нижнему регистру и обрезания пробелов - `strip()`):
#     - `Художественный` и `_Художественный`, где `_` - пробел
#     - `Анимационный` и `_Анимационный`, где `_` - пробел
# * В столбце `film_studio` замечены артефакты-аномалии - некоторые строки при первичном взгляде кажущимися идентичными `value_counts()` считает разными. Проведем такие операции как со столбцом `title`. В итоге, получим количество неявных дубликатов - 70 шт.
#
# * В столбце `production_country` были выявлены неявные дубликаты или аномалии в размере 17 шт.
# * В столбце `director` обнаружено 16 шт. неявных дубликатов, к этому количеству нужно прибавить строки в полными именами - Вася Пупкин и с сокращенными В.Пупкин.
# * В столбце `producer` 23 шт. неявных дубликатов. Здесь такая же проблема как и в столбце `director`.
# * В столбце `ratings` обнаружены артефакты: рейтинг указан в 100% шкале. Переведем проценты в 10-ти балльную шкалу.
#
# В столбцах, где присутвуют строчные элементы, проведем замену на нижний регистр, чтобы найти возможные дубликаты и избавиться от аномалий
#
# Также пытались найти неявные дубликаты относительно других комбинаций столбвоц, но поскольку прокатные удостоверения в бОльшей части своей уникальны, то их не обнаружилось.
#
# Неявные дубликаты вида В.Пупкин и Вася Пупкин попробуем почистить после конкатенции таблиц
#
#
# ***

# %% [markdown]
# ## Анализ df_shows

# %%
# анализируем df_shows
pre_view(df_shows)
# Out:
# First 4 row(s) in the head of data
#     puNumber   box_office
# 0  111000113       2450.0
# 1  111000115      61040.0
# 2  111000116  153030013.4
# 3  111000117   12260956.0
# ------------------------------
# Data Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3158 entries, 0 to 3157
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   puNumber    3158 non-null   int64
#  1   box_office  3158 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 49.5 KB
# None
# ------------------------------
# Data columns:
# Index(['puNumber', 'box_office'], dtype='object')
# ------------------------------
# Data shape:
# (3158, 2)
# ------------------------------
# Data isna by row mean:
# puNumber      0.0
# box_office    0.0
# dtype: float64
# ------------------------------
# Data clear duplicates sum:
# puNumber      0.0
# box_office    0.0
# dtype: float64
# ------------------------------

# %%
# описательная статистика 
describe(df_shows,'box_office')
# Out:
# count    3.158000e+03
# mean     7.647870e+07
# std      2.403531e+08
# min      0.000000e+00
# 25%      8.623900e+04
# 50%      2.327988e+06
# 75%      2.397967e+07
# max      3.073569e+09
# Name: box_office, dtype: float64

# %%
# Проверяем, есть ли значения box_office равные 0
df_shows[df_shows['box_office'] == 0]
# Out:
#        puNumber  box_office
# 83    111001610         0.0
# 104   111002015         0.0
# 117   111002414         0.0
# 144   111003012         0.0
# 277   111005910         0.0
# 319   111006712         0.0
# 341   111007114         0.0
# 363   111007613         0.0
# 453   111009614         0.0
# 463   111009815         0.0
# 503   111011013         0.0
# 588   111013915         0.0
# 654   111017116         0.0
# 1030  121002614         0.0
# 1345  121008610         0.0
# 1505  121011614         0.0
# 1572  121013014         0.0
# 1652  121014613         0.0
# 1919  121020210         0.0
# 2333  121027712         0.0
# 2503  121031913         0.0
# 2782  124002812         0.0
# 2789  124002912         0.0
# 3106  131000213         0.0

# %% [markdown]
# ### Общий вывод по df_shows
# #### Название столбцов:
# В общем и целом, названия столбцов можно оставить и такими. Однако для удобства, читаемости и соблюдения аккуратности кода поменяем `puNumber` на `c_number`, где `c` ≡ `certificate`. Также `box_office` припишем `rub`, чтобы было понятно с какой валютой мы имеем дело. Все переименования сделаем после объединения таблиц.
#
# ***
#
# #### Типы даных:
# Из таблицы видно, что нужно заменить тип у столбцов:
# 1. `puNumber` - заменим на тип `int64`.
# 2. `budget` - заменим на тип `int64`.
#
# ***
#
# #### Пропущенные значения:
#
# Пропущенных значений нет
#
# ***
#
# #### Дубликаты:
#
# Явных дубликатов не выявлено.
#
# ***
#
# #### Артефакты, аномалии и неявные дубликаты:
#
# В столбце `box_office` присутствуют аномалии ввиде нулевых значений. Можем просто отбросить их при ИАД прокатных сборов, а можем оставить, делая допущение, что фильмы на самом деле ничего не собрали в прокате.
#
# ***

# %% [markdown]
# ## Очистка данных в df_movies

# %%
# освежаем в памяти, что нужно сделать
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7486 entries, 0 to 7485
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7486 non-null   object
#  2   show_start_date        7486 non-null   object
#  3   type                   7486 non-null   object
#  4   film_studio            7468 non-null   object
#  5   production_country     7484 non-null   object
#  6   director               7477 non-null   object
#  7   producer               6918 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   object
#  14  genres                 6510 non-null   object
# dtypes: float64(3), object(12)
# memory usage: 877.4+ KB

# %%
# функция для изменения типа столбца
def to_date_func(column):
    df_movies[column] = pd.to_datetime(df_movies[column], format='%Y-%m-%dT%H:%M:%S')

# %%
# функция для удаление не нужных знаков
def del_z(row):
    return row.replace('.000Z','')

# %%
# для начало ищем индекс той строки
anomaly_net_index= df_movies.loc[df_movies['puNumber']=='нет'].index[0]

# %%
# посмотрим, какой индекс у этой строки
anomaly_net_index
# Out:
# 1797

# %%
# выведем размер исходой таблицы для дальнейшей проверки
df_movies.shape[0]
# Out:
# 7486

# %%
# Удаляем аномальную строку
df_movies = df_movies.drop(df_movies.index[[anomaly_net_index]])

# %%
# проверка
df_movies[df_movies['puNumber']=="нет"]
# Out:
# Empty DataFrame
# Columns: [title, puNumber, show_start_date, type, film_studio, production_country, director, producer, age_restriction, refundable_support, nonrefundable_support, budget, financing_source, ratings, genres]
# Index: []

# %%
df_movies[df_movies['production_country'] == '2019']
# Out:
#              title   puNumber           show_start_date             type  \
# 7247  Дело Коллини  121027219  2019-09-19T12:00:00.000Z   Художественный
#
#                                             film_studio production_country  \
# 7247  Константин Филм, Глобал Скрин, Севен Пикчерз Сван               2019
#
#                  director                                           producer  \
# 7247  Марко Кройцпайнтнер  Мартин Московиц, Кристоф Мюллер, Марсель Хартг...
#
#                       age_restriction  refundable_support  \
# 7247  «16+» - для детей старше 16 лет                 NaN
#
#       nonrefundable_support  budget financing_source ratings  \
# 7247                    NaN     NaN              NaN     7.4
#
#                        genres
# 7247  детектив,драма,криминал

# %%
anomaly_country_index = df_movies[df_movies['production_country'] == '2019'].index[0]

# %%
anomaly_country_index
# Out:
# 7247

# %%
# удалим аномалию в строке, где столбец
# production_country равен 2019
df_movies = df_movies.drop(df_movies.index[[anomaly_country_index]])

# %%
# обновляем индекс в табилце 
df_movies.reset_index(inplace=True)

# %%
# проверка
df_movies[df_movies['production_country'] == '2019']
# Out:
#       index         title   puNumber           show_start_date  \
# 7246   7247  Дело Коллини  121027219  2019-09-19T12:00:00.000Z
#
#                  type                                        film_studio  \
# 7246   Художественный  Константин Филм, Глобал Скрин, Севен Пикчерз Сван
#
#      production_country             director  \
# 7246               2019  Марко Кройцпайнтнер
#
#                                                producer  \
# 7246  Мартин Московиц, Кристоф Мюллер, Марсель Хартг...
#
#                       age_restriction  refundable_support  \
# 7246  «16+» - для детей старше 16 лет                 NaN
#
#       nonrefundable_support  budget financing_source ratings  \
# 7246                    NaN     NaN              NaN     7.4
#
#                        genres
# 7246  детектив,драма,криминал

# %%
# выбираем дальнейший столбец для обработки
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7484 entries, 0 to 7483
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   index                  7484 non-null   int64
#  1   title                  7484 non-null   object
#  2   puNumber               7484 non-null   object
#  3   show_start_date        7484 non-null   object
#  4   type                   7484 non-null   object
#  5   film_studio            7466 non-null   object
#  6   production_country     7482 non-null   object
#  7   director               7475 non-null   object
#  8   producer               6916 non-null   object
#  9   age_restriction        7484 non-null   object
#  10  refundable_support     332 non-null    float64
#  11  nonrefundable_support  332 non-null    float64
#  12  budget                 332 non-null    float64
#  13  financing_source       332 non-null    object
#  14  ratings                6518 non-null   object
#  15  genres                 6509 non-null   object
# dtypes: float64(3), int64(1), object(12)
# memory usage: 935.6+ KB

# %%
# Проверим на округление
def num_a_got(row):
    s = set()
    try:
        s.add(len(str(row['ratings']).split('.')[1]))
        return max(s)
    except IndexError as inderr:
        pass

# %%
# Применим и посмотрим
max(df_movies.apply(num_a_got,axis=1))
# Out:
# 1.0

# %% [markdown]
# **Вывод:**
#
# Округлять не нужно, поскольку максимальное количество знаков после запятой - `1`

# %%
# запишем в list_to_int столбцы
# тип который поменяем на int и 
# заполним пропуски 0
list_to_int = ['puNumber','refundable_support','nonrefundable_support','budget']

# %%
list_to_int
# Out:
# ['puNumber', 'refundable_support', 'nonrefundable_support', 'budget']

# %%
# функция для заполнения пропусков нулями
def fill_na_0(row,column):
    return row[column].fillna(value=0,inplace=True)

# %%
# для проверки
df_movies.isna().mean()
# Out:
# index                    0.000000
# title                    0.000000
# puNumber                 0.000000
# show_start_date          0.000000
# type                     0.000000
# film_studio              0.002405
# production_country       0.000267
# director                 0.001203
# producer                 0.075895
# age_restriction          0.000000
# refundable_support       0.955639
# nonrefundable_support    0.955639
# budget                   0.955639
# financing_source         0.955639
# ratings                  0.129075
# genres                   0.130278
# dtype: float64

# %%
# заполняем 0
fill_na_0(df_movies,'refundable_support')

# %%
fill_na_0(df_movies,'nonrefundable_support')

# %%
fill_na_0(df_movies,'budget')

# %%
# проверка
df_movies.isna().mean()
# Out:
# index                    0.000000
# title                    0.000000
# puNumber                 0.000000
# show_start_date          0.000000
# type                     0.000000
# film_studio              0.002405
# production_country       0.000267
# director                 0.001203
# producer                 0.075895
# age_restriction          0.000000
# refundable_support       0.000000
# nonrefundable_support    0.000000
# budget                   0.000000
# financing_source         0.955639
# ratings                  0.129075
# genres                   0.130278
# dtype: float64

# %%
# функция приводящая к типу int
def to_int64(column):
    try:
        df_movies[column] = df_movies[column].astype('int',errors='raise')
    except Exception as ex:
        print(ex)

# %%
# для проверки
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7484 entries, 0 to 7483
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   index                  7484 non-null   int64
#  1   title                  7484 non-null   object
#  2   puNumber               7484 non-null   object
#  3   show_start_date        7484 non-null   object
#  4   type                   7484 non-null   object
#  5   film_studio            7466 non-null   object
#  6   production_country     7482 non-null   object
#  7   director               7475 non-null   object
#  8   producer               6916 non-null   object
#  9   age_restriction        7484 non-null   object
#  10  refundable_support     7484 non-null   float64
#  11  nonrefundable_support  7484 non-null   float64
#  12  budget                 7484 non-null   float64
#  13  financing_source       332 non-null    object
#  14  ratings                6518 non-null   object
#  15  genres                 6509 non-null   object
# dtypes: float64(3), int64(1), object(12)
# memory usage: 935.6+ KB

# %%
# поменяем на инт
for i in list_to_int:
    to_int64(f'{i}')

# %%
# проверка
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7484 entries, 0 to 7483
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   index                  7484 non-null   int64
#  1   title                  7484 non-null   object
#  2   puNumber               7484 non-null   int32
#  3   show_start_date        7484 non-null   object
#  4   type                   7484 non-null   object
#  5   film_studio            7466 non-null   object
#  6   production_country     7482 non-null   object
#  7   director               7475 non-null   object
#  8   producer               6916 non-null   object
#  9   age_restriction        7484 non-null   object
#  10  refundable_support     7484 non-null   int32
#  11  nonrefundable_support  7484 non-null   int32
#  12  budget                 7484 non-null   int32
#  13  financing_source       332 non-null    object
#  14  ratings                6518 non-null   object
#  15  genres                 6509 non-null   object
# dtypes: int32(4), int64(1), object(11)
# memory usage: 818.7+ KB

# %%
# для проверки
df_movies['show_start_date']
# Out:
# 0       2015-11-27T12:00:00.000Z
# 1       2016-09-13T12:00:00.000Z
# 2       2016-10-10T12:00:00.000Z
# 3       2016-06-10T12:00:00.000Z
# 4       2015-07-29T12:00:00.000Z
#                   ...
# 7479    2019-12-23T12:00:00.000Z
# 7480    2019-12-24T12:00:00.000Z
# 7481    2019-12-28T12:00:00.000Z
# 7482    2019-12-30T12:00:00.000Z
# 7483    2019-12-30T12:00:00.000Z
# Name: show_start_date, Length: 7484, dtype: object

# %%
# удаляем не нужные символы из строк с датой
df_movies['show_start_date'] = list(map(del_z,df_movies['show_start_date']))

# %%
# проверяем
df_movies['show_start_date']
# Out:
# 0       2015-11-27T12:00:00
# 1       2016-09-13T12:00:00
# 2       2016-10-10T12:00:00
# 3       2016-06-10T12:00:00
# 4       2015-07-29T12:00:00
#                ...
# 7479    2019-12-23T12:00:00
# 7480    2019-12-24T12:00:00
# 7481    2019-12-28T12:00:00
# 7482    2019-12-30T12:00:00
# 7483    2019-12-30T12:00:00
# Name: show_start_date, Length: 7484, dtype: object

# %%
# приводим к типу datetime
to_date_func('show_start_date')

# %%
# проверяем
df_movies['show_start_date']
# Out:
# 0      2015-11-27 12:00:00
# 1      2016-09-13 12:00:00
# 2      2016-10-10 12:00:00
# 3      2016-06-10 12:00:00
# 4      2015-07-29 12:00:00
#                ...
# 7479   2019-12-23 12:00:00
# 7480   2019-12-24 12:00:00
# 7481   2019-12-28 12:00:00
# 7482   2019-12-30 12:00:00
# 7483   2019-12-30 12:00:00
# Name: show_start_date, Length: 7484, dtype: datetime64[ns]

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7484 entries, 0 to 7483
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   index                  7484 non-null   int64
#  1   title                  7484 non-null   object
#  2   puNumber               7484 non-null   int32
#  3   show_start_date        7484 non-null   datetime64[ns]
#  4   type                   7484 non-null   object
#  5   film_studio            7466 non-null   object
#  6   production_country     7482 non-null   object
#  7   director               7475 non-null   object
#  8   producer               6916 non-null   object
#  9   age_restriction        7484 non-null   object
#  10  refundable_support     7484 non-null   int32
#  11  nonrefundable_support  7484 non-null   int32
#  12  budget                 7484 non-null   int32
#  13  financing_source       332 non-null    object
#  14  ratings                6518 non-null   object
#  15  genres                 6509 non-null   object
# dtypes: datetime64[ns](1), int32(4), int64(1), object(10)
# memory usage: 818.7+ KB

# %%
# считает количество аномалий в столбце raitings
df_movies['ratings'].str.count('%').sum()
# Out:
# 29.0

# %%
# создаем функцию, проверяющую, можно ли 
# перевести к типу float
def isfloat(num):
    try:
        float(num)
        return True
    except Exception as ex:
        return False

# %%
# сколько всего элементов
# которые не могут быть переведены во float
# и через list comprehension
# задаем срез без знака "%"
len([int(x[:2])/10 for x in df_movies['ratings'] if isfloat(x) == False])
# Out:
# 29

# %%
# функция, проверяющая, есть ли в строке
# знак "%", если есть, то заменяет
# на пустую строку, переводит в int и делит на 10
# иначе переводит в тип float
def replace_n_float(row):
    for i in row:
        if '%' in i:
            i = int(i.replace('%',''))/10
            return i
        return float(i)

# %%
# заменяем NaN "0.0"
df_movies['ratings'].fillna(value='0.0',inplace=True)

# %%
# выполняем функцию по замене аномалий
df_movies['ratings'] = df_movies['ratings'].apply(replace_n_float)

# %%
# проверка
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7484 entries, 0 to 7483
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   index                  7484 non-null   int64
#  1   title                  7484 non-null   object
#  2   puNumber               7484 non-null   int32
#  3   show_start_date        7484 non-null   datetime64[ns]
#  4   type                   7484 non-null   object
#  5   film_studio            7466 non-null   object
#  6   production_country     7482 non-null   object
#  7   director               7475 non-null   object
#  8   producer               6916 non-null   object
#  9   age_restriction        7484 non-null   object
#  10  refundable_support     7484 non-null   int32
#  11  nonrefundable_support  7484 non-null   int32
#  12  budget                 7484 non-null   int32
#  13  financing_source       332 non-null    object
#  14  ratings                7484 non-null   float64
#  15  genres                 6509 non-null   object
# dtypes: datetime64[ns](1), float64(1), int32(4), int64(1), object(9)
# memory usage: 818.7+ KB

# %%
# Проверка
df_movies['ratings'].value_counts()
# Out:
# 6.0    2407
# 7.0    1934
# 5.0    1182
# 0.0     966
# 4.0     400
# 8.0     395
# 3.0     123
# 2.0      37
# 9.0      20
# 1.0      20
# Name: ratings, dtype: int64

# %%
# функция, заменяющая NaN
# значением заглушкой 'unknown'
def stub(row):
    return row.fillna(value='unknown',inplace=True)

# %%
# список для 
unknown_list = []

# %%
# находим столбцы с NaN
# добавляем в unknown_list
for i in df_movies.columns:
    if df_movies[i].isna().mean() != 0:
        unknown_list.append(i)

# %%
unknown_list
# Out:
# ['film_studio',
#  'production_country',
#  'director',
#  'producer',
#  'financing_source',
#  'genres']

# %%
# для проверки
(df_movies.isna().mean() != 0).sum()
# Out:
# 6

# %%
#  ставим значение-заглушку
for i in unknown_list:
    df_movies[i].fillna(value='unknown',inplace=True)

# %%
# проверка
(df_movies.isna().mean() != 0).sum()
# Out:
# 0

# %%
# проверка
df_movies.query('genres == "unknown"')
# Out:
#       index                                             title   puNumber  \
# 43       43          Мемуары гейши (по роману Артура Голдена)  121000606
# 150     150                                          Жди меня  111013615
# 154     154  Дом из песка и тумана (по книге Андре Дюбуи III)  221037813
# 159     159                                 Жемчужная девушка  224011014
# 227     227                                        Полустанок  111026714
# ...     ...                                               ...        ...
# 7477   7479                                            Эколав  111023219
# 7478   7480                   Акрам Хан: Родом из Карри Хауса  126007919
# 7479   7481         Сад художника: Американский импрессионизм  126008019
# 7481   7483         Щенячий патруль: Скорей спешим на помощь!  124010819
# 7482   7484          Машины песенки. Серия "Испанские мотивы"  124010619
#
#          show_start_date             type  \
# 43   2012-12-14 12:00:00   Художественный
# 150  2015-08-25 12:00:00   Художественный
# 154  2013-10-25 12:00:00   Художественный
# 159  2014-08-28 12:00:00   Художественный
# 227  2014-12-24 12:00:00   Художественный
# ...                  ...              ...
# 7477 2019-12-26 12:00:00   Художественный
# 7478 2019-12-23 12:00:00           Прочие
# 7479 2019-12-23 12:00:00           Прочие
# 7481 2019-12-28 12:00:00   Художественный
# 7482 2019-12-30 12:00:00     Анимационный
#
#                                             film_studio  \
# 43    Коламбия Пикчерз Корпорейшн, ДримУоркс ЭсКейДж...
# 150                               Киностудия "Мосфильм"
# 154                                     Кобальт Пикчерз
# 159   Чешское телевидение,Студия "Три брата" агентск...
# 227                               Киностудия "Мосфильм"
# ...                                                 ...
# 7477                                               ВГИК
# 7478                                         Свон Филмз
# 7479                               Севен Артс Продакшнз
# 7481           Никелодеон Анимейшн Студиос, Спин Мастер
# 7482           Анимаккорд Лтд., ООО Студия "АНИМАККОРД"
#
#            production_country             director  \
# 43                        США          Роб Маршалл
# 150                      СССР  А.Столпер, Б.Иванов
# 154                       США      Вадим Перельман
# 159                     Чехия        Владимир Дрга
# 227                      СССР             Б.Барнет
# ...                       ...                  ...
# 7477                   Россия          Д.Григорьев
# 7478           Великобритания            Ник Пойнц
# 7479           Великобритания          Фил Грабски
# 7481             США - Канада     Чарльз Е.Бастьен
# 7482  Республика Кипр, Россия             А.Беляев
#
#                                                producer  \
# 43    Стивен Спилберг, Люси Фишер, Дуглас Уик, Джон ...
# 150                                             unknown
# 154                                        Майкл Лондон
# 159                                             unknown
# 227                                             unknown
# ...                                                 ...
# 7477                                               ВГИК
# 7478                             Поппи Бегум, Ник Пойнц
# 7479                                        Фил Грабски
# 7481                                     Дженнифер Додж
# 7482                                          Д.Ловейко
#
#                              age_restriction  refundable_support  \
# 43           «12+» - для детей старше 12 лет                   0
# 150            «6+» - для детей старше 6 лет                   0
# 154          «16+» - для детей старше 16 лет                   0
# 159   «0+» - для любой зрительской аудитории                   0
# 227          «12+» - для детей старше 12 лет                   0
# ...                                      ...                 ...
# 7477             «18+» - запрещено для детей                   0
# 7478         «12+» - для детей старше 12 лет                   0
# 7479         «12+» - для детей старше 12 лет                   0
# 7481  «0+» - для любой зрительской аудитории                   0
# 7482  «0+» - для любой зрительской аудитории                   0
#
#       nonrefundable_support  budget financing_source  ratings   genres
# 43                        0       0          unknown      0.0  unknown
# 150                       0       0          unknown      0.0  unknown
# 154                       0       0          unknown      0.0  unknown
# 159                       0       0          unknown      0.0  unknown
# 227                       0       0          unknown      0.0  unknown
# ...                     ...     ...              ...      ...      ...
# 7477                      0       0          unknown      0.0  unknown
# 7478                      0       0          unknown      0.0  unknown
# 7479                      0       0          unknown      0.0  unknown
# 7481                      0       0          unknown      0.0  unknown
# 7482                      0       0          unknown      0.0  unknown
#
# [975 rows x 16 columns]

# %%
# импортируем пунктуацию из бибилотеки string
from string import punctuation
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
# отбираем нужные символы и создаем переменную spaces
# кол-во пробелов = len(punct)
punct = '#$%&\*+,-./:;<=>@[\]^_`{|}~'
spaces = '                           '

# %%
# создаем функцию, которая очищает 
# и приводит к одному типу все строки
def anti_duplet(column):
    df_movies[column] = (df_movies[column]
                         .str.lower()
                         .str.strip('#$%&\*+,-./:;<=>@[\]^_`{|}~ ')
                        )

# %%
# создаем список столбцов, к которым применим
# функцию anti_duplet
implicit_duplicate_list = []

# %%
# добавляем в список нужные названия столбцов
for i in df_movies.columns:  
    if type(df_movies[i][1]) == str and i != 'age_restriction':
        implicit_duplicate_list.append(i)

# %%
#  выводим список
print(*implicit_duplicate_list,end=' ')
# Out:
# title type film_studio production_country director producer financing_source genres

# %%
# Для проверки смотри на неявне дубликаты 
# в названии
df_movies.query('title.str.contains("шапочка")', engine='python')
# Out:
#       index                    title   puNumber     show_start_date  \
# 4019   4020       Красная шапочка __  121003711 2011-03-14 12:00:00
# 4993   4994       Красная шапочка __  221072611 2011-05-30 12:00:00
# 5019   5020       Красная шапочка __  221098811 2011-09-19 12:00:00
# 6048   6049  Красная шапочка. Онлайн  111012018 2018-09-27 12:00:00
#
#                  type                               film_studio  \
# 4019   Художественный  Аппиан Вэй, Рэндом Филмз, Уорнер Бразерс
# 4993   Художественный  Аппиан Вэй, Рэндом Филмз, Уорнер Бразерс
# 5019   Художественный  Аппиан Вэй, Рэндом Филмз, Уорнер Бразерс
# 6048   Художественный                       РОО ЭКЦ "Новый дар"
#
#      production_country        director  \
# 4019       США - Канада  Кэтрин Хардвик
# 4993       США - Канада  Кэтрин Хардвик
# 5019       США - Канада  Кэтрин Хардвик
# 6048             Россия     Н.Бондарчук
#
#                                              producer  \
# 4019  Дженнифер Дэвиссон Киллоран, Леонардо Ди Каприо
# 4993  Дженнифер Дэвиссон Киллоран, Леонардо Ди Каприо
# 5019  Дженнифер Дэвиссон Киллоран, Леонардо Ди Каприо
# 6048                                        В.Федоров
#
#                              age_restriction  refundable_support  \
# 4019         «16+» - для детей старше 16 лет                   0
# 4993         «16+» - для детей старше 16 лет                   0
# 5019         «16+» - для детей старше 16 лет                   0
# 6048  «0+» - для любой зрительской аудитории                   0
#
#       nonrefundable_support  budget financing_source  ratings  \
# 4019                      0       0          unknown      6.0
# 4993                      0       0          unknown      6.0
# 5019                      0       0          unknown      6.0
# 6048                      0       0          unknown      0.0
#
#                      genres
# 4019  ужасы,фэнтези,триллер
# 4993  ужасы,фэнтези,триллер
# 5019  ужасы,фэнтези,триллер
# 6048                unknown

# %%
# применяем к каждому столбцу в списке implicit_duplicate_list
# функцию anti_duplet
list(map(anti_duplet,implicit_duplicate_list))
# Out:
# [None, None, None, None, None, None, None, None]

# %%
# проверка
df_movies.query('title.str.contains("шапочка")', engine='python')
# Out:
#       index                    title   puNumber     show_start_date  \
# 4019   4020          красная шапочка  121003711 2011-03-14 12:00:00
# 4993   4994          красная шапочка  221072611 2011-05-30 12:00:00
# 5019   5020          красная шапочка  221098811 2011-09-19 12:00:00
# 6048   6049  красная шапочка. онлайн  111012018 2018-09-27 12:00:00
#
#                 type                               film_studio  \
# 4019  художественный  аппиан вэй, рэндом филмз, уорнер бразерс
# 4993  художественный  аппиан вэй, рэндом филмз, уорнер бразерс
# 5019  художественный  аппиан вэй, рэндом филмз, уорнер бразерс
# 6048  художественный                       роо экц "новый дар"
#
#      production_country        director  \
# 4019       сша - канада  кэтрин хардвик
# 4993       сша - канада  кэтрин хардвик
# 5019       сша - канада  кэтрин хардвик
# 6048             россия     н.бондарчук
#
#                                              producer  \
# 4019  дженнифер дэвиссон киллоран, леонардо ди каприо
# 4993  дженнифер дэвиссон киллоран, леонардо ди каприо
# 5019  дженнифер дэвиссон киллоран, леонардо ди каприо
# 6048                                        в.федоров
#
#                              age_restriction  refundable_support  \
# 4019         «16+» - для детей старше 16 лет                   0
# 4993         «16+» - для детей старше 16 лет                   0
# 5019         «16+» - для детей старше 16 лет                   0
# 6048  «0+» - для любой зрительской аудитории                   0
#
#       nonrefundable_support  budget financing_source  ratings  \
# 4019                      0       0          unknown      6.0
# 4993                      0       0          unknown      6.0
# 5019                      0       0          unknown      6.0
# 6048                      0       0          unknown      0.0
#
#                      genres
# 4019  ужасы,фэнтези,триллер
# 4993  ужасы,фэнтези,триллер
# 5019  ужасы,фэнтези,триллер
# 6048                unknown

# %%
# проверка
list(map(check_all,implicit_duplicate_list))
# Out:
# title
# Без применения функции: 6654
# С функцией: 6654
# Разница между без функции и с функцией: 0
# --------------------------------------------------
# type
# Без применения функции: 6
# С функцией: 6
# Разница между без функции и с функцией: 0
# --------------------------------------------------
# film_studio
# Без применения функции: 5420
# С функцией: 5420
# Разница между без функции и с функцией: 0
# --------------------------------------------------
# production_country
# Без применения функции: 933
# С функцией: 933
# Разница между без функции и с функцией: 0
# --------------------------------------------------
# director
# Без применения функции: 4795
# С функцией: 4795
# Разница между без функции и с функцией: 0
# --------------------------------------------------
# producer
# Без применения функции: 5326
# С функцией: 5326
# Разница между без функции и с функцией: 0
# --------------------------------------------------
# financing_source
# Без применения функции: 4
# С функцией: 4
# Разница между без функции и с функцией: 0
# --------------------------------------------------
# genres
# Без применения функции: 742
# С функцией: 742
# Разница между без функции и с функцией: 0
# --------------------------------------------------
# [None, None, None, None, None, None, None, None]

# %%
# Функция для извлечения цифр из строки и замены на оные
# при помощи рег-ых выражений
def int_grabber(row):
    return set([int(i) for i in re.findall(r'\d+',row['age_restriction'])]).pop()

# %%
# Для проверки
df_movies['age_restriction'].head()
# Out:
# 0      «18+» - запрещено для детей
# 1    «6+» - для детей старше 6 лет
# 2      «18+» - запрещено для детей
# 3      «18+» - запрещено для детей
# 4      «18+» - запрещено для детей
# Name: age_restriction, dtype: object

# %%
# Применим функцию
df_movies['age_restriction'] = df_movies.apply(int_grabber,axis=1)

# %%
# Провека
df_movies['age_restriction'].value_counts()
# Out:
# 16    2851
# 18    1604
# 12    1592
# 0      811
# 6      626
# Name: age_restriction, dtype: int64

# %%
pre_view(df_movies)
# Out:
# First 4 row(s) in the head of data
#    index                 title   puNumber     show_start_date            type  \
# 0      0      открытый простор  221048915 2015-11-27 12:00:00  художественный
# 1      1  особо важное задание  111013716 2016-09-13 12:00:00  художественный
# 2      2          особо опасен  221038416 2016-10-10 12:00:00  художественный
# 3      3          особо опасен  221026916 2016-06-10 12:00:00  художественный
#
#                                          film_studio production_country  \
# 0  тачстоун пикчерз, кобальт пикчерз, бикон пикче...                сша
# 1                              киностудия "мосфильм"               ссср
# 2  юниверсал пикчерз, кикстарт продакшнз, марк пл...                сша
# 3  юниверсал пикчерз, кикстарт продакшнз, марк пл...                сша
#
#             director                                           producer  \
# 0      кевин костнер          дэвид валдес, кевин костнер, джейк эбертс
# 1          е.матвеев                                            unknown
# 2  тимур бекмамбетов  джим лемли, джейсон нетер, марк е.платт, яйн смит
# 3  тимур бекмамбетов  джим лемли, джейсон нетер, марк е.платт, яйн смит
#
#    age_restriction  refundable_support  nonrefundable_support  budget  \
# 0               18                   0                      0       0
# 1                6                   0                      0       0
# 2               18                   0                      0       0
# 3               18                   0                      0       0
#
#   financing_source  ratings                     genres
# 0          unknown      7.0     боевик,драма,мелодрама
# 1          unknown      6.0              драма,военный
# 2          unknown      6.0  фантастика,боевик,триллер
# 3          unknown      6.0  фантастика,боевик,триллер
# ------------------------------
# Data Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7484 entries, 0 to 7483
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   index                  7484 non-null   int64
#  1   title                  7484 non-null   object
#  2   puNumber               7484 non-null   int32
#  3   show_start_date        7484 non-null   datetime64[ns]
#  4   type                   7484 non-null   object
#  5   film_studio            7484 non-null   object
#  6   production_country     7484 non-null   object
#  7   director               7484 non-null   object
#  8   producer               7484 non-null   object
#  9   age_restriction        7484 non-null   int64
#  10  refundable_support     7484 non-null   int32
#  11  nonrefundable_support  7484 non-null   int32
#  12  budget                 7484 non-null   int32
#  13  financing_source       7484 non-null   object
#  14  ratings                7484 non-null   float64
#  15  genres                 7484 non-null   object
# dtypes: datetime64[ns](1), float64(1), int32(4), int64(2), object(8)
# memory usage: 818.7+ KB
# None
# ------------------------------
# Data columns:
# Index(['index', 'title', 'puNumber', 'show_start_date', 'type', 'film_studio',
#        'production_country', 'director', 'producer', 'age_restriction',
#        'refundable_support', 'nonrefundable_support', 'budget',
#        'financing_source', 'ratings', 'genres'],
#       dtype='object')
# ------------------------------
# Data shape:
# (7484, 16)
# ------------------------------
# Data isna by row mean:
# index                    0.0
# title                    0.0
# puNumber                 0.0
# show_start_date          0.0
# type                     0.0
# film_studio              0.0
# production_country       0.0
# director                 0.0
# producer                 0.0
# age_restriction          0.0
# refundable_support       0.0
# nonrefundable_support    0.0
# budget                   0.0
# financing_source         0.0
# ratings                  0.0
# genres                   0.0
# dtype: float64
# ------------------------------
# Data clear duplicates sum:
# index                    0.0
# title                    0.0
# puNumber                 0.0
# show_start_date          0.0
# type                     0.0
# film_studio              0.0
# production_country       0.0
# director                 0.0
# producer                 0.0
# age_restriction          0.0
# refundable_support       0.0
# nonrefundable_support    0.0
# budget                   0.0
# financing_source         0.0
# ratings                  0.0
# genres                   0.0
# dtype: float64
# ------------------------------

# %% [markdown]
# **Вывод**
#
# Все поставленные задачи по очистке данных выполнены успешно.

# %% [markdown]
# ## Соединение таблицы и переименование столбца puNumber

# %%
df_shows.head(1)
# Out:
#     puNumber  box_office
# 0  111000113      2450.0

# %%
df_movies = df_movies.drop('index',axis=1)

# %%
movies_shows = pd.merge(df_movies,df_shows,on='puNumber',how='left')

# %%
movies_shows.head(1)
# Out:
#               title   puNumber     show_start_date            type  \
# 0  открытый простор  221048915 2015-11-27 12:00:00  художественный
#
#                                          film_studio production_country  \
# 0  тачстоун пикчерз, кобальт пикчерз, бикон пикче...                сша
#
#         director                                   producer  age_restriction  \
# 0  кевин костнер  дэвид валдес, кевин костнер, джейк эбертс               18
#
#    refundable_support  nonrefundable_support  budget financing_source  \
# 0                   0                      0       0          unknown
#
#    ratings                  genres  box_office
# 0      7.0  боевик,драма,мелодрама         NaN

# %%
df_movies.shape[0] - df_shows.shape[0]
# Out:
# 4326

# %%
movies_shows['box_office'].isna().sum()
# Out:
# 4327

# %%
# заменим названия столбцов как и хотели
# сокращение c ≡  certificate и rub ≡  rubles
movies_shows.rename(columns={'puNumber':'c_number', "box_office": 'box_office_rub'},inplace=True)

# %%
movies_shows.columns
# Out:
# Index(['title', 'c_number', 'show_start_date', 'type', 'film_studio',
#        'production_country', 'director', 'producer', 'age_restriction',
#        'refundable_support', 'nonrefundable_support', 'budget',
#        'financing_source', 'ratings', 'genres', 'box_office_rub'],
#       dtype='object')

# %% [markdown]
# ## Создание столбцов

# %%
for i in (movies_shows['director'].value_counts().reset_index()['index']):
    print(i
         )
# Out:
# о.семёнова
# стивен содерберг
# д.червяцов
# ридли скотт
# тиль швайгер
# клинт иствуд
# питер джексон
# вуди аллен
# кевин смит
# стивен спилберг
# дэвид финчер
# люк бессон
# кристофер нолан
# саймон уэст
# гай ричи
# п.смирнов
# николас столлер
# роберт земекис
# джеймс ван
# л.гайдай
# с.андреасян
# тьерри гиллиам
# роберт швентке
# тодд филлипс
# питер берг
# франсуа озон
# unknown
# дэвид йейтс
# дэвид гордон грин
# пол вайц
# зак снайдер
# пол гринграсс
# джон фавро
# квентин тарантино
# гильермо дель торо
# джонатан либесман
# д.дьяченко
# мартин скорсезе
# брэд пейтон
# георгий орлов
# дэнни бойл
# е.баранов
# н.михалков
# эндрю никкол
# роб райнер
# джастин лин
# роберт родригес
# том хупер
# тони майерс
# роланд эммерих
# с.говорухин
# стивен фрирз
# гарри маршалл
# роберт лукетич
# а.аксененко
# брайан сингер
# майкл бэй
# р.давлетьяров
# хаяо миядзаки
# владислав байрамгулов
# и.пырьев
# ксавье долан
# эдвард цвик
# питер сигал
# бретт рэтнер
# кевин макдональд
# билл кондон
# ю.райзман
# м.найт шьямалан
# адам маккей
# бенуа жако
# крис коламбус
# крис рено
# фрэнк корачи
# тимур бекмамбетов
# ларс фон триер
# джим джармуш
# джеймс демонако
# михаэль ханеке
# фил грабски
# а.федорченко
# к.шипенко
# а.котт
# рон ховард
# шон андерс
# г.данелия
# бальтазар кормакур
# э.рязанов
# пьер коффин, крис рено
# а.стреляная
# илья хржановский
# джон мэдден
# ренни харлин
# доминик сена
# с.соловьев
# джим шеридан
# энг ли
# андрей беляев
# ф.гэри грей
# йоханнес робертс
# роб маршалл
# м.ромм
# р.каримов
# уилл глак
# м.мошкова
# тим бертон
# ноам мурро
# а.баршак
# итэн коэн, джоэл коэн
# франк халфун
# мортен тильдум
# с.мирошниченко
# патрис леконт
# руперт сандерс
# джо карнахан
# д.суворов
# мартин кэмпбелл
# терренс малик
# алехандро гонсалес иньярриту
# софия коппола
# а.почивалов
# джо райт
# рубен фляйшер
# оливер паркер
# наталья мальгина
# джей джей абрамс
# джо джонстон
# джон хиллкоут
# иджинио страффи
# антуан фукуа
# сергей лозница
# расмус а.сивертсен
# марк уотерс
# гарет эдвардс
# дэвид линч
# шейн блэк
# мэтт ривз
# марк уэбб
# джозеф косински
# сет гордон
# винченцо натали
# ульрих зайдль
# о.асадулин
# чжан имоу
# в.тимощенко
# дэвид добкин
# кристофер лэндон
# анджелина джоли
# роман полански
# тим бёртон
# паоло соррентино
# п.чухрай
# а.птушко
# г.натансон
# энн флетчер
# а.сурикова
# гор вербински
# эдгар райт
# ларри вачовски, энди вачовски
# пол фейг
# пол у.с.андерсон
# френсис лоуренс
# маттео гарроне
# и.ковалев
# майк ньюэлл
# джордж клуни
# дэвид йетс
# марк форстер
# джеймс мэнголд
# к.шахназаров
# майкл патрик кинг
# н.хомерики
# жако ван дормель
# в.абдрашитов
# е.чернова
# бен аффлек
# майк флэнеган
# оливер стоун
# в.шамшурин
# сильвэйн уайт
# а.прошкин
# сюзанна уайт
# а.геворгян
# патрик хьюз
# такеши китано
# алекс де ла иглесиа
# дэмьен шазелл
# стефан лоу
# роб леттерман
# натан грино, байрон ховард
# тим бартон
# энди фикмен
# вим вендерс
# джон кёрран
# и.калядин
# томас винтерберг
# жан-пьер дарденн, люк дарденн
# джудд апатоу
# п.руминов
# брэд андерсон
# джордж нолфи
# грег моттола
# томми виркола
# сэм мендес
# спайк джонз
# к.оганесян
# вольфганг петерсен
# джон ву
# кристофер маккуори
# а.звягинцев
# мишель гондри
# даррен аронофски
# с.самсонов
# майкл уинтерботтом
# джон м.чу
# педро альмодовар
# бёрр стирс
# о.карас
# дэвид маквикар
# г.бардин
# дэниэл эспиноза
# джон лукас, скотт мур
# а.атанесян
# а.хачатурян
# м.шевчук
# в.сторожева
# м. найт шьямалан
# паскаль шомель
# джузеппе торнаторе
# шон леви
# дэвид литч
# с.мокрицкий
# к.серебренников
# р.быков
# николас виндинг рефн
# а.миронов, е.головин, р.верещак и др
# бен уитли
# лоне шерфиг
# альбер дюпонтель
# генри джуст, ариэль шульман
# в.азаров
# майкл д'иса-хоган
# брек айзнер
# бен стассен
# элизабет бэнкс
# лоран тирар
# в.георгиев
# крэйг гиллеспи
# а.смирнов
# дэни бун
# грегори плоткин
# кен скотт
# ю.озеров
# сет макфарлейн
# питер гринуэй
# гленн фикарра, джон рекуа
# джордж лукас
# марк лоуренс
# а.алов, в.наумов
# а.козлов
# макото синкай
# ю.быков
# аарон зельцер, джейсон фридберг
# том макграт
# чарльз мартин смит
# том тыквер
# чарльз чаплин
# жан-пьер жене
# джеймс кэмерон
# бернардо бертолуччи
# начо вигалондо
# а.файнциммер
# бен стиллер
# с.подгаевский
# даг лайман
# п.тодоровский
# уильям фридкин
# джо руссо, энтони руссо
# ю.грымов
# том дей
# джим филд смит
# дэвид эйр
# э.кеосаян
# джон чу
# пол макгиган
# а.кравчук
# в.тодоровский
# нил маршалл
# дональд петри
# а.матисон
# виктор сальва
# фатих акин
# с.эйзенштейн
# кевин гротерт
# роб коэн
# скотт спир
# к.худяков
# джеймс бобин
# луи летерье
# сэмюэл байер
# альфонсо куарон
# зигфрид
# раджа госнелл
# а.салтыков
# уэс болл
# м.захариас
# м.туманишвили
# тим стори
# бора дагтекин
# барри зонненфельд
# адам шенкман
# джосс уидон
# дэннис дуган
# джордж миллер
# эрик бревиг
# а.гордон
# сюзанна биер
# стивен найт
# ли ункрич
# франческа замбелло
# стайлз уайт
# карлос салдана
# хауме коллет-серра
# а.кириллов
# нэнси майерс
# р.мосафир
# майкл хоффман
# роусон маршалл тёрбер
# кристоф оноре
# бернард роуз
# ксавье жанс
# деннис дуган
# стив пинк
# р.прыгунов
# джейсон рэйтман
# джо данте
# кен лоуч
# билли боб торнтон
# ф.попов
# геннадий тартаковский
# айвен райтман
# валери донзелли
# джеймс грэй
# лассе халльстрём
# стив маккуин
# крис уэдж
# нимрод антал
# марк невелдайн, брайан тейлор
# дин деблуа, крис сендерс
# джули энн робинсон
# уолтер саллес
# райан джонсон
# джон харвитц, хейден шлоссберг
# к.буслов
# а.волгин
# фред кавайе
# джеймс марш
# такаси миике
# филипп штёльцль
# чарльз е.бастьен
# жан-марк валле
# седрик клапиш
# ким ки-дук
# в.козлов
# сидней сибилиа
# марк стивен джонсон
# фил лорд, кристофер миллер
# мамору хосода
# а.войтинский
# б.юсупов
# рик роман во
# жак одиар
# н.джорджадзе
# к.бронзит
# гас ван сент
# александр пэйн
# харольд цварт
# т.столбова
# андрей кончаловский
# тодд луисо
# лесли хэдланд
# ю.разыков
# скотт чарльз стюарт
# а.борматов
# сильвен уайт
# адам вингард
# энрике гато
# марк ротемунд
# нил джордан
# энди теннант
# ферзан оспетек
# дито монтиель
# с.проскурина
# асгар фархади
# деннис ганзель
# джейсон мур
# александр ажа
# камиль деламарр
# родриго кортес
# франк гастамбиде
# абель феррара
# нил бломкамп
# дэвид о.расселл
# акан сатаев
# эсбен тофт якобсен
# оливье мегатон
# даррен линн боусман
# джей си чендор
# майкл тиддес
# роджер мичелл
# д.тюрин
# хидео наката
# гэри фледер
# ричард линклейтер
# скотт дерриксон
# тодд солондз
# майкл догерти
# ф.бондарчук
# питер веллингтон
# шон гэррити
# а.учитель
# кристиан петцольд
# м.расходников
# а.мегердичев
# элай рот
# к.кузин
# ол паркер
# о.лопато-джагацпанян
# декстер флетчер
# хаум коллет-серра
# и.волошин
# мани хагиги
# рон клементс, джон маскер
# алекс пастор, давид пастор
# джоэл коэн, итан коэн
# с.бурнашев
# грэг макгиливрэй
# с.дружинина
# лука виотто
# джон майкл макдона
# н.бондарчук
# стивен с.миллер
# в.суслин
# флориан хенкель фон доннерсмарк
# д.светозаров
# н.эген
# хуан антонио байона
# лен уайзман
# г.константинопольский
# томас лукас
# рохер гуаль
# а.карпиловский
# а.чернакова
# брэд фурман
# с.лобан
# дженнифер ю
# а.зархи
# ева ионеско
# дэвид кроненберг
# джоэл шумахер
# я.лапшин
# оливье накаш, эрик толедано
# тейт тейлор
# г.кузнецов
# с.колосов
# кен коупис
# н.москаленко
# дэниел барнц
# е.хазанова
# г.чухрай
# хуан хосе кампанелла
# лоран пелли
# в.дербенев
# рассел малкэй
# ю.озеров, ю.бондарев
# дэвид ликли
# тим миллер
# уэс андерсон
# мэттью вон
# беннетт миллер
# м.швейцер, с.милькина
# а.малюков
# феликс фуксштайнер, катарина шёде
# а.митта
# а.роом
# п.лунгин
# барри левинсон
# уолт бекер
# а.силкин
# саймон уэллс
# нил бергер
# а.смирнова
# лиза азуэлос
# д.месхиев
# динг лианг, фуюан лиу
# дэвид маккензи
# ник кассаветис
# одри дана
# джон карпентер
# джеймс мактиг
# джон эрик даудл
# тони скотт
# дэвид слэйд
# и.твердовский
# зенке вортманн
# майкл манн
# б.барнет
# леван когуашвили
# энди фикман
# филипп де шоврон
# маттис ван хейникен младший
# жером салль
# в.ордынский
# джеф треймейн
# дэвид с.гойер
# стивен куэйл
# паскаль ложье
# д.астрахан
# э.климов
# жан-люк годар
# а.муратов
# сильвестр сталлоне
# с.курченко
# том грин
# пол солет
# джули тэймор
# а.петрухин
# н.губенко
# уильям монахэн
# э.гаврилов
# крис вайц
# роджер дональдсон
# кэтрин хардвик
# пол хаггис
# м.бальчюнас
# мишель хазанавичус
# фрэнк оз
# йоргос лантимос
# и.куликов
# кэтрин бигелоу
# а.столпер
# пол фиг
# эрик дарнелл, том макграт, конрад вернон
# в.чеботарев
# г.панфилов
# филлида ллойд
# жан-жак мантелло
# а.серый
# с.юткевич
# кирк джонс
# дэвид дуглас
# жан-жак анно
# анджей бартковяк
# джон эрик даудл, дрю даудл
# майк фиггис
# д.чернов
# адриан грюнберг
# р.джей.катлер
# джэфф баэна
# нанетт бурстайн
# в.басов
# а.чижиков, и.чижиков
# сэм гарбарски
# пьер морель
# жан-франсуа рише
# в.петров
# мигель сапочник
# майк митчел
# в.хотиненко
# пейтон рид
# майкл спириг, питер спириг
# бо дзенга
# томас альфредсон
# грегори хоблит
# с.снежкин
# бобби фаррелли, питер фаррелли
# тосиюки кубоока
# в.меньшов
# майкл сакси
# чад стахелски
# е.ташков
# б.гуц
# эмили янг
# адам робител
# ф.дмитриев
# уэйн крамер
# люк бонди
# антон корбайн
# кристофер нельсон
# маркус ниспел
# ли уоннелл
# и.джендубаев
# паоло дженовезе
# а.якимчук
# александр коффре
# кристоф ган
# джефф уодлоу
# джошуа майкл штерн
# а.барыкин
# мелани лоран
# к.малкин-фам
# джон ридли
# с.комаров, о.асадулин
# рот стромберг
# том форд
# к.оганисян
# ариэль вромен
# м.калатозов
# в.алеников
# андреа ди стефано
# а.черномазов (псевдоним алексей нужный)
# оливье барру, кад мерад
# р.гигинеишвили
# кэмерон кроу
# ким ки дук
# ю.попович
# в.салтыков
# рубен эстлунд
# д.васильев
# д.кубасов
# дени вильнев
# блэр эриксон
# джеймс кент
# е.абызов
# е.соколов
# р.салахутдинов
# джаред хесс
# алессандро сиани
# келли эсбери
# джулиус эйвери
# стюарт битти
# дин деблуа
# виктор левин
# ари астер
# присцилла камерон
# м.нефедова
# с.майоров
# гийом кане
# хесус гарсес ламберт
# род лури
# аарон вудли
# джон пог
# филипп лашо
# а.сидоров
# каран джохар
# фрэнк миллер, роберт родригес
# николас бенаму, филипп лашо
# и.казанков
# и.северов
# а.хван
# франк гастамбид
# скотт купер
# крис бак, дженнифер ли
# а.романец
# халлвард браэин
# бальтасар кормакур
# ёлкин туйчиев
# стивен р.монро
# а.хамраев
# александр бах
# вик армстронг
# к.балагов
# валентино пиконе, сальваторе фикарра
# а.меликян
# уэсс крэйвен
# шон эллис
# н.урвачева
# о.высоцкая
# тадонг пак, маурисио де ла орта
# а.кордон
# п.сергацков, а.верещагин
# м.хлебородов
# а.бильжо
# эмманюэль берко
# оливье даан
# ханс петтер муланд
# рэймонд де фелитта
# а.андрианов
# м.кузовенков
# азиф кападиа
# а.поздняков
# ди джей карузо
# ричард айоади
# джон копли
# е.михалков-кончаловский
# джафар панахи
# стивен хопкинс
# томм мур
# брэйди корбет
# ю.ботоев
# леон джусен, аарон силман
# синдзи хигути
# каспар мунк
# иссара нади, кирати нак-интанон, путипонг сайсрикаев
# брюно дюмон
# т.игуменцева
# иссара нади, кирати нак-интанон, патчанон тумджира
# спайк джонс
# джованни веронези
# джош гордон, уилл спек
# тоби генкель, шон маккормак
# маджид маджиди
# анн фонтен
# е.татаров
# а.кончаловский
# сэм тейлор-джонсон
# рон скальпелло
# уильям брент белл
# наталья березовая
# даниэль санчес аревало
# е.матвеев
# т.эсадзе
# а.темников
# брэд бёрд
# с.гинзбург
# аличе рорвахер
# питер лепениотис
# а.берденников
# скотт моужер, ярроу чейни
# а.верещагин, о.филипенко, д.ушаков
# стивен кантор
# гастон дюпра, мариано кон
# а.калинкин
# серджо манфио
# клэй холл
# марк лампрелл
# п.дроздов
# и.бахтина
# н.меркулова, а.чупов
# вернер херцог
# алекс ван вармердам
# ю.фетинг
# дэвид роберт митчелл
# руперт уайатт
# пол кинг
# в.чигинский
# джастин бенсон, грегг бишоп, начо вигалондо, тодд линкольн, аарон мурхед, марсель сармиенто
# брайан хелгеленд
# м.сегал
# а.зайцев
# е.кожокин
# джим микл
# стив лотер
# а.сиверс
# г.гитис
# питер челсом
# а.богуславский
# б.уладаев
# микеле малли
# о.беляева
# а.цицилин
# фил олден робинсон
# а.велединский
# с.назиров
# клаудио поли
# м.якубсон
# е.шелякин
# роб минкофф
# матиас хёне
# дэвид мерфи
# билл беннетт
# оскар сантос гомес
# фредерик бонд
# рич мур, байрон ховард
# а.богатырев
# джей барушель
# е.окопная
# энцо д'алло
# михаэль р.роскам
# а.мышкин
# атом эгоян
# дени аркан
# а.кириенко
# джереми дегрусон, бен стассен
# а.герман
# с.пучинян
# в.марин
# в.павлов
# д.вятич-бережных
# джон уэллс
# федерико феллини
# майкл даус
# лукино висконти
# грэг макгилливрэй
# джей роуч
# д.кудрявцев
# дэйв грин
# лука гуаданьино
# в.донсков
# пьер сальвадори
# в.кремнев
# пако кабесас
# люси уокер
# г.бежанов
# стефан бризе
# в.котт
# о.нарлыев
# дэн трактенберг
# ижинио страффи
# бенуа делепин, гюстав керверн
# кеннет брана
# джонатан инглиш
# нильс арден оплев
# с.тарасов
# габриэле муччино
# дин девлин
# джоди фостер
# дин ши
# алессандро карлони, дженнифер ю
# д.федоров
# марк аткинс
# александр астье, луис клиши
# к.юдин
# в.бортко
# майкл куэста
# николя ванье
# луи гаррель
# а.красовский
# т.саакян
# мануэль сисилия
# дункан джонс
# росс венокур
# к.муратова
# д.грачев
# ласло немеш
# п.мирзоев
# джеймс каллен брэссак
# а.пиманов
# йоаким триер
# ю.малюгин
# в.азеев
# лука лучини
# в.янковский
# к.плетнёв
# в.глаголева
# б.дышенов
# а.бобровский
# ноа баумбах
# отар иоселиани
# зандор йессе, уте фон мюнхов-поль
# с.соколов
# илмар рааг
# о.штром
# седрик николя-троян
# квентин дюпьё
# оливье ассаяс
# энди годдар
# ф.махмутов (псевдоним фанис камал)
# лин одинг
# валерия гай германика
# люк гринфилд
# а.амбросьев
# мигель артета
# хулио медем
# роберт энрико
# ганс петтер моланд
# а.миндадзе
# андрес пуустусмаа
# уте фон мюнхов-поль
# жан-марк рудницкий
# жоанн сфар
# о. семёнова
# алехандро аменабар
# в.харченко
# юнг куюн парк
# гэвин о'коннор
# джейк касдан
# хауме кольет-серра
# а.першин
# абделатиф кешиш
# трэвис найт
# шана фест
# виджай кришна ачария
# джеймс ганн
# феде альварес
# о.галин
# дрейк доримус
# джоэл эдгертон
# макс николс
# н.сайфуллаева
# джон р.леонетти
# линн рэмси
# киран дарси-смит
# зак брафф
# скотт во
# л.сааков
# али самади ахади
# арно ларьё, жан-мари ларьё
# виктор косаковский
# в.шамиров
# ханнес холм
# тод фреденталь
# гийом гальенн
# т.кеосаян
# а.праздников
# эли важеман
# брайан а.миллер
# клер дени
# в.кильчевская
# в.белов
# стив мартино
# карлос саура
# ник харран
# в.сигарев
# н.брусенцев
# э.радзюкевич
# и.угольников
# том харпер
# кеннет брэна
# в.торопчин
# корин харди
# о.субботина
# питер ландесман
# джастин курзель
# ю.кара
# бабак наджафи
# а.галибин
# и.волосецкий
# дэннис илиадис
# гэвин худ
# спайк ли
# кристиан диттер
# о.степченко
# джей чандрашекхар
# ричард лагравенес
# а.емкужев
# дэвид хэйтер
# дон маккеллар
# мэттью миле
# райан куглер
# р.волобуев
# доме карукоски
# джон краули
# рето салимбени
# милчо манчевски
# в.угличин
# о.товма
# оливер хиршбигель
# ким фаррант
# райан мерфи
# уолт беккер
# жан-марк валли
# джеймс уоткинс
# саймон верховен
# джон майкл макдонах
# макджи
# дженнифер уэстфелд
# кабир кхан
# эммануэль муре
# оливье моршаль
# джейсон ритмэн
# саймон кертис
# клод нуридзани, мари перену
# кике майло
# дейвид р.эллис
# стефан эллиотт
# питер лорд, джефф ньюитт
# джон стоквелл
# хэрольд рэмис
# лоуренс гутерман
# филипп нойс
# орен пели
# к.папакуль
# месси таджедин
# тони тэнг
# франческо инверницци
# сэм рэйми
# олатунда осунсанми
# феликс фуксштайнер
# андре тешине
# майкл дауз
# масаюки кодзима
# а.кулямин
# паскаль шомей
# антонио негрет
# клод берри, франсуа дюпейрон
# бретт ратнер
# мадонна
# йен софтли
# фил лорд, крис миллер
# майкл ньюэлл
# алан пол
# скотт хикс
# джефф николс
# а.попова
# дэвид цукер
# а.мармонтов
# пол андерсон
# эрик лартиго
# реми безансон
# кристиан молина
# карин кусама
# фрэнсис форд коппола
# ник мерфи
# р.нугманов
# рубен остлунд
# самуэль маоз
# малгожата шумовска
# е.борисова
# роар утхауг
# хармони корин
# а.кибкало
# роджер мишелл
# аки каурисмяки
# карлос рейгадас
# эрен криви
# н.лебедев
# кира муратова
# стив лихтаг
# кристофер б.стоукс
# к.ратушная
# стив энтин
# брайан де пальма
# аббас киаростами
# мэт аскем
# и.вырыпаев
# джон уоттс
# йос стеллинг
# джордж а.ромеро
# в.ивановская
# мартин клэпп, дорота кобеля, джофф линдси
# г.евтушенко
# альберто мар
# а.симонов
# джоэл коэн
# оливье ассайас
# в.татарский
# диего каплан
# в.мирзоев
# ален шаба
# андрес мускетти
# о.фесенко
# ким нгуйен
# в.панжев, г.курлаев, и.белостоцкий, м.сулейманова, н.репина, с.морозов и др
# в.воробьев
# мартин макдона
# лаура моранте
# скотт стюарт
# фрэнк дарабонт
# паскаль арнольд, жан-марк барр
# а.шейн
# майкл дж.бассетт
# б.хлебников
# найджел коул
# джеми линден
# ксавье джианолли
# е.барханов
# режи ройнсар
# е.михайлова
# к.тимофеев
# ларс клевберг
# о.лопато
# бенисио дель торо, пабло траперо, элиа сулейман, гаспар ноэ, лоран канте, хулио медем, хуан карлос табио
# жюстин трие
# дэвид ф.сэндберг
# такаши миике
# дэвид фрэнкел
# бертран бонелло
# гэри траусдейл, кирк уайз
# мэттью диас
# джессика хауснер
# п.пархоменко
# фредерик бегбедер
# паскаль вонг, ронан чапалэйн
# е.карелов
# а.мамедов
# к.воинов
# мартин брест
# алехандро агрести
# мартин шрейер
# джейсон рейтман
# коди кэмерон
# в.герасимов
# а.богданов
# крис уэйтс
# питер хаймс
# с.туманов
# марк романек
# рейнхард клоос, хольгер таппе
# р.хрущ
# е.тирдатова
# гела баблуани
# а.луканев
# кенни ортега
# ричард эйр
# р.фрунтов
# дэвид слейд
# брэд силберлинг
# анн фонтейн
# дэвид бикерстафф
# франко дзеффирелли
# марк пеллингтон
# дэвид моро, хавьер палю
# г.полока
# джон туртурро
# в.титов
# нил бреннан
# ю.чулюкин
# уве болл
# а.петрас
# и.бабич
# крис нунан
# найл джонсон
# бен янгер
# ю.карасик
# джон харрисон
# т.лукашевич
# гаспар ноэ
# тейлор хекфорд
# вольфганг петерсон
# а.эфрос
# л.марягин
# джон льюссенхоп
# в.пудовкин
# тод уильямс
# фэн сяоган
# майкл эптед
# жан франсуа рише
# г.александров
# г.егиазаров
# грэг берланти
# пол хантер
# джон тертлтауб
# маркус грейвз
# адам смит
# брайан лардж
# рауль руис
# уильям юбэнк
# оливер барру
# тарсем синх
# роб минкофф, роджер аллерс
# ю.васильев
# б.куломзин
# а.мизгирев
# гэри росс
# питер биллингсли
# пэт холден
# д.фадеев
# нима нуризаде
# гарет эванс
# сон-юн о
# мартин валенте
# макс джива, дания пасквини
# дрю бэрримор
# ларри чарльз
# стефан рибожад
# говард холл
# а.гутман
# а.сухарев
# тони кэй
# энди тэннант
# фернанаду майреллиш
# ниа вардалос
# г.рошаль
# дэвид миркин
# стивен гэган
# стив бек
# с.дворцевой
# эндрю адамсон
# с.меринов
# густаво кова
# р.нестеренко
# марк с. уотерс
# тони билл
# ричардэйр
# е.андриканис
# жаклин шеффер
# кристиан клавье
# дон рус
# тедди чан
# филипп гаррель
# скотт калвер
# кристофер сунь лэп ки
# николя кюш
# хиромаса йонебаяши
# фил трэйл
# с.насенкова
# питер хайамс
# джон харрис
# патриша уитли
# в.барбэ
# хирокадзу корээда
# малкольм д.ли
# паскаль эрольд
# и.блохина
# колин треворроу
# в.златопольский
# мигель анхель ламата
# дэвид баррет
# а.аббасов
# к.феоктистов
# т.бекмамбетов
# андре овредал
# руперт виатт
# гонсало лопес-гальего
# стивен чбоски
# дрейк доремус
# роб зомби
# тим молтби, ричард финн
# фернандо молина
# том вон
# такаши ямадзаки
# эдуардо шульдт
# джон хилкоут
# к.лопушанский
# маркус данстен
# брайан клагман, ли стернтал
# грег маклин
# мабрук эль мекри
# джек каздан
# тони гилрой
# джордан пил
# тэйлор хэкфорд
# джонатан левин
# м.саакян
# роберт карсен
# м.козлов
# синсуке сато
# лорен скафария
# м.ильенко
# екатерина еременко
# тим хилл
# джонатан мостоу
# джон эспинач, рикардо рамон
# клод лелуш
# витторио тавиани, паоло тавиани
# софи леллуш
# ричард доннер
# джеймс л.брукс
# чарльз е.бастьен, джили долев
# цутому ханабуса
# мэтт росс
# гарт дэвис
# эдуардо санчес
# бруно халлин
# чан ань хунг
# кьюнг хо ли
# пако пласа
# а.оганесян
# джеймс фоули
# кертис хэнсон, майкл эптид
# николя бедос
# седрик кан
# дэвид палмер, дэкс шепард
# д.ж.карузо
# гильермо арриага
# и.копылов
# л.марголин
# ф.шабанов
# чарльз шайер
# в.виноградов
# и.савченко, т.лукашевич, м.ромм
# джоан шемла
# о.трофим
# и.тойонов
# в.бархатов
# шон ку
# питер лепениотис, шелли шеной
# и гэ, сун юэфэн
# майкл кэтон-джонс
# алекс оррель, эдуардо шульдт
# г.щукин
# м.воронков
# лех майевски
# оксид пан, дэнни пан
# стефан лангридж
# о.зуева
# а.занин, м.архипов, н.барабаш, а.костандакес, д.шабаев
# фрэнсис лоуренс
# билл плимптон
# жанна лабрюн
# ли чандон
# кэтлин бельхер
# в.ивакин, д.сорокин, о.алиев, а.горовацкий, д.маковцев и др
# н.наумова
# жак дере
# с.алексеев
# джейсон флеминг
# л.трауберг, а.тутышкин
# и.соловьев
# адам гираш
# и.пелинский
# э.салаватов
# жаума кольет-серра
# раду михайлеану
# жозе антонио негрет
# питер энтони
# брайан декьюбелис
# якуб вронски, ира карпелан
# райнер хольцемер
# гэри маршалл
# джуеме балогуеро, пако плаза
# димитри логотетис
# тим фельбаум
# дэннис барток
# маркус вельтер
# н.скуйбин
# к.шахназаров, а.бородянский
# с.маховиков
# майкл и питер спайриг
# агустин диас янес
# д.белоусов
# джоао нуно пинто
# кристина коминчини
# м.швейцер
# феи сяоган
# в.пендраковский, ю.рогозин
# брюс робинсон
# ли даниэлс
# дебра граник
# а.сокуров
# а.драницына
# фабрис эбуе
# с.щербин
# стив одекерк
# миккель бренне сандемусе
# саулюс друнга
# о.попова
# д.киселев, а.першин (ж.крыжовников), а.карпиловский, а.черномазов (а.нужный)
# карим дриди
# трэвис райс
# пол том андерсон
# эрик лавэн
# рон шелтон
# майкл грейси
# к.максимов
# лука миньеро
# максим говар
# трэвис заривны
# мэтью чэпмен
# алберт хьюз, эллен хьюз
# трой никси
# м.алиев, а.пуустусмаа
# михаэль р. роскам
# дэнни кэннон
# и.кордзаия, в.лисневский
# питер уир
# дэвид сильверман
# такаши ямазаки
# мигель анхель вивас
# алекс оруэлл
# а.басаев
# стивен с. миллер
# адам грин
# ю.ауг, л.бочков
# в.каминский
# дэнни стронг
# роберт куртцман
# а.х.песонен, э.хафнор, л.б.хансен, г.энгер, а.цварт, й.тойвоньеми
# микеле плачидо
# д.вершинин
# с.с. раджамули
# арно бурон, антун крингс
# гектор эрнандес
# сьюзен уолтер
# уэсс болл
# стефан брауншвейг
# лиза лангсет
# донато карризи
# ричард айоэйд
# з.болотаев, к.смирнов
# кристиано анания, иления политано, валерио аттаназио, моника дуго, марчелло ди ното, даниэле пини; франческа бруни, алессандро капитани
# марк росман
# а.фон боррис
# джейда торун
# патрик милле
# кристиан гьюдгэст
# рафаэль рибас
# е.грамматиков
# том хэнкс
# аарон соркин
# салли поттер
# людвиг шаммасян, пол шаммасян
# мэтт драммонд
# е.соколов, в.панжев, г.курлаев, с.морозов, м.сулейманова и др
# дани бон
# д.о'рейли
# я.поляруш, т.цоцория, к.кутуев при участии м.алиева
# леонор серай
# армандо ианнуччи
# лоуренс шер
# ахеро манас
# джеймс хат
# джонатан хопкинс
# стенли туччи
# в.пудовкин, м.доллер
# ф.фархшатова
# аун хое го
# джей расселл
# леннарт рафф
# джон красинский
# и.комладзе
# айбек дайырбеков
# а.котёночкин
# н.соколов
# виктор сейнт макари
# ж.романова
# джун-хо бон
# гарольд реймис
# эрик валетте
# мари окада, тошия шиохара
# д.козловский
# я.трофимова
# а.аравин
# томас бальмес
# а.кретова
# р.сабиров
# д.коробкин, л.гурченко
# люк крэссуэл, стив макниколас
# о.погодин
# н.березовая
# жозе падилья
# м.немойтин
# манс марлинд, бьёрн стейн
# марк льюис
# джон лассетер, брэд льюис
# тоа фрейзер
# э.давлетшина
# андерс вальтер хансен
# свен унтервальдт
# к.дружинин
# сильвио сольдини
# патрик имбер, бенжамен реннер
# в.ровенский, н.лопато, в.азеев
# а.балабанов
# с.сенцов
# марианна ченильо, фернандо эймбке, амат эскаланте, гаэль гарсия берналь, родриго гарсия и др
# ричард льюис
# аудни аусгейрссон
# жюльен лякомб, паскаль сид
# н.венлок, ж.клинч, м.кловатер, б.лихтенштерн, д.м.лоренц, м.пийонель, а.смитс, т.смитс, х.хименес, м.шольте
# лорна такер
# майкл ли
# инжинио страффи
# м.жигалова-озкан, ю.зайцев
# эбби кон, марк силверштейн
# майк гюнтер
# роберт дорнхельм
# масаюки
# серж бозон
# хайфа аль-мансур
# элайджа дреннер
# энтони руссо, джо руссо
# д.коробкин
# в.панжев, г.курлаев, ф.кривошеев, м.сулейманова, н.репина, с.морозов и др
# даниэль штамм
# хауме балагеро
# и.каграманов
# а.горчилин
# джон кэмерон митчелл
# аскар узабаев
# вон стайн
# ю.шиллер
# дэвид р.эллис
# катрин корсини
# летиция коломбани
# малькольм венвилль
# мишель ларок
# ник стрингер
# лаки макки
# с.ганночка, с.крайнев
# тони лойзер, джеспер мюллер
# бэнкси
# л.горовец
# к.хрестинин
# робин обер
# ноэль клири, серджо делфино, алекс стадерманн
# боб фишер, роб гринберг
# к.хабенский, а.малюков
# дэниэл роби
# а.новиков (псевдоним - александр новиков-янгинов)
# евгений пашкевич
# в.короленков
# крис дженкинс
# роджер камбл
# с.линцов, а.велемицин
# оливье маршаль
# цутому мидзусима
# е.никитин, а.королёв, к.плетнев
# браян левант
# ван сылинь, чжен линьна
# е.цыплакова
# жан-пьер амери
# саверио костанцо
# томас безуча
# сара смит
# д.прима
# м.волков, в.мухаметзянов
# а.протоковило
# ник мур
# мартин кэмпбэл
# бэн палмер
# н.хомерики, о.бычкова, с.мокрицкий, с.егерев, и.малкин, о.музалева и др
# м.коновальчук
# николай фьюлси
# миранда джулай
# н.макарова, в.воробьев
# ава дюверней
# рудольф ван ден берг
# джон лэндис
# марк майлод
# и.белостоцкий
# симен альсвик, вильям эсхерст
# с.ландо
# колин штраус, грэг штраус
# к.васильев
# гай кассье
# а.войтинский, д.киселев
# джон френсис дейли, джонатан голдстейн
# в.перельман
# грета гервиг
# т.ивашкина
# в.пендраковский
# дэвид аттенборо
# роберт олтман
# шон бэйкер
# с.гордеев
# кеер ху
# хиромаса ёнэбаяси
# ола симмонсон, йохан стьярне нильссон
# с.айнутдинов
# эрдал сейлан
# абделлатиф кешиш
# лиза аддарио, джо сиракьюз
# роар ухтауг
# дэниэль монзон
# гэри маккендри
# а.черняев, е.рустембеков
# стивен с. денайт
# майкл кейтон-джоунс
# майкл кристофер
# т.полосина
# мэтью маскери, майкл нарлок, джейсон хитон
# бени бернхардт, луиз а.гиков
# ричард дэйл, фань лисинь, питер веббер
# бени бернардт, энтони браун
# н.щербаков
# робин сип
# амалия несби фика, юрген лердам, филип эйнштейн липски
# николас ванье
# деррик борте
# в.гинзбург
# в.мариничев
# мартин гиги
# п.москвин
# в.шепелев
# и.шерстобитов
# к.одегов
# о.денисов
# эндрю эрвин, джон эрвин
# николь кэссел
# е.телегина, м.полинский
# лаура шредер
# алекс грегори, питер хайк
# в.кушнирович (псевдоним в.бенигсен)
# ник парк
# в.глухушин
# леси халлстрем
# н.очигава
# джон стивенсон
# дэвид фрейн
# нэш эдгертон
# джон синглтон
# дуглас макграт
# сан ли джан
# в.ефремов, и.ефремова, в.лопач
# дэнни лернер
# е.жигаева
# л.усова
# феликс энрике алкала
# бартлетт шер
# эрик валетт
# тейлор шеридан
# трей эдвард шульц
# бибо бержерон
# джордж с.вульф
# гарри клевен
# уильям олдройд
# луис прието
# джеймс мактэйг
# маркос карневале
# дэвид ф. сандберг
# роберто снейдер
# джон симпсон
# жилль бурдо
# крис горак
# пьер зандрович
# д.киселев, а.котт, а.баранов, л.габриадзе
# стив гебхардт, боб фриз
# питоф
# ф.ибрагимбеков, с.швыдкой
# патрис шеро
# а.дерошер
# аннабель арден
# такэси коикэ
# ю.королев (псевдоним ю.стааль)
# роланд джоффе
# б.казаков, е.серов
# а. калюжный
# кэйити хара
# ж.бадмацыренов, а.кузьминов, е.замалиев
# николай арсель
# жильбер дефло
# бен сэфди, джошуа сэфди
# матье рэтхи
# ронан чапалайн и паскаль вьонг; фрэнсис верзеймер; джези кулар и даниэль кюнт; дидье гросджин
# чарльз роберт карнер
# ален рене
# д.карро, в.абдрашитов
# тони леондис
# эрик дарнелл
# марк циммерманн
# майк митчелл
# маркус голлер
# давид ало
# а.званцова
# лоун шерфиг
# с.глезин
# кэллан брункер
# а.хмельницкая
# а.меликян, п.руминов, н.меркулова, а.чупов, е.шелякин, р.гигинеишвили, н.сайфуллаева
# эндрю с.эрин
# ричард лагравенезе
# о.червоняк, д.стрижевский
# микаэл хальфстрем
# энтони дж.коэн
# гил кинан
# гай ферланд
# ли тамахори
# дэнни девито
# а.мигачев
# стивен лоу
# фредерико моччиа
# т.игуменцева (псевдоним татьяна капитан)
# а.цацуев
# джеральд рашинато
# марк дэвис, ноэль кларк
# вл.китт
# р. кериси
# а.кагадеев
# а.шадров
# а. кутерье
# джастин чадвик
# д. кэмерон
# и.коробейников
# к. шелепов
# ричард лонкрейн
# м. бальчюнас
# кен куопис
# м. мышанский
# эндрю дейвис
# эллори элкайем
# розелин бош
# барбет шрёдер
# м.дворянкин
# андреа андерман
# энтони леондис
# с.амбросова
# паула ван дер уст
# дэнни гордон
# с.осипьян
# джоди хилл
# шенг динг
# майкл редфорд
# макато синкай
# роберт редфорд
# майкл мэнн
# манодж найт шьямалан
# барбара топсе-ротенборг
# том дэй
# макс джива, данайя паскуини
# м.кондрикова
# т.таш-заде
# йен де бонт
# р.исмайлов
# доминик абель, фиона гордон, брюно роми
# антуан томас, джек фрост
# ронни ю
# с.газаров, о.фесенко
# в.меньков, с.линцов, р.саульский
# гарольд беккер
# дейв филони
# сидней поллак
# бретт симмонс
# джордж ихл
# патрик сиверсен
# о.осипов
# а.замыслов
# д.дж.карузо
# п.медведев
# стюарт бейард
# гэри дэйвид голдберг
# д.поволоцкий, м.другой
# зэк снайдер
# майкл дейвис
# таня уэкслер
# джозеф кан
# в.акобян
# гиоргос лантимос
# питер додд
# микаэль хофстрем
# м.барынин, и.цыганов
# филлип джей рот
# марк лоренс
# майкл хэгнер, кари джуусонен
# д. абель, ф. гордон
# эндрю адамсон, виктория дженсон
# эндрю эдамсон, келли эсбари
# пол дугдейл
# николай ленхофф
# н.кузнецова
# тодд филд
# джонатан миллер
# а.соболевский
# б. бум
# федерико тицци
# джон хейман
# лес мэйфилд
# анжела робинсон
# энтони мингелла
# викрам батт
# е.бычкова
# хореография джорджа баланчина
# м.ибрагимбеков
# алистер грирсон
# федерико тьеззи
# апичатпонг вирасетакул
# гюстав де керверн, бенуа делепин
# н.углицких
# а.фенченко
# микеланджело фраммартино
# кэри фукунага
# э.пискатор, м.доллер
# б.дробязко
# а.зельдович
# л.кулишов
# пьер алли
# жеральд юсташ-матьё
# с.росс
# джон камерон митчел
# алекс замм
# р.литвинова
# оливер хорлайт
# джулия ли
# айзек флорентайн
# элисон рейд
# тайка вайтити
# дэвид вустер
# сильвен шомэ
# дэмиан чапа
# а.щербович-вечер
# элиотт лестер
# брюс э.эванс
# кан чжэ гю
# с.осипьян, а.лунгин
# трак бренсс
# в.карабанов
# т.бекмамбетов, я.чеважевский, а.войтинский, д.киселев
# ксави хименез
# орен муверман
# ю сун-донг
# курт мэттила, мэтт чековски
# а.колмогоров
# алекс колл
# нил армфилд
# миккель мунк-фальс
# макс кроу
# м.мкртчян
# джон айвэй
# андреа арнольд
# хуан карлос медина
# а.михайлов
# пипилотти рист
# чарльз мартин
# и.черницкий
# филипп фалардо
# хольгер таппи
# лоррэйн леви
# давид алонсо, энрике гато
# эммануэль амон
# д.юзбашев
# и.замалиев (псевдоним э.бартенев)
# джонатан дэйтон, валери фэрис
# карстен килерих, рихард клаус
# алессандро сьяни
# брайан смрз
# грегор джордан
# элайджа мошински
# мэнс мэрлинд, бьорн стейн
# а.чеканов
# джоан чен
# и.каленов
# хэтти далтон
# м.снежная
# марина кунарова, ерлан нурмухамбетов
# а.бурцев, с.снежкин, е.аксенов, в.сорокин, и.хамраев и др
# к.коваленко
# д.фирсова, и.туманян, и.селезнева
# софи дерасп
# бруно шиш
# крестен вестбьерг андерсен, тордбьорн кристоферссен, филипп эйнштейн липски
# э.гущин
# б.яшин, а.смирнов
# адриан молина, ли ункрич
# л.арнштам
# дайна рейд
# а.сурин
# грэг мэнваринг
# бертран тавернье
# серхио х. санчес
# доминик фарруджия
# кевин танчароэн
# анастасия дыро, андрей шохан
# жиль паке-бреннер
# ховард халл
# маркус вайнер
# тайлер макинтайр
# джон рекуа, гленн фикарра
# биргитте стэмозе
# хью велчман, дорота кобела
# мелисса баттс, барри ким
# дейвид добкин
# жан-стефан брон
# крисс миллер
# питер футт
# ю.лейдерман, а.сильвестров
# тарек будали
# а.романец, в.марченко
# и.шурховецкий
# энди серкис
# в.мельников
# эдуард делюк
# билл джирхарт, роэль рейн, дэвид стрейтон, кевин танчароэн, крис фишер, неаса хардиман
# кевин рейнолдс
# дэвид хакл
# кевин гройтерт
# ричард келли
# гарт дженнингс
# а андрющенко
# дэн буш
# стив бенделэк
# уильям батлер
# симоне годано
# дарен линн босман
# жак дуайон
# ильдико эньеди
# чарли бин
# стефано пода
# александр бустильо, жюльен мори
# эмилио саги
# гейбор ксапо
# джон г.эвилдсен
# даррен лион бойсман
# даррен линн баусмэн
# паскаль пузаду
# терри звигоф
# питер дьюкс
# тим кокс
# майк уайт
# кинен айвори уэйанс
# ричард шепард
# джорджо амато
# анхель грация
# давид гриеко
# кэтрин хардуик
# аманда штерс
# крэйг мэзин
# кевин мунро
# джеймс грей
# майкл кэтлман
# дейвид тоухи
# холли мейерс-шайер
# уилл верник
# цзянь мин хуанг
# кристиан карион
# хореография мариуса петипа в редакции наталии макаровой
# джейсон тиссен
# н.чернышева
# пэт о'коннор
# э.парри
# б.бакурадзе
# оливер хиршбигель, джеймс  мактиг
# з.трофимова
# шэри спрингер берман, роберт пульчини
# джеймс вонг
# а.петровская
# г.коломийцев
# серджи визкайно
# а.колпин, и.пшонкин, в.бедошвили
# н.ченышева
# в.марков
# ромейн леви
# карла лиа монти
# паскаль-алекс винсент
# е.соломина, а.баршак, к.статский
# со абади
# рич рэгсдэйл
# саймон кёртис
# роджер камб
# фредерик берт
# саймон уинсер
# дэни вильнёв
# виталий манский
# керн конвайзер, дэвид рен
# ю.афанасьев, э.архангельская
# генри селик
# джон а.дэйвис
# мэрлин агрело
# хани абу-ассад
# лайам о'доннелл
# дэвид боуэрс, сэм фелл
# кристофер моррис
# лоренс кэздан
# дитер бернер
# жаргалсаихан баатар
# реми шайе
# янус мец педерсен
# давид фонкинос, стефан фонкинос
# эми канаан манн
# кевин костнер
# кэй кэннон
# а.якимчук, в.лагунов
# н.назарова
# оуэн эгертон
# андрей тарковский
# фарад сафиниа
# д.былинушкина
# джастин бальдони
# крис эддисон
# лила авильес
# стивен вутерлуд
# а.никифоров, в.шепелев, о.коронный, в.кузмина, п.скворцов
# тоуб хупер
# пит де риккер
# м.фомина
# люк джейден
# м.агранович
# мануэль х.гарсиа
# хьюберт вейланд
# н.кеппенс, м.флипс, ш.б.линдхольм, б.рэес, м.бине, п.баеза, ф.браух, м.пухоль, к.тэйлхэдс, й.тиро, р.тирион, п.пик, а.манцарис
# а.хатулик, г.ром, к.мазахери, ж.дара, с.дара, ф.-ф.морен-варгас, л.тейлор, к.барретт
# ладислас шолла
# джереми люттер
# микаэль херс
# ян гэ
# мэй аль-тукхи
# жак клюгер
# эрик тости
# дэвид яровецки
# а.рыбников
# т.тания
# надав лапид
# роксана бенжамин
# лакарион вайнайна
# роберт эггерс
# тревор нанн
# вольфганг лауэнштайн, кристоф лауэнштайн
# л.арчидиаконо, э.бей, п.джеремей, л.ди нола, м.лой, л.лукетти, д.манджашутти, д.мастромауро
# дженни гейдж
# шэнь юй, хуан янь
# адам макдональд
# с.саркисов
# рэйф файнс
# клаудио джованнези
# майкл чавес
# тае йонг ким
# бинг лю
# катрин филип
# джордан дауни
# деннис ботс
# карл кох, лотти рейнигер
# милорад крстич
# пия хелленталь
# хуан пабло поланко, сесар алехандро хаймес
# чания баттон
# мигель а.феррер
# марин атлан
# карла фон бенгтсон
# габриела пихлер
# т.мирошник
# милад алами
# люк лорентцен
# джо берлингер
# винсент д'онофрио
# п. "хики" стручков
# райан белгхарт
# д.вологдин
# джиджи рокатти
# чак рассел
# ли лиань
# ринат газизов, илья трусов
# сергей гордеев, артем лукичев
# тодд дуглас миллер
# нестор саенц кампос
# п.левченко
# оливье бару
# николаус лейтнер
# лайам гэвин
# дарио ардженто
# т.абрамова, е.тряпицына
# а.пармас
# джош кули
# шрирам рагхаван
# в.лисневский, с.пикалов
# дианна грон, питер челсом, фернандо эймбке, джастин франклин, деннис ганзель, дани леви, даниэль львовски, йозеф руснак, тиль швайгер, мэсси таджедин, габриэла черняк
# роберт будро
# дэниэл фаррандс
# андрей беляев, владислав байрамгулов, денис червяцов, илья трусов, ринат газизов
# р.артемьев (псев.с.васильев)
# ю.перкуль, а.богатырев, а.камачо
# амели ван элбт
# дэн креч
# гари доберман
# гейл манкусо
# стэйси пассон
# б.акопов
# тимоти вудворд младший
# д.павлов
# елена коссон кизилова
# эмилио портес
# лизе и.осволл
# антонин бодри
# илья трусов
# айк кбеян
# грант спьютор
# ара пайая
# эмма тамми
# джордж галло, франческо синкуемани
# л.садилова
# е.яцкина, а.рубинштейн
# а.лунгин
# г.добрыгин
# оливье мейру
# саймон кинберг
# мэри хэррон
# лу жене
# стивен номура шибле
# чальз е.бастьен, бронвин деннисон, мигель мартинез-хоффре
# в.кузовлев
# р.паушу
# денис червяцов
# д.сергин
# хоао пекенао
# иван кальберак
# митали гошал
# макс мингелла
# л.борисова
# с.ивекович, д.кричли, д.кроссвэйт, с.лэйр, к.мейнел, г.ндириту, д.смит, л.фоулер, м.хеске, д.холл, г.шервин
# а.хаакана
# т.ильина (псевдоним - иван непомнящий)
# н.фомин
# кристоффер нюхольм
# такахиро омори, хидэки ито
# м.вартанян (псевдоним - милана федосеева)
# а.золотухин
# джо пенна
# гай гвидо
# мими ледер
# карлос каррера
# н.бучнева
# л.круглов
# м.олейник (псевдоним - мария полякова)
# с.андрианова
# дидерик ван ружен
# м.волчанская
# анна боден, райан флек
# эрик барбье
# николас маккарти
# питер хатчингс
# а.петрова
# а.богуславский, а.волгин
# с.уваров
# н.ведмицкая
# а.хржановский
# майкл майер
# анатолий иванов
# в.олькович, с.матросова, д.иванов, а.сэмбон
# аманда шарп
# м.мошкова, а.борисова, а.бахурин, т.мошкова, а.жидков, а.ковтун
# а.зозуля, м.елкин
# флориан дэвид фитц
# б.батуллин
# лучано лигабуэ
# ю.морская
# е.трапезникова
# м.архипов
# е.жиркова, а.кузина, м.солошенко
# в.копцев, е.копцева
# лайонел стекти
# а.бадягина
# пабло рохас кастильо
# р.кузьмина
# а.розов
# а.гришаков
# и.малкин, и.бессарабова
# с.сильвертон
# и.зайцев, о.урушев
# фрэнк миллер, роберт родригес, квентин тарантино
# гейб клингер
# андреас дрезен
# в.кузенков
# а.усаков
# и.красников, вахтанги хубутия
# питер хеджес
# а.васильев
# а.соколов-дворников (псевдоним - алексей соколов)
# надин лабаки
# джо корниш
# а.джазоян
# а.руже
# джастин типпинг
# рашид бушареб
# айрис заки
# крис батлер
# м.катушкин
# п.селин
# а.боровикова, е.войтович, з.джиджилава, а.тимофеева, а.духонина, и.басенко, ю.машукова
# с.струсовский
# д.иванкова
# ф.золоева, в.гулуев
# д.рудаков
# с.васильев
# я.лебедев
# ю.забурьянный (псевдоним жора фероренко)
# антонио падован
# ли кронин
# а.гаврилов
# алексис михалик
# я.варлашкина
# н.лопато, в.ровенский
# кевин колш, деннис уидмайер
# е.бедарев
# франсуа дезанья
# анне севитски
# джейсон стоун
# эспен сандберг
# том о'дэлл
# энтони марас
# элен жиро, томас сабо
# деннис хоппер
# ана урушадзе
# бастер китон
# монс морлинд, бьёрн стейн
# з.гапиенко
# гастон дюпра
# джона хилл
# а.домогаров
# с.андрианова, а.чижикова (псевдоним а.воронина), п.кутукина, к.голубков
# д.великовская, н.лопато (псевдоним нилова)
# джузеппе доминго романо
# и.ермолов, и.каграманов, э.барсегян, н.искандарова
# мэтт хейнеман
# м.довженко
# тува новотны
# майкл чимино
# л.геращенко
# в.фанасютина
# фред вульф
# с.крэйг залер
# си чао
# е.жиркова, а.кузина, м.солошенко, с.кравцова
# а.пичужин
# с.сафонова, а.хмельницкая, а.сальянов, н.назарова, д.моисеев
# с.алякимова
# а.лукин
# гильермо иван
# кристиан альварт
# джесси в.джонсон
# цзоу и
# э.балье, с.гейнсборо, а.дамиан, ж.кати, я.куйперс, а.мадзарис, м.пажек, д.хесс, к.шпект
# в.медведев
# джош аппелбаум, аарон дем, эшли чейни
# ю,гапон
# эмануэле имбуччи
# мартин оуэн
# лев прудкин, владимир прудкин
# майкл с.ойеда
# александр клименко
# жослин дебоэр, доун люббе
# франко кастеллано, джузеппе моччиа
# селин скьямма
# а.пинхасов
# марианна яровская
# юго желен
# а.митёшин
# майкл энглер
# грег тирнан, конрад вернон
# а.бажанов
# игорь тувери
# рейчел хиронс
# ванесса фильо
# анхель алонсо
# тайлер нильсен, майкл шварц
# рейчел гриффитс
# элис вэддингтон
# т.гулина
# уэйн робертс
# патрик брайс
# джузеппе стази, джанкарло фонтана
# уильям кауфман
# микаэль хальфстрем
# кевин монро
# и.копылов, с.щербин
# харука фудзита, таити исидатэ
# о.городецкая
# роман козич
# шон патрик о'рейли
# скотт бек, брайан вудс
# ж.альберт, к.грижевски, с.зморк, и.кранковски, д.милейро, э.романс,, н.тайберг, х.фариас
# ник брумфилд
# т.андрианова (псевд.т.вигель)
# аюму ватанабэ
# го аун хое
# каллен брункер
# а.шархун
# сэфи неббу
# элиз дюран
# генри джейкобсон
# тодд вилдерман, джилл калтон
# сиддхартх ананд
# абе форсайт
# лулу ванг
# чарльз е.бастьен, дэвид нотт, карин-энн андерсон
# джим хоскин
# м.игнатенко
# джереми деллер
# гийом медачевски
# майк ган
# руперт гулд
# джон лукас, скотт мкр
# аньес варда, дидье роже
# карлос гутиеррез медрано
# г.менкяров
# н.малыгина
# андрей гринько, макс сирый
# дон харди, дэна начман
# зак липовски, адам б.стейн
# джейсон кэбелл
# петра хёфер, фредди рёкенхаус
# дэвид холройд
# фархат шарипов
# закари адлер
# дяо инань
# брайан кирк
# роуэн этейл
# фенар ахмад
# зёнке вортманн
# артем лукичев
# джефф чан
# чарльз е.бастьен, билл спирс
# адам рэндолл
# ю.казачков
# н.герман
# в.бедошвили, о.ужинов, и.пшонкин, д.цыбулькин
# стэнли кубрик, мэтт уэллс
# вадих эль хайек
# эдвард нортон
# кирби аткинс
# д.шмидт, к.феоктистов
# л.соломатина (томилова)
# виктор флеминг
# н.карачкова
# софи такал
# к.чувикова
# симона костова
# м.бальчюнас (псевдоним м.вайсберг)
# д.григорьев
# ник пойнц
# ник пауэлл
# а.беляев
# ли джон-хо
# а.федоров
# себастьян джонс, рамез силян
# мати диоп
# джун янг йом
# миккель бранде сандемузе
# фредерик ченг
# габриэль жюльен-лаферье
# джастин дек
# хади мохамадян
# пол кампф
# альфонсо гомес-рехон
# ж.бадмацыренов
# а.иванов
# в.лаптев
# о.николаевский
# рафик сарджанян
# и.рожков
# а.басов
# мумин шакиров
# чан хун
# уэс андерсен
# юкка-пекка валькеапяя
# джейк кэздан
# майкл мелски
# азиз джиндани
# луи валлекан
# о.арлаускайте (псевд.о.арлаускас)
# ладж ли
# алла ковган
# о.степанцова
# а.герасимов
# и.кунилов
# м.морсков
# анна соловьева
# деннисон рамальо
# кия роуч-тернер
# гай наттив
# йоахим масаннек
# кирилл михановский
# с.шанкар
# сюнъити ёсидзава
# дэвид махмуди
# оливье массе-депасс
# рон юань
# пак чжун су
# олег маламуж
# урсула макфарлейн
# туроп ван орман
# анна аревшатян
# мариано кон
# а.манзуров
# марк веркерк
# кацуси сакураби
# амели равалек
# герард квинто, эстеве солер, дэвид торрас
# эндрю раймер, джефф чан
# чхве гук-хи
# е.невский (псевдоним е.торрес)
# бертран банелло
# лукас бернард
# джонатан макхью, джордан реннерт
# хи-чан ра
# дэн вэйфэн
# питер стриклэнд
# а.соколюк
# аасне ваа грейброкк, тор бренн, исаак гёртсен, мария лойтер, патрик эклунд
# арно лемор
# ольга львова
# пол хайет
# джон херцфелд
# е.логунцова
# вильгельм домке-шульц
# ф.петрухин
# и.мардарь
# в.фекленко
# л.искандерова
# н.сергеева (псевдоним н.берег)
# о.фомин
# дорон пас, йоав пас
# пон чжун-хо
# о.дибцева, д.булгаков, а.ильин, а.шабаров, а.борщева (псевдоним - анастасия шахватова)
# д.шумакова
# бронвин деннисон, мигель мартинез-хоффре, пол браун
# бен гез, александра кулак
# м.зыков
# риккардо милани
# майкл дэвид пэйт
# танигути горо
# ю.мамин
# мэтт аселтон
# е.гусева
# ян бергер
# алексей козлов
# клэр маккарти
# антуан блоссье
# м.зыков, ф.абрютин
# даниэль фергюсон
# д.давыдов
# кори пирсон
# м.карри, у.киндрик, и.пьятт, а.рис, с.роден, с.сури, н.хартанто
# джеймс франко
# энди мускетти
# хироюки имаиси
# юхэй сакураги
# а.богатырев, а.камачо
# джастин пембертон
# кристиан волькман
# леон динг
# и.соснин, п.андреева, м.местецкий, е.стишова, м.архипов
# йоаким роннинг
# валерия паризи
# сальвадор симо
# лорин скафария
# ю.ардашев
# гаррет прайс
# линь хуэйда, дин лян
# г.сальников
# барт фрейндлих
# м.мерзликин
# арно деплешен
# п.ольденбург
# мэтт тирнаур
# шеймус мёрфи
# нильс болбринкер, томас тильш
# дэвид дитль
# алан линдсэй
# марко кройцпайнтнер
# п.анделл, м,барбе, а,войячек, ф.дэвис, ф,кит-роуч, а.лейт-роджерс, х.о.рамос, и.пиат, о.прендергаст, м.риахи
# и.дамаскин, р.рашитов
# джакомо гатти
# т.байбл, р.вивье, к.гравенд, с.злотэску, м.зулоага, э.калемар, а.капур, к.ле тёфф, н.лурм, г.робертс, т.руссо, р.тёрнер, й.эвер-хадани
# кевин джонсон
# м.айрапетов
# а.цыренов
# тони пауэр
# с.ростоцкий
# и.фрэз
# самуэль жуи
# маноло мунгуйя
# рёта накано
# гэбриел маскаро
# брайан ли
# и.белов
# а.михалков (псевдоним а.кончаловский)
# джордж галло
# кейси аффлек
# келли эсбёрн
# н.маханько
# томас ян
# йоханнес нюхольм
# ник хэмм
# люсия гарибальди
# дэвид рэймонд
# тони уэст
# мэттью беттинелли, тайлер джиллетт
# андреа блок, кристиан хаас
# д.штурманова (псевдоним: дуня лисова)
# кэндзи камияма
# луис ортега
# понгса корнсри, гун пхансувон, нат йосватананонт
# тара пирния
# а.злобин
# силвейн уайт
# карлус диегос
# сузанна фогель
# в.приходько
# пьер греко, нэнси севард
# яне магнуссон
# джеймс крамп
# э.нелидова
# н.шмелёв
# а.остапенко
# дрю пирс
# е.белова
# м.бигоцкий
# л.кулагина
# н.фролова (псевдоним камалов ленар)
# н.антонов
# е.дворецкая (псевдоним - елена лобачева-дворецкая)
# ю.бобкова
# к.белевич (псевдоним - кирилл астахов), г.ильин
# в.хохлов, к.ляшенко
# карл мендес
# в.шамиров, д.балинова, р.хачмамук
# клайв тонг
# д.курочка (псевдоним денис бродский)
# р.газизов, а.исрафилова, м.конева
# ромен гаврас
# д.демура
# н.тамаров
# лео жанг
# оливер дэйли
# н.климчук, о.морозова
# хань янь
# а.свирский
# е.астрецова
# аниш чаганти
# кевин коннолли
# е.кривцов, в.кленин
# а.игудин
# м.мошкова, а.бахурин, а.борисова, а.аверьянова, т.мошкова
# герард макмюррей
# дженнифер ю.нельсон
# ж.бекмамбетова
# г.заозёрский
# ю.захарова
# в.арясов
# ю.шамилов
# стэнли кубрик
# с.шаглеева
# е.резников
# е.безбородов
# л.шмельков
# а.шадрина
# а.шемес
# а.марсакова
# в.чичайкин
# е.королева
# а.краевский
# альберт хьюз
# хади хаджэйг
# мари мондж
# н.федченко
# б.мамлин
# а.чеботарева
# серикбол утепбергенов
# галина миклинова
# я.войтова, и.черджиева
# о.гончаренко
# е.кашинцева
# м.черных
# и.семашко
# а.рудницкая, с.винокуров
# а.полунина
# д.семибратов
# р.верещак
# панос косматос
# е.стишова
# хезер ленц
# карин пройя
# а.денисова
# м.идов
# а.сухарев, г.шенгелия
# дэвид керр
# жан-стефан совер
# мэтью каллен
# н.евстифеев
# и.стам
# михаэль ноер
# али аббаси
# вольфганг лауэнштайн, кристоф лауэнштайн, шон маккормак
# а.голуб
# мэттью м.росс
# к.соколов
# д.цветков, а.петрова
# а.цыренжапов, б.цыренов, б.доржиев, б.цыбиков, в.овчинников
# д.сулейманов, о.мусин
# с.харчевина (псевдоним - светлана крапивина)
# а.горбунов
# джонатан бэйкер, джош бэйкер
# п.олевский
# л.марголин, а.марутян
# с.токалов
# дэвид дуглас, дрю фелмэн
# дэвид зеллнер, нейтан зеллнер
# гэри ван
# брайан хенсон
# сиддхартх малхотра
# т.малова
# а.сашнева
# том вольф
# т.семенченко
# мэнди флетчер
# с.воронежский
# а.титов, л.ефимов
# томас боденштайн, маркус хаман
# кловис корнийяк
# кайл райдаут
# исида хироясу
# в.смолина
# т.джураев
# г.болдугеров
# а.шустикова
# р.фазлиев, а.галиаскаров
# а.южаков
# эмили атеф
# с.филиппова
# дэвид бэтти
# майкл митчелл, триша гам
# брайан о.мэлли
# а.петров, м.кулагин
# а.залдастанов
# а.бушнев
# в.сунцов
# м.лиманский
# джеймс франко, брюс тьерри чунг
# фридрих боэм
# д.степанов
# джеймс окли
# брэд берд
# фернандо леон де араноа
# билл холдермэн
# карл кристиан раабе
# лоуренс фаулер
# а.зенкович
# лукас фейгельфилд
# н.веревкина
# в.фатьянов
# а.русланова
# м.новикова
# о.холодова, е.савина, а.чернова, н.рысс, а.дёмин
# и.басенко (псевдоним - ирина бас)
# а.сутормин
# джованни пискалья
# дженнифер пидом
# д.гринькин
# франк дюбоск
# р.гиматдинова
# и.максимов
# д.алейников
# е.астрецова, е.фадеев, в.карнавалова, е.филиппова, а.веселов, и.максимов и др
# т.дондурей
# а.коломеец
# филипп волкен
# торстен кюнстлер
# д.дваджиев
# а.поличук
# и.петухов
# с.григорьева
# и.ягафаров
# т.жалнин
# энтони бирн
# ориол паоло
# джереми дайсон, энди найман
# а.ким
# д.шабаев
# андрес кутерье
# м.шалаева
# массимо гаудиозо
# с.храмых
# и.евланникова, д.моллер, м.котик
# а.безрук
# н.мещанинова
# а.новоселов
# н.першина
# в.битоков
# с.ливнев
# бландин ленуар
# м.воробьева
# густаво эрнандес
# е.киреева, т.кисилева, е.нестерова, а.панкратов, о.сивакова-васина, а.романова и др
# с.филиппова, с.антонов, к.кравченко, е.храпкова, е.бим, а.зайцев и др
# бен луин
# ю.миронова
# матьё тури
# джастин бенсон, аарон мурхед
# о.головина
# а.петров
# а.горбунов, д.сулейманов
# в.алфёров
# в.семёновых
# элайджа байнум
# майкл уинник
# джеймс кокс
# джон тёртлтауб
# гильермо амоедо
# пол вонг, феликс ип
# к.кокорев
# а.писаркин, э.мецгер
# д.крылов
# йеспер гансландт
# а.осипова
# м.елкин
# и.фирсова
# т.бочарова
# т.корнеева
# а.истратов
# н.михалкова
# кристофер маккуорри
# м.солошенко
# а.кузмин-тарасов, а.колчина
# томас штубер
# д.даниелян
# ю.курочка
# о.белоусова
# в.мякишева
# джефф томсич
# с.ермоленко
# стефано соллима
# г.якубовский
# а.бойков
# в.новиков
# кристиан дюгей
# майкл пирс
# н.раужин
# е.шин
# а.кузина
# джанлука ансанелли
# джейсон райтман
# а.корытко
# в.кузнецов
# и.иванов
# м.сергеева
# доминик роше
# ю.сизов
# м.бирюкова
# ли чхан-дон
# в.гришин (псевдоним - влад гришин), а.тельнов
# е.туркова
# лян сюань, чжан чунь
# э.бордуков, г.дульян, м.тумова, э.жолнин, в.кудряшов
# м.куклина
# э.арутюнов, а.алексиади
# максим арбугаев, кристиан фрай
# изабель койшет
# пол дано
# даниель отой
# м.васюнов
# наталья малыгина
# я.лаптев (псевдоним яков раскалов)
# д.резванов, о.хружков, и.вейштагин
# т.бекмамбетов, а.першин (псевдоним ж.крыжовников)  , а.пармас, е.баранов, а.котт
# д.кабаков
# джордж рэтлифф
# боб персичетти, питер рамси, родни ротман
# е.ермолина
# д.цибаускайте (псевдоним - дали руст)
# а.круглов
# р.янковский
# сара коланджело
# н.микрюкова
# о.ларин
# жиль де местр
# ю.рыбакова
# ю.бердников, а.васин
# герман васке
# с.раздорский
# в.сидоренко
# о.лещинер
# питер фаррелли
# джованни троило
# евгений голынкин, николя милетич
# а.домогаров (младший), в.кашляев, а.волгин, и.вилкова, и.волкова
# джози рурк
# антони кордье
# а.карелина, а.филиппова, е.ланских
# валерио аттаназио
# е.милых
# в.бек, и.оганесов, а.симакова, п.сеплярский
# леопольдо агиляр
# джон леннон, йоко оно
# кристиан риверс
# дженнифер весткотт
# хореограф матс эк
# гунилла валлин. хореограф матс эк
# м.алина
# с.данилина
# о.броневицкая
# в.тертышный
# в.воронцов
# с.черников
# перри лэнг
# мачией лиговски
# эмилио бельмонте молина
# е.севастьянов
# е.обермаер (псевдоним е.шапиро-обермаер)
# а.новокреповская
# т.новикова
# брэндон кристенсен
# себастиан гробер
# аркадий коган
# александр абатуров
# андрэ шефер
# и.долгина
# о.аверкиева
# е.паршина-штайн (псевдоним елена штайн)
# а.сайфуллина
# в.витовцев
# с.мкртчян
# энди миттон
# даниэле лукетти
# с.лыгденов
# е.егоров
# анна соловьева, наталья березовская
# крэйг уильям макнейлл
# в.вохминцев, и.оганесов, а.безрукова (псевдоним - анна матисон), р.мухомеджан, е.сычёв
# а.шемятовский, и.оганесов, к.гогленкова, а.смирнов, а. евсеев (псевдоним - хант), с.королева
# а.сазонов, е.климович, а.коломеец, с.черникова, е.олейник, а.ефимова
# д.панченко
# вари ом, джорджия уайсс
# р.чумаков
# крис мул
# патрик кассир
# сара драйвер
# п.сидоров
# патрисия уитли
# о.барковская
# м.бальчюнас (псевдоним марюс вайсберг)
# е.дорофеева
# в.потемкин
# с.быченко, т.обозова
# и.затевахин
# с.гарькавый
# п.солдатенков
# г.курлаев, и.ситников, а.щеглов, в.панжев и др
# о.дроздова
# к.герасимов
# г.тесля-герасимов
# с.крючков
# карстен килерих
# р.карапетян
# манс бертас, ульрика бандейра, джулия гумперт, оливия кастербринг и др
# о семёнова
# м,найт шьямалан
# а.цицилин, роберт ленс
# с.быченко
# стивен кейпл-мл
# николас песке
# р.шарафутдинов, е.куркова, м.соснина, р.синкевич
# хеннинг кастен
# г.жихаревич
# а.кадыкова
# е.хломова
# а.красильщиков
# г.игнатов
# е.савин
# г.щерба
# а.лукьянчиков
# феликс ван грунинген
# в.потапов, а.карелин
# янн деманж
# джулиан шнабель
# хуан вера
# асаф бернштейн
# итан коэн
# м.абдулкадыров
# в.дьяченко
# э.тухарели
# в.николаев, м.бабенко
# а.сахелашвили
# митци пейроне
# лукас донт
# уош уэстмоленд
# эммануэль жилибер
# в.эйснер
# куинн лэшер
# луиш диого
# ю.горбачевская
# п.ходнев
# в.саков
# а.самойлов
# а.судиловский
# томас граскур, адина истрате, пако каверо, александр ланка, норман тамкиви
# финн тейлор
# джеффри начманофф
# грег кос
# а.титов
# м.костарев, н.саврас
# л.лысцов
# а.линич
# а.куликов
# ари сендел
# с.митин
# в.локтионов
# л.коршик
# е.дубкова
# павел павликовский
# айан бонхот, питер эттедги
# с.иванов
# билл оливер
# камаль бансаль
# такуя игараси
# с.миляев
# в.ракша
# а.арутюнян, а.коршунов
# кэри киркпатрик
# сантьяго лимон
# д.кузнецов (псевдоним - хаски), д.найшуллер (псевдоним - даша чаруша), с.поварницын, а.золотарев, и.плечёв
# чак пауэрс
# брэдли купер
# хлинюр палмасон
# е.останина, с.родкевич
# в.непевный
# рубен флейшер
# дрю годдард
# мамора хосода
# е.болычева
# к.серебряков
# к.попович
# сторм эшвуд
# гари вонг
# ю.ершова
# и.корнеев
# е.антимоний (псевдоним - иван курский)
# а.турчанинов
# м.юсупов
# жюльен леклерк
# скатт спир
# к.козлова
# г.константинопольский, д.булин, е.чичканов, д.власова, п.емелин
# м.киреева
# е.цымбал
# а.сидоров, о.фомин, р.ярославцев
# э.габидуллин
# д.колонтай, и.качалин, д.глазовский
# к.румак
# а.шабаров, д.булин, н.михалкова-кончаловская, г.пирогова, е.вещева, т.федоровская, е.абызов
# в.потёмкин
# а.егоров
# н.иванова, а.кузнецова
# в.захаров
# н.бисярина
# а.соколова
# пьер шоллер
# джо джонстон, лассе холлстрем
# франческо мунци, лучио пеллегрини
# дарья жук
# а.проскура
# е.шереметьева
# с.рубенчик
# том эдмундс
# ганс вайнгартнер
# эндрю боулер
# эндрю десмонд
# а.жакулина
# фил джонстон, рич мур
# а.колядин, м.павлов
# н.пиотровский
# к.красноперов
# к.мирзоян, а.петрухин
# фредерик пакстон
# в.макарихин
# е.бронникова
# сэм левинсон
# о.арлаускас, г.петросян, с.горло
# отто батхёрст
# в.есинов
# в.орехов
# п.фаттахутдинов
# д.силяков
# м.ховенко
# с.кирсанова
# и.евланникова
# г.голубева
# н.грофпель
# в.лавров
# демиан рунья
# м.рафаил
# п.хвалеев
# и.осипов
# е.захаров, а.соснов
# а.рожнова (псевдоним александра р'юж)
# бьёрн рунге
# мила онг-твин, ван рёко
# вэйшали синха
# жиль леллуш
# донован марш
# мат уайткросс
# эрик зонка
# д.гусельников
# а.голубовский
# н.михалкова-кончаловская
# я.хальпукова (псевдоним яна мартынец)
# а.коновальцева (псевдоним ангелина подорожная)
# а.рубецкой, е.шабанова
# м.смирнов
# н.батраева
# и.сарахатунова
# г.калинина
# пернилла фишер кристенсен
# николас столлер, даг суитлэнд
# б.бадриев
# якоб розенберг
# а.сильвестров
# марина де ван
# пол шредер
# фарид гумбатов
# джонатан ауф дер хайди, миа васиковска, клер маккарти, йен медоуз, стивен пейдж, эшли пейдж, саймон стоун, уорвик торнтон, мариека уолш, дэвид уэнэм
# с.ольденбург-свинцов
# карло карлей
# а.вартанов, к.михановский
# хореография пьера лакотта по филиппу тальони
# сандра неттельбек
# дебора андерсон
# джесси маккормак
# энтони марсиано
# в.гай германика
# сильвен шоне
# джон карни
# дуглас амиокоски
# ...
# саймон эбауд
# а.хант
# пьер годо
# дэн кван, дэниэл шайнерт
# теа шеррок
# майк термайер, гален т.чу
# джонатан кесселман
# родриго гарсия
# паскаль бурдьо
# сэм фридлендер
# р.шульман
# д.таран
# николас бенаму
# мартин кулховен
# эрик саммер, эрик уорин
# хьюго желен
# марен аде
# энтони пауэр
# шелдон уилсон
# хулио сото гурпиде
# м.демченко
# аскар бисембин
# али замади ахади
# с.азази, х.г.пене, к.дик, т. вон гюнтен
# кристобаль крузен
# м.бэйкер, д.е.брайант, д.рондот, я.серсар, д.спинелли, ж.халард,   м.эмануэлли, х.эмануэлли
# а.ильин
# пэтти дженкинс
# джон клацкевич, курт морган
# катерина кароне
# марио ван пиблз
# д.хананов
# д.золототрубов
# е.морозов
# манук депоян
# тоби генкель, реза мемари
# н.меркулова
# а.арпеньтеньер, а.бариларо, м.бланчес, р.валлей, л.гранд, ф.дион, а.жасина, э.коэтс,  лу хаму-лхад, п.осборн, т.ушев
# хатем храиче
# гилберт кинг
# с.аксенов
# пако леон
# аарон кауфман
# синг-чунг фу, бетти тэнг
# конрад вернон, грег тирнан
# робин суикорд
# эндрю стентон, ангус маклэйн
# са ниа
# дэвин дихэйвен
# н.досталь
# е.борисова при участии в.фатьянова
# дэвид лоуэри
# е.чичканов
# томохиро кавамура, йосихиро комори
# дэвид кэмпбэлл
# хак ботко
# в.фурманов
# юлиан радльмайер
# кристиан де вита
# хью лори, бен элтон
# мика каурисмяки
# м.маханько
# сэм вуд
# ален вулф
# дени деркур
# роберт уилсон
# эмма данте
# в.кущинский
# юэнь ву-пин
# хью родс
# уэс крейвен
# фернандо труэбо
# нил ла бьют
# а.самойлова
# ю.мазурова
# е.сысоева (с.лысенко)
# м.рязанова, н.репина, в.панжев, д.никулин и др
# е.ташков, а.ташков
# а.юмагулов
# жюли бертучелли
# а.бзаров
# с.арланов
# гари виник
# тенисон бардуэлл
# а.джунковский
# трент купер
# м.рязанова, в.панжев, г.курлаев, м.сулейманова, н.репина, с.морозов и др
# джейсон эпперсон
# а.адилханян
# патрик люссье
# гейб ибаньес
# йорген лердам
# и.ромащенко
# жак перрен, жак клюзо
# корнелиу порумбойю
# р.ганган
# д.ефремович, а.каторженко
# и.цветов (режиссер ч/б фильма - с.тимошенко)
# мэтью вон
# микаэль саломон
# и.соловьева, д.шмидт, о.ужинов, д.червяцов, м.нефедова, о.кузовков
# эндрю морахан
# лука ронкони
# д.мастеров, н.попова
# клод миллер, натан миллер
# пэдди бретнэк
# дэвид маллет
# сэм тейлор вуд
# н.мирзоян
# д.сулейманов
# софи бартез
# йоахим роуннинг, эспен сандберг
# томас борч-нельсен
# д.мамулия
# мик ван дием
# дэвид мур, джереми вебб, метин хусейн, элис тротон
# к.котельников, а.аболс
# в.федоров
# джанкарло дель монако
# и.савельев
# агнешка войтович-восло
# жалмари хеландер
# матье амальрик
# дениэл эспиноза
# джордж миллер, уоррен коулмэн, джуди моррис
# эндрю дэвис
# рэйджа госнелл
# берр стирс
# а.стемпковский
# е.гроховская
# марк махон
# п.санаев
# а.марутян
# с.борчуков
# а.мачерет
# джон х.уильямс
# скандер копти, ярон шани
# а.щербинин
# г.негашев
# ю.мерзляков, р.магомадов, а.ольков
# м.сулейманов
# фатих акин, иван атталь и др
# джина ким
# л.шалгачева
# а.виткин, м.беспалый
# джей дюплис, марк дюплис
# йорма такконе
# хирокадзу корэ-эда
# питер доктер, боб питерсон
# нора эфрон
# карлос саладна
# генри бин
# дункан уорд
# а.барщевский, и.матвеев
# а.эшпай
# п.бардин
# паскаль бурдиак
# шем биттерман
# ли сингму
# эли крэйг
# том ди чилло
# деон тейлор
# берни маттинсон
# с.бодров-старший, г.омарова
# марк с.уотерс
# рассел малкэхи
# дэвид макнелли
# сяолу го
# джадд апатов
# стефен соммерс
# аллен колтер
# чхан-ук пак
# трой миллер
# хава эссуман, том тыквер
# с.абрахамс, ф.гарсиа-руис, р.лиментани, т.розин, г.тис, а.энгель, м.и.эпштайн
# шэрон магуайр
# чарльз покел
# е.михайлова, и.максимов
# ю.сапонова
# барри дженкинс
# н.беляускене
# бенедикт эндрюс
# кристиан матысек
# а.молочников
# т.воронецкая, а.богатырев
# о.агейчев
# кайл балда, эрик гуильон, пьер коффан
# джон дженкс
# кимо стамбол, тимо тьяджанто
# игор биддау
# антонио капуано
# марк уильямс
# эндрю росси
# м.барынин
# тод "кип" уильямс
# хосе майа, фредерико пинто
# ж.альберт, м.кунерт, м.митник,  д.рейниш, м.ричмонд, д.соскин,  в.стотер, д.ходжсон
# мари мадинье
# майкл мур
# кенни янг
# каспер барфоэд
# жан-франсуа пуле
# кен сэнзел
# р.рашитов, с.сунгатуллин
# т.корнев
# р.хамдамов
# а.лукичев
# чан гуанси, пэн фэй
# тьерри фремо
# а.журавлева,м.кузнецова,с.меринов,а.дьяков,о.ужинов,н.гребенкина,а.соколов
# х.стойчев, с.кулиш
# марилу берри
# к.баскакова
# а.каурых, с.охотин
# эген уулу нурбек
# д.шмидт, ф.дмитриев, в.торопчин
# д.дунаев
# ребекка злотовски
# а.бальчев
# р.каргаполов
# о.кузовков, и.трусов, а.беляев, н.мальгина, в.байрамгулов
# даниэль рагуссис
# стюарт хендлер
# юэн макгрегор
# маркус дэнстон
# педро морелли
# шинтаро шимосава
# а.созонов
# а.касаткин
# ф.коршунов при участии п.мирзоева
# дэвид френкель
# тед мелфи
# а.аболс
# айван райтман
# р.кубаева, с.щугарев, я.мочалов
# кристиан алварт
# брюс бересфорд
# томас джейн
# дэвид о'расселл
# в.дубровицкий
# л.габриадзе
# тошикадзу нагаэ
# джон уайтселл
# в.аравин
# дэйвид р.эллис
# дейвид макнэлли
# дэни леви
# е.кончаловский
# дональд шебиб
# бетти томас
# мира наир
# хойт йетман
# хон сан су
# п.масларов
# энтони бэлл, бен глюк
# а.кавун
# алекс пастор, дэвид пастор
# ришар бери
# обри паулл
# в.огородников
# джон мктиран, майкл крайтон
# михаэль дюдок де вит
# г.михалков, г.натансон, в.сторожева, а.касаткин, а.михалков, а.разенков, э.суни и др
# пабло ларраин
# ю.калинина
# м.кукушкин, т.данн
# а.селиверстов
# а.васин, г.параджанов, о.бородина
# с.ушаков, и.евланникова
# а.грабарь
# э.назаров
# а.попогребский
# л.гладунко
# е.семенов
# с.дебижев
# д.боголепов
# в.юркус
# а.самохвалов, б.ростов
# джесс гордон
# в.потапов, ю.бердников
# валерио мьели
# онир
# л.носырев
# м.вайсберг
# х.нарлиев
# чуан лу
# данте лам
# и.сафаров
# динг лианг, фуюань лью
# марк дакаскос
# том маккарти
# н.джорджадзе, в.игнатьев
# д.штурманова
# а.аравин, а.прошкин
# к.ангелина
# стефано лоренци
# в.штерянов при участии е.немых
# е.салабай, е.шабанова, а.миронов, а.толстобров, в.мухаметзянов
# о.бондарев при участии в.чеботарева
# ю.озеров, с.гуров
# с.урусевский
# с.эйзенштейна
# з.аграненко
# о.ремизов
# б.бушмелев
# в.азаров, н.досталь
# в.максаков
# а.пархоменко
# джош лоусон
# р.д. браунштейн
# ялмари хеландер
# а.ананикян, в.рейнгеверц
# е.салабай, е.шабанова, а.соколов, и.пшонкин и др
# к.белевич
# в.крючков
# и.пшонкин, м.ершов, а.миронов и др
# джил кинан
# в.пономарёв, а.миронов, а.колпин, а.толкалин и др
# грегори джейкобс
# кайл балда, пьер соффин
# марике блау, дэйзи джейкобс, глен кин, роберт кондо, торилл коув, йорис опринс, патрик осборн, билл плимптон, йоб роггевен, даизуке цуцуми
# в.елина, ю.кошкина, к.макаренков, с.юдаков, т.игуменцева
# седрик хименес
# д.нейдманд
# алик моухибян, герин хованнисян
# джеймс моран
# кайл ньюман
# пит доктер, роналдо вуд кармен
# джулиан джаррольд
# альфредо монтеро
# кэт кэндлер
# карлос маркус-марсет
# энрико кастильоне
# джошуа оппенхаймер, кристина синн
# лиза иммордино врилэнд, бент-йорген перлмутт, фридерик ченг
# алан тэйлор
# к.денё, х.дюмулайн, а.кардона, т.мекинс, д.фини, м.фонтан-росси, л.хадсон
# джош форбс
# е.константинова (псевдоним алена званцева)
# в.орёл
# давид лево
# колин фей
# риад саттуф
# а.коручеков
# р.асхаев
# одед биннун, михаль брезис, мат кирби,  майкл леннокс, талкон хамзави
# м.капля
# петер торварт
# л.шмурьева (псевдоним лика алексеева)
# тарсем сингх
# яннис смарагдис
# макс джозеф
# м.ксейбати, и.лопез, э.лоурич, к.м.сабер, к.о.тул,  р.серри, р.тьюннард, м.энгламайр
# петер штайн
# д.зинченко
# н.кудряшова
# д.лазарев, с.антонов
# г.нуриманов
# нэнси мейерс
# в.пономарёв, а.миронов, е.салабай, а.хачатурян, е.чернова, а.бахурин
# жан-батист леонетти
# дана браун
# себастьян шиппер
# роланд жоффе
# елена аршакян
# р.гарифуллин
# д.кузьмин
# э.оганесян
# м.местецкий
# о.смольников
# р.гигинеишвили, к.оганисян, р.прыгунов
# стив карр
# дэн гилрой
# рой андерссон
# майк ван дим
# баран бо одар
# маржан сатрапи
# цунэо кобаяси
# рикардо арнаиз, рауль гарсиа, майк кункель
# жамель деббуз
# ник саймон
# и.пшонкин, е.салабай, а.миронов, а.толстобров, в.мухаметзянов
# норберт хайткер
# и.перекатов
# р.ильясов
# с.пускепалис
# джейк шрейер
# трейвис клафф, крис лофинг
# карл тордж
# м. абрамов, ж. анноккии, м. дансембург, д. кларк, л. де кон, в. мавония-койка, к.б. рафаэль, л.стюарт, б. тондер
# м.фадеев
# джонатан голдстейн, джон фрэнсис дейли
# ма юань, донь да ке
# лора пойтрас
# лео габриадзе
# антуан бардо-жаке
# седрик анже
# губерт вайланд, нина вельс
# джошуа трэнк
# стефан либерски
# а.чукарев
# в.рощин
# а.грицаенко
# в.пономарёв, а.миронов, е.салабай и др
# э.манжеева
# е.салабай, е.шабанова  и.пшонкин и др
# р.светлов, и.магитон, а.арутюнян, л.мирский, а.зеленков, м.сулейманова и др
# е. махнутин (псевдоним - евгений юматов)
# джонатан кент
# бен нотт, морган о.нил
# роберт ганнэвей
# лассе халстром
# д.елеонский
# р.шаляпин
# а.григорян
# с.никоненко
# в.толкачиков
# и.анненский
# в.немоляев
# ю.даниялов
# г.мелконян
# а.столбов
# амат эскаланте
# питер стрикленд, ник фентон
# хорхе с.дорадо
# линн шелтон
# сакет чаудхари
# б.токарев, л.гладунко
# биргер ларсен
# фред скеписи
# крис уильямс, дон холл
# дмитрий черняков
# хэмиш гамильтон
# б.волчек
# а.килин, с.потапов
# мираэ мицуэ, петрос сильвестрос, билли ройз, фридрих шлайх, алекс уинклер, йонг ю ми, элке гроэн, кристиан нойбаухер
# э.архангельская, м.пандурски
# с.дахин, п.духовской
# е.грибов
# серджо бассо
# илай рот
# вэй кеунг лау, эндрю лу
# дэвид юнг
# энтони стакки, грэхэм эннэйбл
# филиппе мартинес
# а.яхнис, м.кричман
# п.костомаров, а.расторгуев
# пер флю
# мак картер
# и.маслюков
# николаус ленхофф
# грачья кешишян
# и.котельников
# в.бродский
# азия ардженто
# мартин уильямс
# дэн сан пьер, уилл финн
# зоя ахтар
# энтони сильверстон
# джонатан глейзер
# а.розенберг
# г.параджанов
# жан-пьер жёне
# клаудио фах
# виола байер, стефан берман, мэрайке блау, йорис опринс, пол плобергер, жан-батист пуйю, йюст раймерс, йоб роггевен, эрик шмит, бен эстон
# а.захаров
# шейн аткинсон, питер бауман, парк дже ин, реми каяла, эрик киссак, петра лючков, нильс хедигер
# мирослав слабошпицкий
# корнель мундруцо
# б.метальников
# е.зильберштейн, а.дудоров
# м.янчо
# э.шуб, а.фролов
# б.жамьянгийн, а.бобровский
# в.харченко, а.волков
# а.а.эшпай
# в.пономарёв, а.миронов, е.салабай, и.пшонкин
# и.чижиков, а.чижиков
# с.самошина, н.тамаров, п.руминов, в.санду, к.плетнёв
# алекс гибни
# эрик инглэнд
# остин старк
# ули эдель
# а.адраникян
# митчелл алтери
# джастин стил
# в.пономарёв, а.миронов, е.салабай, в.бедошвили и др
# э.шенгелая, ф.ибрагимбеков, при участии т.бутикашвили
# нанни моретти
# тед гейган
# даниэль бурман
# т.березанцева
# инджинио страффи
# жауме балагуэро
# андреас прохазка
# винсент чжоу
# в.лонской
# а.ладынин
# м.рык
# а.панкратов-черный
# стэнли юнг
# жуанра фернандез
# мишель дэннер
# кристиан е. кристиансен
# бенедикт эрлингссон
# и.белостоцкий, р.фрунтов, а.зеленков, е.юликов, с.морозов, а.щеглов, г.курлаев и др
# п.фетисов
# х.бакаев
# марко пьянджиани
# м.медведь
# джереми джонс, стив джонс, тодд джонс
# винко брешан
# дэниэл шехтер
# скот армстронг
# энтони фукуа
# питер муллан
# дин израэлайт
# лана вачовски, энди вачовски
# дженнифер кент
# дамиан шифрон
# тони макнамара
# в.пономарёв, а.миронов, е.салабай, н.мальгина
# гейб польски
# робин верет, дмитрий гочгарян, тиль новак, росто, корали фарго, патрисия фонт, дэн хогсон, янгци ши
# с.кравцова, а.калин, е.чернова и др
# ксавье джанноли
# росс кац
# н.кудряшов
# н.мубинов, а.чернова, с.горя, а.черногоров и др
# у.бош, м.данкер, л.индовина, к.кэхилл, р.люкер, б.магнотье, э.маргетсон, т.эльрих
# джеймс нанн, ронни томпсон
# джонатан силвермен, дженнифер финниган
# г.проценко
# о.столповская
# скотт манн
# в.харьков
# а.русланова (псевдоним - саша франк)
# винсент кестелут, бен стассен
# мадс маттисен
# а.китайцев
# луи летеррье
# г.дюкарев, а.рубинштейн, а.ким, м.воскобоев, н.беляускене
# алис винокур
# бенжамин роше
# александр сокуров
# а.андризани, а.бардани, в.карнелутти, ф.коста,  г.с.нардис, в.пальмьери, в.чеа, а.юлиано
# ф.ало, д.баккер, э.креси, к.рот, д.рэймерс, с.тэйлор-джонсон, л.уплэйн, х.м.фазели, ч.ч.ким, э.эйнхорн, п.эмерсон
# м.валто, а.диксон,  ж.крыжовников, д.ласу, т.лесурд, д.оду, м.пелисиоли, б.плимптон, а.тонен, л.фирод
# дани де ла орден
# р.артемьев, г.суханова, а.маслов, и.максимов, н.тамаров, а.нужный
# татьяна данильянц, джанфранко панноне, диего ченетьемпо
# гэрри маршалл
# гуэндалина дзампаньи
# тревор уолл
# п.бар, к.баркер, к.бронзит, м.демаре,  ю.жан, ж.журдан, п.-б.марти,  г.осорио, с.патэль, м.пилье, б.плимптон, ж.робин,  к.роже, ж.солер, н.филан, н.форнер,  д.херцфельд, к.ше
# а.амиров
# и.найтшуллер
# вано бурдули
# т.сличенко
# жан-мари пуаре
# майкл мэдсен
# а.давыдова
# к.геворкян
# е.данченко
# т.мамедов
# ю.сысоев, в.мистюков, к.тищенко
# георгий варсимашвили
# ник рид, сорежиссер марк франкетти
# зося (софия) родкевич
# р.артемьев
# роберт карлайл
# дэвид фейсс
# тео пирри
# иван джерголет
# стефано инчерти
# роландо равелло
# давиде феррарио
# пьетро паролин
# кан евренол
# лиза джонсон
# джонатан демме
# марко беллоккио
# а.миронов, е.головин, е.савчук, р.верещак, е.салабай, е.чернова, а.бахурин
# г.курлаев, в.панжев, е.соколов, с.морозов и др
# джей блейксон
# уилл кэнон
# с. крэйг залер
# оуэн харрис
# н.степанова при участии с.иванова
# а.майовер, д.крылова
# т.м.райвс
# а.соколов
# раман хюи
# джесси нельсон
# эриксон кор
# франсуа бриссон, жан-франсуа пуле
# марк осборн
# а.миронов, р.верещак, а.грибков, а.соколов и др
# м.михайлова
# джон маклин
# элла лемхаген
# дэвид листер
# дж.п. сниадецки
# хонгки ли, монс монссон
# дэвид о.рассел
# маттиас олоф эйх
# у.грайнер, д.гротелл, г.мендеш, м.ситер, а.халискиас,  ж.хосмалин
# а.михалков
# р.сафин
# майкл дж.сарна
# д.шмидт
# п.ливолси,э.моргетсон, к.рейнер, р.русенс, я.русенс, д.ходжсон, б.шоу
# в.лакисов
# п.воллрат, д.донахьюм, б.клеари, б.халил, г.хугхеш
# клаудиа майерс
# луи симон
# артур бензакен
# джейсон зада
# ю.белюсева
# в.бек
# люка бельво
# е.салабай, в.пономарёв, а.миронов, е.головин, а.бахурин
# эндрю хэй
# а.коваленко
# грен уэллс
# т.харкевич
# м.кравченко
# м.вартанян, е.головин, а.миронов, о.шепляков, а.борисова, е.шабанова
# кевин гетц, майкл гетц
# алекс пройас
# с.эйзенштейн, д.васильев
# г.мыльников, б.токарев, а.сиренко
# эндрю морган
# а.томашевский
# е.салабай, р.верещак, е.головин, а.миронов, е.савчук, р.газизов, е.шабанова
# а.миронов, к.кравченко, е.головин, е.савчук, а.соколов, р.верещак, е.салабай
# клаудио уберти
# сара адина, энтони скотт бёрнс, кевин колш, николас маккарти, адам иджипт мортимер, кевин смит, скотт чарльз стюарт, деннис уидмайер, гари шор
# рошди зем
# арнольд гискин
# брек эйснер
# киран фой
# э.бордуков
# а.нужный
# джэймс кэмерон
# джулиано никколо лигабуэ, марко раффаини
# габриэль рива паласио алатристе, родольфо рива паласио алатристе
# л.густаво купер
# штефан кромер
# джонни о'райлли
# а.балахонов
# в.мухаметзянов, в.пономарёв, а.миронов, е.салабай
# с чекалов
# арман марутян, ваагн хачатрян
# вим вендерс, джулиано рибейру сальгаду
# а.агаджанян
# шон патрик о.рейли
# о.ланд
# е.салабай, в.пономарёв, а.миронов, и.пшонкин, а.рубецкой, н.харина, е.чернова, а.бахурин, о.ужинов
# и.кордзаия
# в.пономарев, а.миронов, е.салабай
# масахико мурата
# хаято датэ
# а.анненский
# мартин бурбулон
# дениз гамзе эргювен
# п.буслов
# питер соллетт
# пабло фендрик
# а.першин (псевдоним ж.крыжовников)
# тристан паттерсон
# жослин таун, саймон хелберг
# дэниел альфредсон
# йуис килес
# дэн фогельман
# райан гослинг
# т.зубова
# андре сингер
# кэри мёрнион, джонатан милотт
# дэниэль эспиноса
# адриан биньес
# а.шелехов (псевдоним александр шелл)
# бенуа филиппон, алесандр эбоян
# джон фулджеймс
# хореография фредерика аштона
# исаак федер
# мэттью уорчас
# эрве мимран, жеральдин накаш
# алехандро хидальго
# филипп амио, филипп беллимар, мартин брукс, диего виванко, ниниан доф, йан кларк, морган кранц, рас леморо, барри джин мерфи, балазс патаки, дин саффрон, грег хаккет, рейчел хардинг, стефан хенель, стефан шотт
# к.сафина, а.першин, г.добрыгин, о.михеева, к.плетнев
# с.антонов, с.подивилов, в.стрельченко, ю.пронин
# б.терекбаев
# стив бокс, ник парк
# тинатаин каджришвили
# стивен с.кампанелли
# марк невелдайн
# в.пономарёв, а.миронов, е.салабай
# пабло троперо
# бен блейн, крис блейн
# а.рубинштейн, а.ким, м.воскобоев, н.беляускене
# а.миронов, е.головин, р.верещак, е.салабай, в.бедошвили, е. чернова, а.бахурин, а.соколов
# в.ровенский
# и.волкова
# жан-поль раппно
# артур делер, квентин рейно
# фузаль булифа, маркус лехмусусс, майкл мохан, фульвио резулио, маша халберстад
# вильям де витал
# а.дамскер
# брэдли кинг
# акош барноцкий
# м.волков, а.галат, в.николаев
# т.воронецкая, д.сергин
# и.триф
# тоби бауманн
# клэй кейтис, фергал рейли
# т.эверестова
# джон лойд
# джерика клилэнд, кевин манро
# теренс дэвис
# а.демин, р.синкевич, н.березовая, о.ужинов и др
# роман мушегян
# мэттью барни
# майвенн ле беско
# к.дружинин, а.шальопа
# а.миронов, е.головин, е.савчук, р.верещак и др
# рене фере
# дуг эллин
# родни эшер
# терри джонс
# деннис виллануэве
# питер сон
# альберт майзелс
# е.салабай, а.миронов, е.головин, а.борисова и др
# с.хажироко
# л.трофимова, а.курганская
# билли рэй
# дамон гамо
# симон ферхоэвен
# е.перволовичи
# адам шиндлер
# антон корбейн
# тиан сяо пенг
# д.изместьев
# г.куценко (ю.куценко)
# кент джонс
# флориан галленбергер
# афонсо пойарт
# том коркоран
# е.сергеев
# фернандо гонзалез молина
# и.трусов

# %%
coma = ','
first_name = []

# %%
# создаем функция для преобразовния имен
def grab_first_name_or_genre(names):
    if names == 'unknown':
        return names
    elif ',' in names:
        return (names[:(names.find(','))])
    return names

# %%
movies_shows['I_director_name'] = movies_shows['director'].apply(grab_first_name_or_genre)

# %%
movies_shows.loc[movies_shows['I_director_name'].isna()]['director']
# Out:
# Series([], Name: director, dtype: object)

# %%
movies_shows['director']
# Out:
# 0           кевин костнер
# 1               е.матвеев
# 2       тимур бекмамбетов
# 3       тимур бекмамбетов
# 4       тимур бекмамбетов
#               ...
# 7479          фил грабски
# 7480           ник пауэлл
# 7481     чарльз е.бастьен
# 7482             а.беляев
# 7483             и.трусов
# Name: director, Length: 7484, dtype: object

# %%
movies_shows.query('director.str.contains("бекмам")', engine='python')
# Out:
#                                         title   c_number     show_start_date  \
# 2                                особо опасен  221038416 2016-10-10 12:00:00
# 3                                особо опасен  221026916 2016-06-10 12:00:00
# 4                                особо опасен  221030815 2015-07-29 12:00:00
# 417   президент линкольн: охотник на вампиров  121013812 2012-06-07 12:00:00
# 1985                                ёлки 1914  111023014 2014-12-10 12:00:00
# 3609                                   ёлки 5  111018016 2016-12-15 12:00:00
# 3712                           бен-гур (2016)  221042816 2016-11-25 12:00:00
# 3713                           бен-гур (2016)  121024416 2016-09-05 12:00:00
# 4528                                     ёлки  111010710 2010-12-08 12:00:00
# 4957               ирония судьбы. продолжение  111005911 2011-09-05 12:00:00
# 6081                                чик-чирик  114003818 2018-08-14 12:00:00
# 6302                                  учитель  111019518 2018-10-17 12:00:00
# 6508                           ёлки последние  111023918 2018-12-10 12:00:00
#
#                 type                                        film_studio  \
# 2     художественный  юниверсал пикчерз, кикстарт продакшнз, марк пл...
# 3     художественный  юниверсал пикчерз, кикстарт продакшнз, марк пл...
# 4     художественный  юниверсал пикчерз, кикстарт продакшнз, марк пл...
# 417   художественный  абрахам продакшнз, базелевс продакшн, тим берт...
# 1985  художественный                                       ооо "таббак"
# 3609  художественный                                       ооо "таббак"
# 3712  художественный  дезерт вулф продакшн, майкл грандаж компмни, р...
# 3713  художественный  дезерт вулф продакшн, майкл грандаж компмни, р...
# 4528  художественный                                       ооо "таббак"
# 4957  художественный                                     ооо "базелевс"
# 6081    анимационный                               ооо "си-джи-фэктори"
# 6302  художественный                                       ооо "таббак"
# 6508  художественный                                       ооо "таббак"
#
#      production_country                                           director  \
# 2                   сша                                  тимур бекмамбетов
# 3                   сша                                  тимур бекмамбетов
# 4                   сша                                  тимур бекмамбетов
# 417                 сша                                  тимур бекмамбетов
# 1985             россия  т.бекмамбетов, о.харина, ю.быков, д.киселев, а...
# 3609             россия  т.бекмамбетов, и.джендубаев, а.котт, а.шавкеро...
# 3712                сша                                  тимур бекмамбетов
# 3713                сша                                  тимур бекмамбетов
# 4528             россия  т.бекмамбетов, я.чеважевский, а.войтинский, д....
# 4957             россия                                      т.бекмамбетов
# 6081             россия                                     ж.бекмамбетова
# 6302             россия                                      т.бекмамбетов
# 6508             россия  т.бекмамбетов, а.першин (псевдоним ж.крыжовник...
#
#                                                producer  age_restriction  \
# 2     джим лемли, джейсон нетер, марк е.платт, яйн смит               18
# 3     джим лемли, джейсон нетер, марк е.платт, яйн смит               18
# 4     джим лемли, джейсон нетер, марк е.платт, яйн смит               18
# 417           тимур бекмамбетов, тим бертон, джим лемли               16
# 1985                             т.бекмамбетов, с.агеев                6
# 3609         т.бекмамбетов, и.стромилова, м.затуловская                6
# 3712  марк барнетт, шон дэниэл, джони левин, дункан ...               16
# 3713  марк барнетт, шон дэниэл, джони левин, дункан ...               16
# 4528                               с.муазен, а.ремизова               12
# 4957                 а.максимов, к.эрнст, т.бекмамбетов               12
# 6081           т.бекмамбетов, а.горохов, ж.бекмамбетова               12
# 6302                                      т.бекмамбетов                6
# 6508                       т.бекмамбетов, г.стрижевская                6
#
#       refundable_support  nonrefundable_support     budget financing_source  \
# 2                      0                      0          0          unknown
# 3                      0                      0          0          unknown
# 4                      0                      0          0          unknown
# 417                    0                      0          0          unknown
# 1985                   0                      0          0          unknown
# 3609                   0              150000000  215162287        фонд кино
# 3712                   0                      0          0          unknown
# 3713                   0                      0          0          unknown
# 4528                   0                      0          0          unknown
# 4957                   0                      0          0          unknown
# 6081                   0                      0          0          unknown
# 6302                   0                      0          0          unknown
# 6508            75000000               25000000  179708770        фонд кино
#
#       ratings                      genres  box_office_rub    I_director_name
# 2         6.0   фантастика,боевик,триллер             NaN  тимур бекмамбетов
# 3         6.0   фантастика,боевик,триллер             NaN  тимур бекмамбетов
# 4         6.0   фантастика,боевик,триллер             NaN  тимур бекмамбетов
# 417       5.0        ужасы,фэнтези,боевик             NaN  тимур бекмамбетов
# 1985      5.0      семейный,комедия,драма    4.259705e+08      т.бекмамбетов
# 3609      4.0            семейный,комедия    3.084015e+08      т.бекмамбетов
# 3712      5.0    боевик,драма,приключения             NaN  тимур бекмамбетов
# 3713      5.0    боевик,драма,приключения    2.595068e+08  тимур бекмамбетов
# 4528      6.0                     комедия    1.250000e+02      т.бекмамбетов
# 4957      5.0           мелодрама,комедия    1.996000e+03      т.бекмамбетов
# 6081      7.0  мультфильм,короткометражка             NaN     ж.бекмамбетова
# 6302      6.0                       драма             NaN      т.бекмамбетов
# 6508      6.0                     комедия    7.015070e+08      т.бекмамбетов

# %%
# Заменим все дубликаты типа Имя  Фамилия на И.Фамилия
def name_to_n(names):
    n = names[:(names.find(' '))]
    if names == 'unknown':
        return names
    if len(n) > 0:
        if '.' not in n:
            return (n[0] + '.' + names[(names.find(' ')+1):])

# %%
# избавляемся от пробелов
def strip_space(name):
    return name.strip(' ')

# %%
movies_shows['I_director_name'].apply(strip_space)
# Out:
# 0           кевин костнер
# 1               е.матвеев
# 2       тимур бекмамбетов
# 3       тимур бекмамбетов
# 4       тимур бекмамбетов
#               ...
# 7479          фил грабски
# 7480           ник пауэлл
# 7481     чарльз е.бастьен
# 7482             а.беляев
# 7483             и.трусов
# Name: I_director_name, Length: 7484, dtype: object

# %%
movies_shows['I_director_name'] = movies_shows['director'].apply(name_to_n)

# %%
movies_shows['I_director_name']
# Out:
# 0           к.костнер
# 1                None
# 2       т.бекмамбетов
# 3       т.бекмамбетов
# 4       т.бекмамбетов
#             ...
# 7479        ф.грабски
# 7480         н.пауэлл
# 7481      ч.е.бастьен
# 7482             None
# 7483             None
# Name: I_director_name, Length: 7484, dtype: object

# %%
movies_shows.isna().mean()
# Out:
# title                    0.000000
# c_number                 0.000000
# show_start_date          0.000000
# type                     0.000000
# film_studio              0.000000
# production_country       0.000000
# director                 0.000000
# producer                 0.000000
# age_restriction          0.000000
# refundable_support       0.000000
# nonrefundable_support    0.000000
# budget                   0.000000
# financing_source         0.000000
# ratings                  0.000000
# genres                   0.000000
# box_office_rub           0.578167
# I_director_name          0.317611
# dtype: float64

# %%
# добавим столбец с бюджетом от государства
movies_shows['gov_sup_budget'] = movies_shows['nonrefundable_support'] + movies_shows['refundable_support']

# %%
# функция для добавления столбца 
# с долей гос поддержки от общего бюджета
def gov_sup_ratio(row):
    if row['budget'] != 0:
        return (row['gov_sup_budget'] / row['budget'])
    return 0

# %%
movies_shows['gov_sup_ratio'] = movies_shows.apply(gov_sup_ratio,axis=1)

# %%
movies_shows['gov_sup_ratio'] = round(movies_shows['gov_sup_ratio'] * 100,1)

# %%
# проверяем
movies_shows['gov_sup_ratio'].value_counts()
# Out:
# 0.0     7169
# 70.0      15
# 65.0      11
# 66.7       8
# 65.8       7
#         ...
# 44.3       1
# 50.8       1
# 32.5       1
# 11.7       1
# 53.0       1
# Name: gov_sup_ratio, Length: 197, dtype: int64

# %% [markdown]
# **Вывод**
#
# Все столбцы успешно созданы

# %%
#выполним очистку данных в созданных столбцах

# %%
def date_sep(row,column,new):
    try:
        row[new] = row[column].dt.year
    except Exception as ex:
        print(ex)
        return print('Ищи ошибки')

# %%
date_sep(movies_shows,'show_start_date','show_start_year')

# %%
movies_shows['I_genre_name'] = movies_shows['genres'].apply(grab_first_name_or_genre)

# %%
movies_shows.head(1)
# Out:
#               title   c_number     show_start_date            type  \
# 0  открытый простор  221048915 2015-11-27 12:00:00  художественный
#
#                                          film_studio production_country  \
# 0  тачстоун пикчерз, кобальт пикчерз, бикон пикче...                сша
#
#         director                                   producer  age_restriction  \
# 0  кевин костнер  дэвид валдес, кевин костнер, джейк эбертс               18
#
#    refundable_support  ...  budget  financing_source ratings  \
# 0                   0  ...       0           unknown     7.0
#
#                    genres box_office_rub  I_director_name gov_sup_budget  \
# 0  боевик,драма,мелодрама            NaN        к.костнер              0
#
#    gov_sup_ratio  show_start_year  I_genre_name
# 0            0.0             2015        боевик
#
# [1 rows x 21 columns]

# %%
movies_shows.loc[movies_shows['budget'] != 0]['budget'].value_counts()
# Out:
# 38000000     6
# 50000000     4
# 80000000     4
# 40000000     3
# 37142857     3
#             ..
# 109020947    1
# 90276774     1
# 78686500     1
# 14462464     1
# 150147502    1
# Name: budget, Length: 289, dtype: int64

# %%
movies_shows.columns
# Out:
# Index(['title', 'c_number', 'show_start_date', 'type', 'film_studio',
#        'production_country', 'director', 'producer', 'age_restriction',
#        'refundable_support', 'nonrefundable_support', 'budget',
#        'financing_source', 'ratings', 'genres', 'box_office_rub',
#        'I_director_name', 'gov_sup_budget', 'gov_sup_ratio', 'show_start_year',
#        'I_genre_name'],
#       dtype='object')

# %%
movies_shows['budget'].sort_values()
# Out:
# 7113   -2147483648
# 0                0
# 4908             0
# 4907             0
# 4906             0
#            ...
# 3350     684200536
# 7170     779941965
# 7472     944000000
# 7462     980000000
# 5436    1032905957
# Name: budget, Length: 7484, dtype: int32

# %%
# найдем это значение
movies_shows['budget'][7113]
# Out:
# -2147483648

# %% [markdown]
# **Вывод** Нашли аномалию, применим функция abs для каждого числового столбца навсякий случай

# %%
# создаем функцию abs
def to_abs(row):
    return abs(row)

# %%
#  навсякий случай сделаем abs каждого столбца с 
# int значениями или float
# для этого создадим с список
# добави в список list_to_int
# недостающие столбцы
list_to_int
# Out:
# ['puNumber', 'refundable_support', 'nonrefundable_support', 'budget']

# %%
movies_shows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7484 entries, 0 to 7483
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7484 non-null   object
#  1   c_number               7484 non-null   int32
#  2   show_start_date        7484 non-null   datetime64[ns]
#  3   type                   7484 non-null   object
#  4   film_studio            7484 non-null   object
#  5   production_country     7484 non-null   object
#  6   director               7484 non-null   object
#  7   producer               7484 non-null   object
#  8   age_restriction        7484 non-null   int64
#  9   refundable_support     7484 non-null   int32
#  10  nonrefundable_support  7484 non-null   int32
#  11  budget                 7484 non-null   int32
#  12  financing_source       7484 non-null   object
#  13  ratings                7484 non-null   float64
#  14  genres                 7484 non-null   object
#  15  box_office_rub         3157 non-null   float64
#  16  I_director_name        5107 non-null   object
#  17  gov_sup_budget         7484 non-null   int32
#  18  gov_sup_ratio          7484 non-null   float64
#  19  show_start_year        7484 non-null   int64
#  20  I_genre_name           7484 non-null   object
# dtypes: datetime64[ns](1), float64(3), int32(5), int64(2), object(10)
# memory usage: 1.4+ MB

# %%
# добавляем в list_to_int столбцы
# 'box_office_rub','ratings'
list_to_int.extend(['box_office_rub','ratings'])

# %%
# заменяем первый элемент "puNumber" на 'c_number'
list_to_int[0] = 'c_number'

# %%
# проверка
print(*list_to_int)
# Out:
# c_number refundable_support nonrefundable_support budget box_office_rub ratings

# %%
# применяем функцию
for i in list_to_int:
    movies_shows[i] = movies_shows[i].apply(to_abs)

# %%
# проверка
movies_shows['budget'][7113]
# Out:
# 2147483648

# %%
movies_shows.columns
# Out:
# Index(['title', 'c_number', 'show_start_date', 'type', 'film_studio',
#        'production_country', 'director', 'producer', 'age_restriction',
#        'refundable_support', 'nonrefundable_support', 'budget',
#        'financing_source', 'ratings', 'genres', 'box_office_rub',
#        'I_director_name', 'gov_sup_budget', 'gov_sup_ratio', 'show_start_year',
#        'I_genre_name'],
#       dtype='object')

# %% [markdown]
# ## ИАД и графики

# %% [markdown]
# Посмотрите, сколько фильмов выходило в прокат каждый год. Обратите внимание, что данные о прокате в кинотеатрах известны не для всех фильмов. Посчитайте, какую долю составляют фильмы с указанной информацией о прокате в кинотеатрах. Проанализируйте, как эта доля менялась по годам. Сделайте вывод о том, какой период полнее всего представлен в данных.

# %% [markdown]
# Из анализа сайта, выделим закономерности. Номер сертификата больше или равно 22_____ говорит нам о том, что фильм не выходил в прокат кинотеатров, а транслировался по ТВ или в онлайн домашнем кинотеатре и тд. Таким образом, нужно избавиться через метод `query` все, что больше 22_____

# %% [markdown]
# ### Кол-во фильмов в прокате каждый год

# %%
# находим длинну сертификата
len(str(movies_shows['c_number'][1]))
# Out:
# 9

# %%
movies_shows.head(1)
# Out:
#               title   c_number     show_start_date            type  \
# 0  открытый простор  221048915 2015-11-27 12:00:00  художественный
#
#                                          film_studio production_country  \
# 0  тачстоун пикчерз, кобальт пикчерз, бикон пикче...                сша
#
#         director                                   producer  age_restriction  \
# 0  кевин костнер  дэвид валдес, кевин костнер, джейк эбертс               18
#
#    refundable_support  ...  budget  financing_source ratings  \
# 0                   0  ...       0           unknown     7.0
#
#                    genres box_office_rub  I_director_name gov_sup_budget  \
# 0  боевик,драма,мелодрама            NaN        к.костнер              0
#
#    gov_sup_ratio  show_start_year  I_genre_name
# 0            0.0             2015        боевик
#
# [1 rows x 21 columns]

# %%
# создаем отредактированную таблицу
# где будет находиться информация только
# о кинопрокате
cinema_film = movies_shows.query('c_number < 220_000_000')

# %%
# cinema_film_percent - процент данных, относящихся к кинопрокату 
# other_percent - процент данных, которые не относятся к кинопрокату 
cinema_film_percent = (round(cinema_film.shape[0] / movies_shows.shape[0]*100,1))
other_percent = round(100-cinema_film_percent,1)

# %%
print(f'Процент данных, относящихся к кинопрокату равен: {cinema_film_percent}%')
print(f'Процент данных, которые не относятся к кинопрокату равен: {other_percent}%')
# Out:
# Процент данных, относящихся к кинопрокату равен: 84.9%
# Процент данных, которые не относятся к кинопрокату равен: 15.1%

# %%
cinema_film.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6353 entries, 1 to 7483
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  6353 non-null   object
#  1   c_number               6353 non-null   int64
#  2   show_start_date        6353 non-null   datetime64[ns]
#  3   type                   6353 non-null   object
#  4   film_studio            6353 non-null   object
#  5   production_country     6353 non-null   object
#  6   director               6353 non-null   object
#  7   producer               6353 non-null   object
#  8   age_restriction        6353 non-null   int64
#  9   refundable_support     6353 non-null   int64
#  10  nonrefundable_support  6353 non-null   int64
#  11  budget                 6353 non-null   int64
#  12  financing_source       6353 non-null   object
#  13  ratings                6353 non-null   float64
#  14  genres                 6353 non-null   object
#  15  box_office_rub         3125 non-null   float64
#  16  I_director_name        3994 non-null   object
#  17  gov_sup_budget         6353 non-null   int32
#  18  gov_sup_ratio          6353 non-null   float64
#  19  show_start_year        6353 non-null   int64
#  20  I_genre_name           6353 non-null   object
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(6), object(10)
# memory usage: 1.0+ MB

# %%
# группируем по столбцу show_start_year и считаем количество лицензий, обнуляем индекс
cinema_film_group_year = cinema_film.groupby('show_start_year')['c_number'].count().reset_index()

# %%
cinema_film_group_year
# Out:
#    show_start_year  c_number
# 0             2010       492
# 1             2011       438
# 2             2012       510
# 3             2013       589
# 4             2014       694
# 5             2015       607
# 6             2016       709
# 7             2017       496
# 8             2018       889
# 9             2019       929

# %%
cinema_film_group_year
# Out:
#    show_start_year  c_number
# 0             2010       492
# 1             2011       438
# 2             2012       510
# 3             2013       589
# 4             2014       694
# 5             2015       607
# 6             2016       709
# 7             2017       496
# 8             2018       889
# 9             2019       929

# %%
# функция для построения distplot
def distplot_graph(data,
                   bins,
                   xlabel,
                   ylabel,
                   title,
                   span_xmin,
                   span_xmax,
                   color_graph='skyblue',
                   color_span='r',
                   alpha=0.3,
                   kde=True):
    sns.displot(data,bins=bins,kde=kde,color=color_graph)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.axvspan(xmin=span_xmin,xmax=span_xmax,alpha=alpha,color=color_span)
    plt.show()

# %%
# строим distplot
distplot_graph(data=cinema_film['show_start_year'],
                   bins=10,
                   xlabel='Год',
                   ylabel='Частота',
                   title='Количество фильмов в кинопрокате за год',
                   span_xmin=2016.3,
                   span_xmax=2017.2,)

# %%
# сортируем по количеству удостоверений
ordered_cinema_film_group_year = cinema_film_group_year.sort_values(by='c_number')

# %%
ordered_cinema_film_group_year
# Out:
#    show_start_year  c_number
# 1             2011       438
# 0             2010       492
# 7             2017       496
# 2             2012       510
# 3             2013       589
# 5             2015       607
# 4             2014       694
# 6             2016       709
# 8             2018       889
# 9             2019       929

# %%
# функция, которая строит диаграмму рассеяния 
def scatter_plot(data,
                 x,
                 y,
                 alpha,
                 grid=True):
    data.plot(x=x,
              y=y,
              kind='scatter',
              alpha=alpha,
              grid=grid)
    plt.show()

# %%
# строим для анализа диаграмму рассеяния
scatter_plot(data=ordered_cinema_film_group_year,
             x='show_start_year',
             y='c_number',
             alpha=0.8)

# %%
my_range =range(0,len(ordered_cinema_film_group_year.index))

# %%
# функция для построение stem графика
def stem_grap(data,
              column,
              xticks,
              ylabel,
              xlabel,
              title):
    plt.stem(column)
    my_range = range(0,len(data.index))
    plt.xticks(my_range,xticks)
    plt.ylabel('Частота')
    plt.title('Количество фильмов в кинопрокате за год')
    plt.xlabel('Год')
    plt.show()

# %%
# строим спичечный график
stem_grap(data=ordered_cinema_film_group_year,
          column=cinema_film_group_year['c_number'],
          xticks=cinema_film_group_year['show_start_year'],
          ylabel='Частота',
          xlabel='Год',
          title='Количество фильмов в кинопрокате за год')

# %%
# создаем функцию для построения squarify
def squarify_graph(sizes,label,alpha,title,axis):
    (squarify.plot(sizes=sizes,
              label=label,
              alpha=alpha))
    plt.title(title)
    plt.axis(axis)
    plt.show()

# %%
# строим squarify
squarify_graph(sizes=cinema_film_group_year['c_number'],
              label=cinema_film_group_year['show_start_year'],
              alpha=0.8,
              title=('Количество фильмов в кинопрокате за год'),
              axis=('off'))

# %%
ordered_cinema_film_group_year
# Out:
#    show_start_year  c_number
# 1             2011       438
# 0             2010       492
# 7             2017       496
# 2             2012       510
# 3             2013       589
# 5             2015       607
# 4             2014       694
# 6             2016       709
# 8             2018       889
# 9             2019       929

# %% [markdown]
# **Выводы:**
#
# Из графиков и таблицы можем выделить год лидер по количеству фильмов и год, имеющий наименьшее количество фильмов в прокате.
#
# * **Год с наибольшим количеством фильмов в прокате - 2019 (930 шт.)**
# * **Год с наименьшем количеством фильмов в прокате - 2011 (438 шт.)**
#
# Также присутствует заметный спад количества прокатных удостоверений в 2017 году на гистрограмме.

# %% [markdown]
# ### Доли фильмов по годам

# %% [markdown]
# #### Доля прокатных фильмов -  все удостоврение с первым числом меньше 22

# %%
# создаем столбец, в котором указан
# процент от общей базы
ordered_cinema_film_group_year['to_all_percent'] = (
                                                   round( ordered_cinema_film_group_year['c_number'] / 
                                                    cinema_film.shape[0] * 100,1)
                                                   )

# %%
ordered_cinema_film_group_year
# Out:
#    show_start_year  c_number  to_all_percent
# 1             2011       438             6.9
# 0             2010       492             7.7
# 7             2017       496             7.8
# 2             2012       510             8.0
# 3             2013       589             9.3
# 5             2015       607             9.6
# 4             2014       694            10.9
# 6             2016       709            11.2
# 8             2018       889            14.0
# 9             2019       929            14.6

# %%
# создаем функцию для создания 
# графика "пирог"
def pie_graph(x,
              autopct,
              explode,
              labels,
              shadow=True,
              startangle=-150):
    fig1, ax1 = plt.subplots()
    ax1.pie(x=x,
            autopct=autopct,
            explode=explode,
            labels=labels,
            shadow=shadow,
            startangle=startangle)
    plt.show()

# %%
# задаем нужные параметры для функции
labels=ordered_cinema_film_group_year['show_start_year']
explode = [0 for i in range(9)]
explode[0] = 0.2
explode.append(0.2)

# %%
explode
# Out:
# [0.2, 0, 0, 0, 0, 0, 0, 0, 0, 0.2]

# %%
# строим график пирог
pie_graph(x=ordered_cinema_film_group_year['to_all_percent'],
          autopct='%1.1f%%',
          explode=explode,
          labels=labels)

# %%
# создаем таблицу сумма сборов по годам 
# из таблицы cinema_film
cinema_film_year_box_office = (cinema_film.loc[cinema_film['box_office_rub'].isna()==False]
.groupby('show_start_year')['box_office_rub']
.sum()
.reset_index())

# %%
# для удобства создаем новый столбец
# с миллионными
cinema_film_year_box_office['box_office_rub_millions'] = round(cinema_film_year_box_office['box_office_rub']/1_000_000,2)

# %%
# сортируем по столбцу "box_office_rub_millions"
cinema_film_year_box_office.sort_values(by='box_office_rub_millions')
# Out:
#    show_start_year  box_office_rub  box_office_rub_millions
# 0             2010    2.375449e+06                     2.38
# 2             2012    6.947423e+06                     6.95
# 1             2011    1.409301e+07                    14.09
# 3             2013    2.979937e+07                    29.80
# 4             2014    7.444943e+09                  7444.94
# 5             2015    3.949736e+10                 39497.36
# 6             2016    4.786610e+10                 47866.10
# 9             2019    4.842337e+10                 48423.37
# 7             2017    4.856371e+10                 48563.71
# 8             2018    4.966840e+10                 49668.40

# %%
ordered_cinema_film_group_year
# Out:
#    show_start_year  c_number  to_all_percent
# 1             2011       438             6.9
# 0             2010       492             7.7
# 7             2017       496             7.8
# 2             2012       510             8.0
# 3             2013       589             9.3
# 5             2015       607             9.6
# 4             2014       694            10.9
# 6             2016       709            11.2
# 8             2018       889            14.0
# 9             2019       929            14.6

# %%
# функция для построения столбчатой диаграммы
def bar_bo_by_year(x,
                   height,
                   xlabel,
                   ylabel,
                   title,
                   edgecolor='black',
                   log=True,
                   color='skyblue',
                   ylim=False,
                  rotation=0):
    plt.bar(x=x,
            height=height,
            log=log,
            edgecolor=edgecolor,
            color=color)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.xticks(rotation=rotation)
    plt.ylim(ylim)
    plt.show()

# %%
# строим столбчатую диаграмму
bar_bo_by_year(x=cinema_film_year_box_office['show_start_year'],
            height= cinema_film_year_box_office['box_office_rub_millions'],
            xlabel="Года",
            ylabel='Сборы в миллионах руб.',
            title='Сборы от кинопроката по годам')
# Out:
# C:\Users\Egor\AppData\Local\Temp/ipykernel_19560/1354184497.py:21: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.ylim(ylim)

# %%
# задаем нужные параметры для функции
labels_cinema_film_year_box_office=cinema_film_year_box_office['show_start_year']
explode_cinema_film_year_box_office = [0 for i in range(9)]
explode_cinema_film_year_box_office[0] = 0.2
explode_cinema_film_year_box_office.append(0.2)

# %%
# строим график пирог
pie_graph(x=cinema_film_year_box_office['box_office_rub_millions'],
          autopct='%1.1f%%',
          explode=explode_cinema_film_year_box_office,
          labels=labels_cinema_film_year_box_office)

# %% [markdown]
# **Выводы в цифрах:**
#
# Из графика `Сборы от кинопроката по годам`, из графика "пирога" и таблицы `cinema_film_year_box_office` можно выделить минимальный и максимальный год относительно сборов:
#
# * Минимальный год по сборам - **2010 - 2.38 миллиона рублей**
# * Максимальный год по сборам - **2018 - 49_668.40 миллионов рублей**

# %% [markdown]
# #### Полнота данных проката по годам

# %%
cinema_film_ratio_box = cinema_film.groupby('show_start_year')['box_office_rub'].agg({'count','size'})

# %%
cinema_film_ratio_box['percent_fullness'] = round(cinema_film_ratio_box['count'] / cinema_film_ratio_box['size'] * 100, 1)

# %%
cinema_film_ratio_box.reset_index(inplace=True)

# %%
cinema_film_ratio_box.sort_values(by='percent_fullness')
# Out:
#    show_start_year  size  count  percent_fullness
# 0             2010   492     97              19.7
# 1             2011   438    106              24.2
# 2             2012   510    126              24.7
# 3             2013   589    183              31.1
# 4             2014   694    272              39.2
# 8             2018   889    475              53.4
# 9             2019   929    529              56.9
# 7             2017   496    357              72.0
# 6             2016   709    518              73.1
# 5             2015   607    462              76.1

# %%
bar_bo_by_year(x=cinema_film_ratio_box['show_start_year'],
            height= cinema_film_ratio_box['percent_fullness'],
            xlabel="Года",
            ylabel='Процент',
            title='Доля данных о прокате по годам',
            log=False)

# %% [markdown]
# **Выводы:**
#
# Наименьшая доля данных о прокате была в 2010 году - 19.7%.
#
# А полнее всех представлен 2015 год - 76.1% от всех записей имеют данные о прокате.

# %% [markdown]
# ### Средняя и медианная сумма сбора по годам

# %%
# создаем сводную таблицу для 
# средней и медианной сумме по годам
cinema_film_pivot_year = (
    cinema_film.pivot_table(index='show_start_year',
                                        values='box_office_rub',
                                        aggfunc={'median','mean'})
                )

# %%
cinema_film_pivot_year
# Out:
#                          mean      median
# show_start_year
# 2010             2.448916e+04     1700.00
# 2011             1.329529e+05     3042.50
# 2012             5.513828e+04     5660.00
# 2013             1.628381e+05     3545.00
# 2014             2.737112e+07    21445.00
# 2015             8.549212e+07  5003450.15
# 2016             9.240560e+07  4091820.05
# 2017             1.360328e+08  9968340.00
# 2018             1.045651e+08  8891102.21
# 2019             9.153756e+07  4654563.09

# %%
cinema_film_pivot_year['mean'] = cinema_film_pivot_year['mean'].astype('int',errors='raise')
cinema_film_pivot_year['median'] = cinema_film_pivot_year['median'].astype('int',errors='raise')

# %%
# переименнуем столбцы. bor ≡ box_office_rub
cinema_film_pivot_year.columns = ['mean_bor','median_bor']

# %%
cinema_film_pivot_year['mean_bor'] = cinema_film_pivot_year['mean_bor'].astype('int')

# %%
cinema_film_pivot_year.reset_index(inplace=True)

# %%
cinema_film_pivot_year.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   show_start_year  10 non-null     int64
#  1   mean_bor         10 non-null     int32
#  2   median_bor       10 non-null     int32
# dtypes: int32(2), int64(1)
# memory usage: 288.0 bytes

# %%
cinema_film_pivot_year
# Out:
#    show_start_year   mean_bor  median_bor
# 0             2010      24489        1700
# 1             2011     132952        3042
# 2             2012      55138        5660
# 3             2013     162838        3545
# 4             2014   27371115       21445
# 5             2015   85492120     5003450
# 6             2016   92405603     4091820
# 7             2017  136032793     9968340
# 8             2018  104565059     8891102
# 9             2019   91537561     4654563

# %%
# сортируем
cinema_film_pivot_year.sort_values(by='mean_bor',ascending=True)
# Out:
#    show_start_year   mean_bor  median_bor
# 0             2010      24489        1700
# 2             2012      55138        5660
# 1             2011     132952        3042
# 3             2013     162838        3545
# 4             2014   27371115       21445
# 5             2015   85492120     5003450
# 9             2019   91537561     4654563
# 6             2016   92405603     4091820
# 8             2018  104565059     8891102
# 7             2017  136032793     9968340

# %%
cinema_film_pivot_year.sort_values(by='median_bor')
# Out:
#    show_start_year   mean_bor  median_bor
# 0             2010      24489        1700
# 1             2011     132952        3042
# 3             2013     162838        3545
# 2             2012      55138        5660
# 4             2014   27371115       21445
# 6             2016   92405603     4091820
# 9             2019   91537561     4654563
# 5             2015   85492120     5003450
# 8             2018  104565059     8891102
# 7             2017  136032793     9968340

# %%
# строим столбчатую диаграмму
print("Без логарифмирования")
bar_bo_by_year(x=cinema_film_pivot_year['show_start_year'],
            height= cinema_film_pivot_year['mean_bor'],
            xlabel="Года",
            ylabel='Средний сбор рублях',
            title='Средний сбор рублях по годам')
bar_bo_by_year(x=cinema_film_pivot_year['show_start_year'],
            height= cinema_film_pivot_year['median_bor'],
            xlabel="Года",
            ylabel='Медианный сбор в рублях',
            title='Медианный сбор в рублях по годам',
            color='dodgerblue')
print('-'*100)
print('Логарифмируя получаем:')
# строим столбчатую диаграмму

bar_bo_by_year(x=cinema_film_pivot_year['show_start_year'],
            height= cinema_film_pivot_year['mean_bor'],
            xlabel="Года",
            ylabel='Средний сбор в рублях',
            title='Средний сбор в рублях по годам',log=False)
bar_bo_by_year(x=cinema_film_pivot_year['show_start_year'],
            height= cinema_film_pivot_year['median_bor'],
            xlabel="Года",
            ylabel='Медианный сбор в рублях',
            title='Медианный сбор в рублях по годам',
            color='dodgerblue',log=False)
# Out:
# Без логарифмирования
# C:\Users\Egor\AppData\Local\Temp/ipykernel_19560/1354184497.py:21: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.ylim(ylim)
# ----------------------------------------------------------------------------------------------------
# Логарифмируя получаем:

# %% [markdown]
# **Выводы в цифрах:**
#
# Поскольку природа нахождения средних и медианных значений отличается - медианные значения менее чувствительны к выбросам, а на средние онные весьма серьезно влияют как в меньшую, так и в большую сторону в зависимости от концентрации и знаений выбросов от среднего значения. Поэтиому имеем такую картину - средние значения довольно сильно отличаются в нашем случае
#
# **Средняя** сумма сбора по годам (по возрастанию):
#
# 1. **2010 - 24_489.2 рублей**
# 2. **2012 - 55_138.3 рублей**
# 3. **2011 - 132_952.0 рублей**
# 4. **2013 - 162_838.1 рублей**
# 5. **2014 - 227_371_115.3 рублей**
# 6. **2015 - 85_492_120.3 рублей**
# 7. **2019 - 91_369_261.8 рублей**
# 8. **2016 - 92_405_603.9 рублей**
# 9. **2018 - 104_565_059.2 рублей**
# 10. **2017 - 136_032_793.3 рублей**
#
# **Медианная** сумма сбора по годам (по возрастанию):
#
# 1. **2010 - 1_700 рублей**
# 2. **2011 - 3_043 рублей**
# 3. **2013 - 3_545 рублей**
# 4. **2012 - 5_660 рублей**
# 5. **2014 - 21_445 рублей**
# 6. **2016 - 4_091_820 рублей**
# 7. **2019 - 4_627_798 рублей**
# 8. **2015 - 5_003_450 рублей**
# 9. **2018 - 8_891_102 рублей**
# 10. **2017 - 9_968_340 рублей**

# %% [markdown]
# ### Сумма сбора ~ возрастное ограничение + год

# %%
# отбираем условием записи, в которых
# в столбце год значение больше 2014
cinema_film_from_2015 = cinema_film.query('show_start_year > 2014')

# %%
# найдем процент 
print(f'{round(cinema_film.query("show_start_year > 2014").shape[0]/cinema_film.shape[0]*100,1)}%')
# Out:
# 57.1%

# %%
# выводим имена столбцов
cinema_film_from_2015.columns
# Out:
# Index(['title', 'c_number', 'show_start_date', 'type', 'film_studio',
#        'production_country', 'director', 'producer', 'age_restriction',
#        'refundable_support', 'nonrefundable_support', 'budget',
#        'financing_source', 'ratings', 'genres', 'box_office_rub',
#        'I_director_name', 'gov_sup_budget', 'gov_sup_ratio', 'show_start_year',
#        'I_genre_name'],
#       dtype='object')

# %%
#  создаем таблицу от 2015 года включительньо
cinema_film_from_2015_pivot = (
                               cinema_film_from_2015
                              .pivot_table(index=['show_start_year','age_restriction'],
                                        values='box_office_rub',
                                        aggfunc='sum')
                              )

# %%
cinema_film_from_2015_pivot.reset_index(inplace=True)

# %%
# создаем финальную верстию сводной таблицы
cinema_film_from_2015_pivot_final = (
                                    cinema_film_from_2015_pivot
                                     .pivot_table(index='show_start_year',
                                            columns='age_restriction')
)

# %%
cinema_film_from_2015_pivot_final
# Out:
#                 box_office_rub                                            \
# age_restriction             0             6             12            16
# show_start_year
# 2015              3.790532e+08  8.701799e+09  1.361608e+10  1.136812e+10
# 2016              1.502286e+08  1.205314e+10  1.220442e+10  1.666438e+10
# 2017              2.295989e+08  1.208614e+10  7.851428e+09  1.874504e+10
# 2018              3.244900e+07  1.010497e+10  1.426729e+10  1.650360e+10
# 2019              1.774607e+07  1.285255e+10  1.268020e+10  1.275342e+10
#
#
# age_restriction            18
# show_start_year
# 2015             5.432306e+09
# 2016             6.793929e+09
# 2017             9.651496e+09
# 2018             8.760086e+09
# 2019             1.011946e+10

# %%
cinema_film_from_2015_pivot_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 2015 to 2019
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   (box_office_rub, 0)   5 non-null      float64
#  1   (box_office_rub, 6)   5 non-null      float64
#  2   (box_office_rub, 12)  5 non-null      float64
#  3   (box_office_rub, 16)  5 non-null      float64
#  4   (box_office_rub, 18)  5 non-null      float64
# dtypes: float64(5)
# memory usage: 240.0 bytes

# %%
# выводим финальную версию 
cinema_film_from_2015_pivot_final
# Out:
#                 box_office_rub                                            \
# age_restriction             0             6             12            16
# show_start_year
# 2015              3.790532e+08  8.701799e+09  1.361608e+10  1.136812e+10
# 2016              1.502286e+08  1.205314e+10  1.220442e+10  1.666438e+10
# 2017              2.295989e+08  1.208614e+10  7.851428e+09  1.874504e+10
# 2018              3.244900e+07  1.010497e+10  1.426729e+10  1.650360e+10
# 2019              1.774607e+07  1.285255e+10  1.268020e+10  1.275342e+10
#
#
# age_restriction            18
# show_start_year
# 2015             5.432306e+09
# 2016             6.793929e+09
# 2017             9.651496e+09
# 2018             8.760086e+09
# 2019             1.011946e+10

# %%
# функция для построение столбчатой диаграммы
def barplot_2_group(data,y,markerfirst=True,frameon=False,rotation=0,grid=True,log=True,ylim=False):
    data.plot(kind='bar',
      y=y,
     grid=grid,
     log=log)
    plt.legend(markerfirst=markerfirst,frameon=frameon) 
    plt.xticks(rotation=rotation)
    plt.ylim(ylim)
    plt.show()

# %%
print('-'*120)
print('Логарифмированный график')
(cinema_film_from_2015_pivot_final.plot(kind='bar',
      y='box_office_rub',
     grid=True,
     log=True)
)
plt.legend(markerfirst=True,frameon=False) 

plt.xticks(rotation=0)
plt.show()
print('-'*120)
print('График для анализа 6,12 и 18 категорий')
barplot_2_group(data=cinema_film_from_2015_pivot_final,y='box_office_rub',ylim=(0,50_000),log=False)
print('-'*120)
print('График для анализа категории 16')
barplot_2_group(data=cinema_film_from_2015_pivot_final,y='box_office_rub',ylim=(0,1_00000_000_000)
                ,log=False)
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# Логарифмированный график
# ------------------------------------------------------------------------------------------------------------------------
# График для анализа 6,12 и 18 категорий
# ------------------------------------------------------------------------------------------------------------------------
# График для анализа категории 16

# %% [markdown]
# **Выводы в цифрах:**
#
# Из таблицы и графиков можем выявить годы с максимальной суммой сборов по каждой из категорий:
#
# Категории:
# * `0`
#  - **Год с минимальной суммой сбора 2019 17.7 миллионов рублей**
#  - **Год с максимальной суммой сбора 2015 379 миллионов рублей**
# * `6`
#  - **Год с минимальной суммой сбора 2015 8_701 миллионов рублей**
#  - **Год с максимальной суммой сбора 2019 12_852.5 миллионов рублей**
# * `12`
#  - **Год с минимальной суммой сбора 2017 7_851.4  миллионов рублей**
#  - **Год с максимальной суммой сбора 2018 14_267.3 миллионов рублей**
# * `16`
#  - **Год с минимальной суммой сбора 2015 1_136_812  миллионов рублей**
#  - **Год с максимальной суммой сбора 2017 1_874_504 миллионов рублей**
# * `18`
#  - **Год с минимальной суммой сбора 2015 5_432.3 миллионов рублей**
#  - **Год с максимальной суммой сбора 2019 10_121.8 миллионов рублей**
#
#
# Также заметим, что:
# * Сумма сборов категории `18` растет с каждым годом.
# * Сумма сборов категории `16` росла до 2017 года, а после начала падать.
# * Сумма сборов категории `12` и росла и падала на протяжении 5 лет, однако в 2017 году было одно из самых больших падений в сумме сбора
# * Сумма сборов категории `6` с 2015 года сильно выросла, однако не смогла укрепить свои позиции и в дальнейшем имела большую волотильность
# * Сумма сборов категории `0` падает из года в год за исключением 2017 года.

# %% [markdown]
# ### Процент государственной поддержки по годам

# %%
cinema_film_gov_sup_ratio_per_year = (
                                    cinema_film.query('gov_sup_ratio != 0')
                                    .groupby('show_start_year')['gov_sup_ratio']
                                    .median()
                                     )

# %%
cinema_film_gov_sup_ratio_per_year = (
                                        cinema_film_gov_sup_ratio_per_year
                                        .reset_index()
                                    )

# %%
cinema_film_gov_sup_ratio_per_year.sort_values(by='show_start_year')
# Out:
#    show_start_year  gov_sup_ratio
# 0             2013          47.35
# 1             2014          53.90
# 2             2015          61.10
# 3             2016          63.70
# 4             2017          47.70
# 5             2018          55.55
# 6             2019          58.30

# %%
bar_bo_by_year(x=cinema_film_gov_sup_ratio_per_year['show_start_year'],
            height= cinema_film_gov_sup_ratio_per_year['gov_sup_ratio'],
            xlabel="Год",
            ylabel='Процент гос. поддержки от общего бюджета',
            title='Процент гос. поддержки от общего бюджета по годам',
            rotation=0)
# Out:
# C:\Users\Egor\AppData\Local\Temp/ipykernel_19560/1354184497.py:21: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.ylim(ylim)

# %% [markdown]
# **Вывод**
#
# Из графика и таблицы можем легко описать основные тенденции в финансировании фильмов государством:
#
# 1. С 2013 года по 2016 год поддержка фильмов **_выросла_** с **47.35%** процентов до **63.70%**
# 2. В 2017 году было значительное **__падение__** до уровня 2013 года - **47.70%**
# 3. Дальше последовал резкий рост в 2018 до **55.55%**. В 2019 году не менее значительный рост c **55.55%** - **58.30%**

# %% [markdown]
# ### Процент возвращаемой и невозвращаемой государственной поддержки по годам

# %%
def refundable_ratio(row):
    if row['gov_sup_budget'] != 0:
        return round(row['refundable_support'] / row['gov_sup_budget'] * 100,1)

# %%
cinema_film['refundable_gov_sup_ratio']  = cinema_film.apply(refundable_ratio,axis=1)
# Out:
# C:\Users\Egor\AppData\Local\Temp/ipykernel_19560/4096762183.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cinema_film['refundable_gov_sup_ratio']  = cinema_film.apply(refundable_ratio,axis=1)

# %%
pd.set_option('mode.chained_assignment', None)

# %%
cinema_film['refundable_support'].value_counts().head(5)
# Out:
# 0           6242
# 20000000      12
# 10000000      10
# 25000000      10
# 5000000        9
# Name: refundable_support, dtype: int64

# %%
refundable_ratio_per_year = cinema_film.groupby('show_start_year')['refundable_gov_sup_ratio'].agg({'mean','count'})

# %%
refundable_ratio_per_year.dropna(inplace=True)

# %%
refundable_ratio_per_year
# Out:
#                  count       mean
# show_start_year
# 2013                 2   0.000000
# 2014                16  10.268750
# 2015                86  14.688372
# 2016                61  14.613115
# 2017                41  19.870732
# 2018                56  13.267857
# 2019                70  11.308571

# %%
refundable_ratio_per_year.reset_index(inplace=True)

# %%
refundable_ratio_per_year.sort_values(by='mean')
# Out:
#    show_start_year  count       mean
# 0             2013      2   0.000000
# 1             2014     16  10.268750
# 6             2019     70  11.308571
# 5             2018     56  13.267857
# 3             2016     61  14.613115
# 2             2015     86  14.688372
# 4             2017     41  19.870732

# %%
bar_bo_by_year(x=refundable_ratio_per_year['show_start_year'],
            height=refundable_ratio_per_year['mean'],
            xlabel="Год",
            ylabel='Процент',
            title='Процент возвращаемой гос. поддержки',
            rotation=0)
# Out:
# C:\Users\Egor\AppData\Local\Temp/ipykernel_19560/1354184497.py:21: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.ylim(ylim)

# %% [markdown]
# **Вывод**
#
# Поскольку выборка в 2013 году очень мала - 2 записи - мы не будем брать этот год в анализ.
#
# Итого:
#
# **Самый большой** процент возвратных средств приходится на **2017 году - 19.9%**
#
# **Самый низкий** процент возворатных средств был в **2014 году - 10.3%**

# %%
def nonrefundable_ratio(row):
    if row['gov_sup_budget'] != 0:
        return round(row['nonrefundable_support'] / row['gov_sup_budget'] * 100,1)

# %%
cinema_film['nonrefundable_gov_sup_ratio'] = cinema_film.apply(nonrefundable_ratio,axis=1)

# %%
cinema_film['nonrefundable_gov_sup_ratio'].value_counts().head(5)
# Out:
# 100.0    221
# 50.0      13
# 66.7      11
# 0.0        9
# 80.0       7
# Name: nonrefundable_gov_sup_ratio, dtype: int64

# %%
nonrefundable_ratio_per_year = cinema_film.groupby('show_start_year')['nonrefundable_gov_sup_ratio'].agg({'mean','count'})

# %%
nonrefundable_ratio_per_year.dropna(inplace=True)

# %%
nonrefundable_ratio_per_year.reset_index(inplace=True)

# %%
nonrefundable_ratio_per_year.sort_values(by='mean')
# Out:
#    show_start_year  count        mean
# 4             2017     41   80.129268
# 2             2015     86   85.311628
# 3             2016     61   85.386885
# 5             2018     56   86.732143
# 6             2019     70   88.691429
# 1             2014     16   89.731250
# 0             2013      2  100.000000

# %%
bar_bo_by_year(x=nonrefundable_ratio_per_year['show_start_year'],
            height= nonrefundable_ratio_per_year['mean'],
            xlabel="Год",
            ylabel='Процент',
            title='Процент невозвращаемой гос. поддержки',
            rotation=0)
# Out:
# C:\Users\Egor\AppData\Local\Temp/ipykernel_19560/1354184497.py:21: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.ylim(ylim)

# %% [markdown]
# **Вывод**
# Максимальный процент невозратного финансирования приходится на 2013 год. Однако, поскольку для этого года имеется всего лишь 2 записи, то это мало чего говорит о генеральной совокупности по этому году.
#
# По остальным годам данных достаточно (n > 30), чтобы хоть что-то можно было сказать о генеральной совокупности и вообще о нашей выборке:
#
# * **Минимальный** процент невозратных средств была в **2017 году - 80.1%.**
#
# * **Максимальный**, не считая 2013 - 100%, процент невозратных средст приходится на **2014 год - 89.7%**

# %% [markdown]
# ### Анализ жанров фильмов с гос. поддержкой с гос. поддержкой

# %%
# функция для содания таблицы для анализа 

def more_an(groupby,data=cinema_film,values=['box_office_rub','ratings'],agg={'box_office_rub':['sum','count'],'ratings':['median']}):
    return (
    data.query(f'{groupby} != "unknown" and gov_sup_budget != 0')
    .groupby(groupby)[values]
    .agg(agg))

# %%
# Группировка по 1-ому жанру фильма, сумма и количество записей 
cinema_film_grouby_1_genre = more_an(groupby='I_genre_name')

# %%
cinema_film_grouby_1_genre.reset_index(inplace=True)

# %%
cinema_film_grouby_1_genre.columns
# Out:
# MultiIndex([(  'I_genre_name',       ''),
#             ('box_office_rub',    'sum'),
#             ('box_office_rub',  'count'),
#             (       'ratings', 'median')],
#            )

# %%
cinema_film_grouby_1_genre = cinema_film_grouby_1_genre.droplevel(level=1,axis=1)

# %%
cinema_film_grouby_1_genre.columns = ['I_genre_name','bor_sum', 'bor_count','rating_median']

# %%
cinema_film_grouby_1_genre
# Out:
#    I_genre_name       bor_sum  bor_count  rating_median
# 0     биография  5.168830e+08          3            6.0
# 1        боевик  5.959289e+08          6            6.0
# 2       военный  1.017670e+09          9            6.0
# 3      детектив  1.385475e+08          5            6.0
# 4       детский  3.013652e+06          3            7.0
# 5         драма  9.490844e+09         87            6.0
# 6       история  1.455468e+09          4            5.5
# 7       комедия  1.247998e+10         73            5.0
# 8      криминал  2.397939e+08          3            7.0
# 9     мелодрама  5.478897e+07         14            6.0
# 10   мультфильм  5.622014e+09         30            6.0
# 11       мюзикл  1.017050e+08          4            6.5
# 12  приключения  1.205597e+09          6            5.0
# 13  реальное тв  3.272110e+07          1            5.0
# 14     семейный  5.844247e+08          6            4.0
# 15        спорт  2.967768e+09          3            7.0
# 16      триллер  7.004502e+08         15            5.0
# 17        ужасы  7.101232e+08         10            5.0
# 18   фантастика  1.718204e+09         10            6.0
# 19      фэнтези  9.958366e+08         11            6.0

# %%
bar_bo_by_year(x=cinema_film_grouby_1_genre.sort_values(by='bor_sum')['I_genre_name'],
            height= cinema_film_grouby_1_genre.sort_values(by='bor_sum')['bor_sum'],
            xlabel="Жанры",
            ylabel='Сумма сборов в миллионах руб.',
            title='Сумма соборов от проката фильмов с гос. поддержкой по жанру',
            rotation=90)
# Out:
# C:\Users\Egor\AppData\Local\Temp/ipykernel_19560/1354184497.py:21: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.ylim(ylim)

# %%
bar_bo_by_year(x=cinema_film_grouby_1_genre.sort_values(by='rating_median')['I_genre_name'],
            height= cinema_film_grouby_1_genre.sort_values(by='rating_median')['rating_median'],
            xlabel="Жанры",
            ylabel='Сумма сборов в миллионах руб.',
            title='Сумма соборов от проката фильмов с гос. поддержкой по жанру',
            rotation=90)
# Out:
# C:\Users\Egor\AppData\Local\Temp/ipykernel_19560/1354184497.py:21: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.ylim(ylim)

# %% [markdown]
# **Выводы:**
#
# Больше всего собрал жанр `комедия` - 12_479_980_000 рублей
#
# Меньше всего собрал жанр `детский` - 3_013_652 рублей
#
#
# Топ 2 жанров, которые получили гос. поддержку больше всех(по убыванию):
#
# 1. Драма - 87 раз.
# 2. Комедия - 73 раза.
#
# Топ 2 жанров, получившие меньше всего поддержки от государств(по убыванию):
# 1. Спорт, 	Биография	Криминал, Детский - 3 раза.
# 2. Реальное тв - 1 раз.
#
# Рейтинг по жанрам:
#
# Самый высокий рейтинг у жанров:
#
# 1. Детский - 7
# 2. Спорт - 7
# 3. Криминал - 7
#
# Самый низкий рейтинг у жанра:
#
# * Семейный

# %% [markdown]
# ### Анализ типов фильмов с гос. поддержкой

# %%
movies_shows['gov_sup_budget'].value_counts()
# Out:
# 0           7152
# 25000000      48
# 30000000      44
# 40000000      24
# 35000000      21
#             ...
# 27510000       1
# 24986000       1
# 25345000       1
# 50123915       1
# 25900000       1
# Name: gov_sup_budget, Length: 91, dtype: int64

# %%
movies_shows.head(1)
# Out:
#               title   c_number     show_start_date            type  \
# 0  открытый простор  221048915 2015-11-27 12:00:00  художественный
#
#                                          film_studio production_country  \
# 0  тачстоун пикчерз, кобальт пикчерз, бикон пикче...                сша
#
#         director                                   producer  age_restriction  \
# 0  кевин костнер  дэвид валдес, кевин костнер, джейк эбертс               18
#
#    refundable_support  ...  budget  financing_source ratings  \
# 0                   0  ...       0           unknown     7.0
#
#                    genres box_office_rub  I_director_name gov_sup_budget  \
# 0  боевик,драма,мелодрама            NaN        к.костнер              0
#
#    gov_sup_ratio  show_start_year  I_genre_name
# 0            0.0             2015        боевик
#
# [1 rows x 21 columns]

# %%
# Группировка по типу фильма сумма, сумма и количество записей
cinema_film_grouby_type = more_an(groupby='type')

# %%
cinema_film_grouby_type.reset_index(inplace=True)

# %%
cinema_film_grouby_type
# Out:
#              type box_office_rub       ratings
#                              sum count  median
# 0    анимационный   5.623293e+09    30     6.0
# 1  документальный   0.000000e+00     0     8.0
# 2  художественный   3.649022e+10   288     6.0

# %%
cinema_film_grouby_type = cinema_film_grouby_type.droplevel(level=1,axis=1)

# %%
cinema_film_grouby_type.columns = ['type','bor_sum', 'bor_count','rating_median']

# %%
bar_bo_by_year(x=cinema_film_grouby_type['type'],
            height= cinema_film_grouby_type['bor_sum'],
            xlabel="Тип",
            ylabel='Сумма сборов в миллионах руб.',
            title='Сумма соборов от проката фильмов с гос. поддержкой по типу фильма')
# Out:
# C:\Users\Egor\AppData\Local\Temp/ipykernel_19560/1354184497.py:21: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.ylim(ylim)

# %%
bar_bo_by_year(x=cinema_film_grouby_type['type'],
            height= cinema_film_grouby_type['rating_median'],
            xlabel="Тип",
            ylabel='Рейтинг',
            title='Рейтинг фильмов с гос. поддержкой по типу фильма')
# Out:
# C:\Users\Egor\AppData\Local\Temp/ipykernel_19560/1354184497.py:21: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.ylim(ylim)

# %%
# Если бы анимационные фильмы имели такое же количество
# гос поддержки, было бы у них больше сборов
5.623293e+09 * 10> 3.649022e+10
# Out:
# True

# %%
int(3.649022e+10)
# Out:
# 36490220000

# %% [markdown]
# **Выводы:**
#
# Государство выделяет больше всего бюджета на **художественные фильмы - 288 раз**, меньше на **анимационные - 30 раз**.
#
# Вероятнее всего только поэтому анимационные фильмы собрали меньше - 5_623_293_000 рублей, чем художественные - 36_490_220_000 рублей
#
# Таким образом, можно предложить заказчику, чтобы он спонсировал чаще анимационные фильмы или даже выделял субсидии на них.
#
# Медианный рейтинг по типу фильма (по убыванию):
# 1. **Документальный - 8**
# 2. **Художественный и Анимационный - 6**

# %% [markdown]
# ## Выводы:
#
# ### Количество фильмов по годам
#
# В основном наблюдается положительный тренд в количестве прокатных удостоверений, однако есть года, в которых количество оных падало (по силе падения по убыванию):
# 1. 2017 - серьезный спад, который откатил значения на уроень 2010 года (492 шт.) в количестве удостоверений - с 709 шт. до **496 шт.** Возможно вызвано какими-то ограничениями в законодательной базе. В 2018 последовал серьезный скачок, который отыграл потери почти в 2 раза.
#
# 2. 2015 - небольшой _спад_ около **10%** - с 694 шт. до **607 шт.**, который был отыгран в 2016 году.
# 3. 2011 - незначительный _спад_ около **10%** - с 492 шт. до **438 шт.**, в 2012 году отыграл все потери примерно на ту же величину как и 2015 год.
#
#
#
#
# ### Средняя и медианная сумма сбора по годам (по возрастанию)
#
# **Средняя** сумма сбора по годам (по возрастанию):
#
# 1. **2010 - 24_489.2 рублей**
# 2. **2012 - 55_138.3 рублей**
# 3. **2011 - 132_952.0 рублей**
# 4. **2013 - 162_838.1 рублей**
# 5. **2014 - 227_371_115.3 рублей**
# 6. **2015 - 85_492_120.3 рублей**
# 7. **2019 - 91_369_261.8 рублей**
# 8. **2016 - 92_405_603.9 рублей**
# 9. **2018 - 104_565_059.2 рублей**
# 10. **2017 - 136_032_793.3 рублей**
#
# **Медианная** сумма сбора по годам (по возрастанию):
#
# 1. **2010 - 1_700 рублей**
# 2. **2011 - 3_043 рублей**
# 3. **2013 - 3_545 рублей**
# 4. **2012 - 5_660 рублей**
# 5. **2014 - 21_445 рублей**
# 6. **2016 - 4_091_820 рублей**
# 7. **2019 - 4_627_798 рублей**
# 8. **2015 - 5_003_450 рублей**
# 9. **2018 - 8_891_102 рублей**
# 10. **2017 - 9_968_340 рублей**
#
# ### Доля прокатных фильмов - все удостоврение с первым числом меньше 22
#
# Из графика "пирог" мы подтвежраем факт, что рост количества прокатных удостоверений сохраняется
# практически во всех годах, кроме 2017. Лидеры по доле прокатных фильмов:
# 1.**2019 год(930 шт. - 14.6%)**
# 2.**2018 год(889 шт. - 14%)**
#
# Год с наименьшей долей прокатных фильмов:
#
# 1.**2011 год(438 шт. - 6.9%)**
#
#
# Также стоит выделить неудачные года по падению прокатных фильмов:
#
# 1.**2017 год(496 шт. - 7.8%)**
#
# ### Полнота данных проката по годам:
#
#
# **Наименьшая доля** данных о прокате была в **2010 году - 19.7%.**
#
# Самое **полное представления** данных о прокате был в **2015 год - 76.1%.**
#
#
# Доля полноты данных (по возрастанию):
# 1. 2010 - 19.7%
# 2. 2011 - 24.2%
# 3. 2012 - 24.7%
# 4. 2013 - 31.1%
# 5. 2014 - 39.2%
# 6. 2018 - 53.4%
# 7. 2019 - 57.0%
# 8. 2017 - 72.0%
# 9. 2016 - 73.1%
# 10. 2015 - 76.1%
#
#
# ### Сумма сбора ~ возрастное ограничение + год
#
# Категории:
# * `0`
#  - **Год с минимальной суммой сбора 2019 17.7 миллионов рублей**
#  - **Год с максимальной суммой сбора 2015 379 миллионов рублей**
# * `6`
#  - **Год с минимальной суммой сбора 2015 8_701 миллионов рублей**
#  - **Год с максимальной суммой сбора 2019 12_852.5 миллионов рублей**
# * `12`
#  - **Год с минимальной суммой сбора 2017 7_851.4  миллионов рублей**
#  - **Год с максимальной суммой сбора 2018 14_267.3 миллионов рублей**
# * `16`
#  - **Год с минимальной суммой сбора 2015 1_136_812  миллионов рублей**
#  - **Год с максимальной суммой сбора 2017 1_874_504 миллионов рублей**
# * `18`
#  - **Год с минимальной суммой сбора 2015 5_432.3 миллионов рублей**
#  - **Год с максимальной суммой сбора 2019 10_121.8 миллионов рублей**
#
# Также заметим, что:
# * Сумма сборов категории **1** растет с каждым годом.
# * Сумма сборов категории **16** росла до 2017 года, а после начала падать.
# * Сумма сборов категории **12** и росла и падала на протяжении 5 лет, однако в 2017 году было одно из самых больших падений в сумме сбора
# * Сумма сборов категории **6** с 2015 года сильно выросла, однако не смогла укрепить свои позиции и в дальнейшем имела большую волотильность
# * Сумма сборов категории **0** падает из года в год за исключением 2017 года.
#
#
# ### Процент государственной поддержки по годам
#
# 1. **2013 - 47.35%**
# 2.**2014 - 53.90%**
# 3.**2015 - 61.10%**
# 4.**2016 - 63.70%**
# 5.**2017 - 47.70%**
# 6.**2018 - 55.55%**
# 7.**2019 - 58.30%**
#
# Наивысший процент поддержки:
# * **2016 - 63.7%**
#
# Наименшьний процент поддержки:
# * **2013 - 47.35%**
#
# ### Процент возвращаемой и невозвращаемой государственной поддержки по годам:
# * **Минимальный** процент возратных средств, не считая 2013 - 0%, была в **2014 году - 10.3%.**
#
# * **Максимальный** процент возратных средст приходится на **2017 год - 19.9%**
#
# Возвращаемый (по возрастанию):
#
# 1.**2013 - 0%**
# 2.**2014 - 10.3%**
# 3.**2019 - 11.3%**
# 4.**2018 - 13.3%**
# 5.**2016 - 14.6%**
# 6.**2015 - 14.7%**
# 7.**2017 - 19.9%**
#
# * **Минимальный** процент невозратных средств была в **2017 году - 80.1%.**
#
# * **Максимальный**, не считая 2013 - 100%, процент невозратных средст приходится на **2014 год - 89.7%**
#
# Невозврощаемый (по возрастанию):
# 1. **2017 - 80.1%**
# 2. **2015 - 85.3%**
# 3. **2016 - 85.4%**
# 4. **2018 - 86.7%**
# 5. **2019 - 88.7%**
# 6. **2014 - 89.7%**
# 7. **2013 - 100%**
#
#
# ### Анализ жанров фильмов с гос. поддержкой и рейтинга
#
# Больше всего собрал жанр **Комедия - 12_479_980_000 рублей**
#
# Меньше всего собрал жанр **Детский - 3_013_652 рублей**
#
#
# Топ 2 жанров, которые получили гос. поддержку больше всех(по убыванию):
#
# 1. **Драма - 87 раз.**
# 2. **Комедия - 73 раза.**
#
# Топ 2 жанров, получившие меньше всего поддержки от государств(по убыванию):
# 1. **Спорт, 	Биография	Криминал, Детский - 3 раза.**
# 2. **Реальное тв - 1 раз.**
#
# Рейтинг по жанрам:
#
# Самый высокий рейтинг у жанров:
#
# 1. **Детский - 7**
# 2. **Спорт - 7**
# 3. **Криминал - 7**
#
# Самый низкий рейтинг у жанра:
#
# * **Семейный - 4**
#
# Несмотря на низкий рейтинг комедия является лидером прокатного оборота
#
#
# ### Анализ типов фильмов с гос.поддержкой и рейтинга
#
# Государство выделяет больше всего бюджета на **художественные фильмы - 288 раз**, меньше на **анимационные - 30 раз**.
#
# Вероятнее всего только поэтому **анимационные** фильмы собрали меньше - **5_623_293_000 рублей**, чем **художественные - 36_490_220_000 рублей**
#
# Таким образом, можно предложить заказчику, чтобы он спонсировал чаще анимационные фильмы или даже выделял субсидии на них.
#
# Медианный рейтинг по типу фильма (по убыванию):
# 1. **Документальный - 8**
# 2. **Художественный и Анимационный - 6**
